# %%
# Query BigGIM-DrugResponse KP

# %%
import requests
import json
import os
#BigGIM_URL = "https://api.bte.ncats.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query"
#BigGIM_URL = "https://api.bte.ncats.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query"


BigGIM_URL_dev = "https://api.bte.ncats.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query"
BigGIM_URL_ci = "https://bte.ci.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query"
BigGIM_URL_test = "https://bte.test.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query" #TRAPI 1.4 endpoint
BigGIM_URL      = "https://bte.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query"  #TRAPI 1.3 endpoint

#BigGIM_URL_test = "https://api.bte.ncats.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31/query"
#https://arax.test.transltr.io/ #TRAPI1.4
#https://arax.transltr.io/ #TRAPI1.3

#Specify url in the ARAX with https://bte.test.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31 or https://bte.transltr.io/v1/smartapi/adf20dd6ff23dfe18e8e012bde686e31

# SmartAPI regstration: https://smart-api.info/registry?q=multiomics

# %%
#Example: which drugs shows sensitivity with KRAS (NCBIGene:3845) altered?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids":["NCBIGene:3845"],
 
                },
                "n1": {
                    "categories":["biolink:Protein", "biolink:Gene"],

               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:physically_interacts_with"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL_test,json=query_json)
result = response.json()["message"]

# %%
result['knowledge_graph']
# Out:
# {'nodes': {'NCBIGene:3845': {'categories': ['biolink:Gene'],
#    'name': 'KRAS',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3845',
#       'ENSEMBL:ENSG00000133703',
#       'HGNC:6407',
#       'OMIM:190070',
#       'UMLS:C1537502',
#       'UniProtKB:A0A024RAV5',
#       'UniProtKB:I1SRC5',
#       'UniProtKB:L7RSL8',
#       'UniProtKB:P01116',
#       'PR:P01116',
#       'UMLS:C0763464']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['KRAS',
#       'KRAS gene',
#       'A0A024RAV5_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog, isoform CRA_b (trembl)',
#       'I1SRC5_HUMAN UBE2L3/KRAS fusion protein (trembl)',
#       'L7RSL8_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog (trembl)',
#       'RASK_HUMAN GTPase KRas (sprot)',
#       'GTPase KRas (human)',
#       'KRAS protein, human']}]},
#   'NCBIGene:9770': {'categories': ['biolink:Gene'],
#    'name': 'RASSF2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:9770',
#       'ENSEMBL:ENSG00000101265',
#       'HGNC:9883',
#       'OMIM:609492',
#       'UMLS:C1419286',
#       'UniProtKB:P50749',
#       'PR:P50749']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RASSF2',
#       'RASSF2 gene',
#       'RASF2_HUMAN Ras association domain-containing protein 2 (sprot)',
#       'Ras association domain-containing protein 2 (human)']}]},
#   'NCBIGene:5900': {'categories': ['biolink:Gene'],
#    'name': 'RALGDS',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5900',
#       'ENSEMBL:ENSG00000160271',
#       'HGNC:9842',
#       'OMIM:601619',
#       'UMLS:C1335588',
#       'UniProtKB:Q12967',
#       'PR:Q12967',
#       'UMLS:C4317017',
#       'UniProtKB:Q8N4Y1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RALGDS',
#       'RALGDS gene',
#       'GNDS_HUMAN Ral guanine nucleotide dissociation stimulator (sprot)',
#       'Ral guanine nucleotide dissociation stimulator (human)',
#       'Ral Guanine Nucleotide Dissociation Stimulator, human',
#       'Q8N4Y1_HUMAN Ral guanine nucleotide dissociation stimulator-like 1 (Fragment) (trembl)']}]},
#   'NCBIGene:5296': {'categories': ['biolink:Gene'],
#    'name': 'PIK3R2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5296',
#       'ENSEMBL:ENSG00000105647',
#       'HGNC:8980',
#       'OMIM:603157',
#       'UMLS:C1418577',
#       'UniProtKB:O00459',
#       'PR:O00459',
#       'ENSEMBL:ENSP00000222254',
#       'ENSEMBL:ENSP00000222254.6',
#       'UMLS:C3537330']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PIK3R2',
#       'PIK3R2 gene',
#       'P85B_HUMAN Phosphatidylinositol 3-kinase regulatory subunit beta (sprot)',
#       'phosphatidylinositol 3-kinase regulatory subunit beta (human)',
#       'Phosphatidylinositol 3-Kinase Regulatory Subunit Beta, Human']}]},
#   'NCBIGene:5863': {'categories': ['biolink:Gene'],
#    'name': 'RGL2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5863',
#       'ENSEMBL:ENSG00000237441',
#       'HGNC:9769',
#       'OMIM:602306',
#       'UMLS:C1538835',
#       'UniProtKB:A0A024RCS9',
#       'UniProtKB:O15211',
#       'PR:O15211']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RGL2',
#       'RGL2 gene',
#       'A0A024RCS9_HUMAN RGL2 (trembl)',
#       'RGL2_HUMAN Ral guanine nucleotide dissociation stimulator-like 2 (sprot)',
#       'Ral guanine nucleotide dissociation stimulator-like 2 (human)']}]},
#   'NCBIGene:596': {'categories': ['biolink:Gene'],
#    'name': 'BCL2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:596',
#       'ENSEMBL:ENSG00000171791',
#       'HGNC:990',
#       'OMIM:151430',
#       'UMLS:C0376515',
#       'UniProtKB:A0A024R2B3',
#       'UniProtKB:A0A024R2C4',
#       'UniProtKB:A0A7I2V3S7',
#       'ENSEMBL:ENSP00000503628',
#       'ENSEMBL:ENSP00000503628.1',
#       'UniProtKB:P10415',
#       'PR:P10415',
#       'UMLS:C4042483']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['BCL2',
#       'BCL2 gene',
#       'A0A024R2B3_HUMAN Apoptosis regulator Bcl-2 (trembl)',
#       'A0A024R2C4_HUMAN Apoptosis regulator Bcl-2 (trembl)',
#       'A0A7I2V3S7_HUMAN Apoptosis regulator Bcl-2 (trembl)',
#       'BCL2_HUMAN Apoptosis regulator Bcl-2 (sprot)',
#       'apoptosis regulator Bcl-2 (human)',
#       'BCL2 protein, human']}]},
#   'NCBIGene:5924': {'categories': ['biolink:Gene'],
#    'name': 'RASGRF2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5924',
#       'ENSEMBL:ENSG00000113319',
#       'HGNC:9876',
#       'OMIM:606614',
#       'UMLS:C1419282',
#       'UniProtKB:A0A2X0SFL3',
#       'UniProtKB:O14827',
#       'PR:O14827',
#       'ENSEMBL:ENSP00000265080',
#       'ENSEMBL:ENSP00000265080.4',
#       'UMLS:C1611078',
#       'UniProtKB:Q68DX5']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RASGRF2',
#       'RASGRF2 gene',
#       'A0A2X0SFL3_HUMAN RASGRF2 (Fragment) (trembl)',
#       'RGRF2_HUMAN Ras-specific guanine nucleotide-releasing factor 2 (sprot)',
#       'Ras-specific guanine nucleotide-releasing factor 2 (human)',
#       'RASGRF2 protein, human',
#       'Q68DX5_HUMAN Uncharacterized protein DKFZp781H1715 (Fragment) (trembl)']}]},
#   'NCBIGene:351': {'categories': ['biolink:Gene'],
#    'name': 'APP',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:351',
#       'ENSEMBL:ENSG00000142192',
#       'HGNC:620',
#       'OMIM:104760',
#       'UMLS:C1364818',
#       'UniProtKB:A0A0A0MRG2',
#       'ENSEMBL:ENSP00000352760',
#       'ENSEMBL:ENSP00000352760.4',
#       'UniProtKB:A0A140VJC8',
#       'UniProtKB:B4DGD0',
#       'UniProtKB:B4DJT9',
#       'UniProtKB:E9PG40',
#       'ENSEMBL:ENSP00000398879',
#       'ENSEMBL:ENSP00000398879.2',
#       'UniProtKB:P05067',
#       'PR:P05067',
#       'UMLS:C0611285']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['APP',
#       'APP gene',
#       'A0A0A0MRG2_HUMAN Amyloid-beta A4 protein (trembl)',
#       'A0A140VJC8_HUMAN Amyloid-beta A4 protein (trembl)',
#       'B4DGD0_HUMAN Amyloid-beta A4 protein (trembl)',
#       'B4DJT9_HUMAN Amyloid-beta A4 protein (trembl)',
#       'E9PG40_HUMAN Amyloid-beta A4 protein (trembl)',
#       'A4_HUMAN Amyloid-beta precursor protein (sprot)',
#       'amyloid-beta precursor protein (human)',
#       'APP protein, human']}]},
#   'NCBIGene:8036': {'categories': ['biolink:Gene'],
#    'name': 'SHOC2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:8036',
#       'ENSEMBL:ENSG00000108061',
#       'HGNC:15454',
#       'OMIM:602775',
#       'UMLS:C1423500',
#       'UniProtKB:Q9UQ13',
#       'PR:Q9UQ13',
#       'UMLS:C0676309']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SHOC2',
#       'SHOC2 gene',
#       'SHOC2_HUMAN Leucine-rich repeat protein SHOC-2 (sprot)',
#       'leucine-rich repeat protein SHOC-2 (human)',
#       'Leucine-Rich Repeat Protein SHOC-2, Human']}]},
#   'NCBIGene:5290': {'categories': ['biolink:Gene'],
#    'name': 'PIK3CA',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5290',
#       'ENSEMBL:ENSG00000121879',
#       'HGNC:8975',
#       'OMIM:171834',
#       'UMLS:C1335212',
#       'UniProtKB:P42336',
#       'PR:P42336',
#       'ENSEMBL:ENSP00000263967',
#       'ENSEMBL:ENSP00000263967.3',
#       'UMLS:C1451005',
#       'UniProtKB:Q4LE51']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PIK3CA',
#       'PIK3CA gene',
#       'PK3CA_HUMAN Phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit alpha isoform (sprot)',
#       'phosphatidylinositol 4,5-bisphosphate 3-kinase catalytic subunit alpha isoform (human)',
#       'PIK3CA protein, human',
#       'Q4LE51_HUMAN Phosphatidylinositol-4,5-bisphosphate 3-kinase (Fragment) (trembl)']}]},
#   'NCBIGene:5894': {'categories': ['biolink:Gene'],
#    'name': 'RAF1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5894',
#       'ENSEMBL:ENSG00000132155',
#       'HGNC:9829',
#       'OMIM:164760',
#       'UMLS:C0812215',
#       'UniProtKB:A0A0S2Z4L5',
#       'ENSEMBL:ENSP00000508794',
#       'ENSEMBL:ENSP00000508794.1',
#       'ENSEMBL:ENSP00000509612',
#       'ENSEMBL:ENSP00000509612.1',
#       'ENSEMBL:ENSP00000509669',
#       'ENSEMBL:ENSP00000509669.1',
#       'UniProtKB:L7RRS6',
#       'UniProtKB:P04049',
#       'PR:P04049',
#       'UMLS:C4706023']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAF1',
#       'RAF1 gene',
#       'A0A0S2Z4L5_HUMAN Non-specific serine/threonine protein kinase (Fragment) (trembl)',
#       'L7RRS6_HUMAN Non-specific serine/threonine protein kinase (trembl)',
#       'RAF1_HUMAN RAF proto-oncogene serine/threonine-protein kinase (sprot)',
#       'RAF proto-oncogene serine/threonine-protein kinase (human)',
#       'RAF1 protein, human']}]},
#   'NCBIGene:2011': {'categories': ['biolink:Gene'],
#    'name': 'MARK2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:2011',
#       'ENSEMBL:ENSG00000072518',
#       'HGNC:3332',
#       'OMIM:600526',
#       'UMLS:C1414387',
#       'UniProtKB:A0A140VJP1',
#       'UniProtKB:A8K2S4',
#       'UniProtKB:E7ETY4',
#       'ENSEMBL:ENSP00000415494',
#       'ENSEMBL:ENSP00000415494.3',
#       'UniProtKB:Q7KZI7',
#       'PR:Q7KZI7',
#       'UMLS:C0299851']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MARK2',
#       'MARK2 gene',
#       'A0A140VJP1_HUMAN Non-specific serine/threonine protein kinase (trembl)',
#       'A8K2S4_HUMAN Non-specific serine/threonine protein kinase (trembl)',
#       'E7ETY4_HUMAN Non-specific serine/threonine protein kinase (trembl)',
#       'MARK2_HUMAN Serine/threonine-protein kinase MARK2 (sprot)',
#       'serine/threonine-protein kinase MARK2 (human)',
#       'MARK2 protein, human']}]},
#   'NCBIGene:6714': {'categories': ['biolink:Gene'],
#    'name': 'SRC',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6714',
#       'ENSEMBL:ENSG00000197122',
#       'HGNC:11283',
#       'OMIM:190090',
#       'UMLS:C0080298',
#       'UniProtKB:P12931',
#       'PR:P12931',
#       'UMLS:C3853644']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SRC',
#       'SRC gene',
#       'SRC_HUMAN Proto-oncogene tyrosine-protein kinase Src (sprot)',
#       'proto-oncogene tyrosine-protein kinase Src (human)',
#       'Proto-Oncogene Tyrosine-Protein Kinase Src, human']}]},
#   'NCBIGene:57669': {'categories': ['biolink:Gene'],
#    'name': 'EPB41L5',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:57669',
#       'ENSEMBL:ENSG00000115109',
#       'HGNC:19819',
#       'OMIM:611730',
#       'UMLS:C1426448',
#       'UniProtKB:Q9HCM4',
#       'PR:Q9HCM4',
#       'UMLS:C5401351']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['EPB41L5',
#       'EPB41L5 gene',
#       'E41L5_HUMAN Band 4.1-like protein 5 (sprot)',
#       'band 4.1-like protein 5 (human)',
#       'Band 4.1-Like Protein 5']}]},
#   'NCBIGene:768211': {'categories': ['biolink:Gene'],
#    'name': 'RELL1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:768211',
#       'ENSEMBL:ENSG00000181826',
#       'HGNC:27379',
#       'OMIM:611212',
#       'UMLS:C1970015',
#       'UniProtKB:Q8IUW5',
#       'PR:Q8IUW5',
#       'ENSEMBL:ENSP00000313385',
#       'ENSEMBL:ENSP00000313385.4',
#       'ENSEMBL:ENSP00000398778',
#       'ENSEMBL:ENSP00000398778.2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RELL1',
#       'RELL1 gene',
#       'RELL1_HUMAN RELT-like protein 1 (sprot)',
#       'RELT-like protein 1 (human)']}]},
#   'NCBIGene:25921': {'categories': ['biolink:Gene'],
#    'name': 'ZDHHC5',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:25921',
#       'ENSEMBL:ENSG00000156599',
#       'HGNC:18472',
#       'OMIM:614586',
#       'UMLS:C1425537',
#       'UniProtKB:A0A024R546',
#       'UniProtKB:Q9C0B5',
#       'PR:Q9C0B5']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['ZDHHC5',
#       'ZDHHC5 gene',
#       'A0A024R546_HUMAN Palmitoyltransferase (trembl)',
#       'ZDHC5_HUMAN Palmitoyltransferase ZDHHC5 (sprot)',
#       'palmitoyltransferase ZDHHC5 (human)']}]},
#   'NCBIGene:51715': {'categories': ['biolink:Gene'],
#    'name': 'RAB23',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:51715',
#       'ENSEMBL:ENSG00000112210',
#       'HGNC:14263',
#       'OMIM:606144',
#       'UMLS:C1422524',
#       'UniProtKB:A0A024RD41',
#       'UniProtKB:Q9ULC3',
#       'PR:Q9ULC3',
#       'ENSEMBL:ENSP00000320413',
#       'ENSEMBL:ENSP00000320413.3',
#       'ENSEMBL:ENSP00000417610',
#       'ENSEMBL:ENSP00000417610.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAB23',
#       'RAB23 gene',
#       'A0A024RD41_HUMAN RAB23, member RAS oncogene family, isoform CRA_a (trembl)',
#       'RAB23_HUMAN Ras-related protein Rab-23 (sprot)',
#       'Ras-related protein Rab-23 (human)']}]},
#   'NCBIGene:255252': {'categories': ['biolink:Gene'],
#    'name': 'LRRC57',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:255252',
#       'ENSEMBL:ENSG00000180979',
#       'HGNC:26719',
#       'UMLS:C1825902',
#       'UniProtKB:A0A024R9M3',
#       'UniProtKB:Q8N9N7',
#       'PR:Q8N9N7',
#       'ENSEMBL:ENSP00000326817',
#       'ENSEMBL:ENSP00000326817.2',
#       'ENSEMBL:ENSP00000380319',
#       'ENSEMBL:ENSP00000380319.3',
#       'ENSEMBL:ENSP00000455445',
#       'ENSEMBL:ENSP00000455445.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['LRRC57',
#       'LRRC57 gene',
#       'A0A024R9M3_HUMAN Leucine rich repeat containing 57, isoform CRA_c (trembl)',
#       'LRC57_HUMAN Leucine-rich repeat-containing protein 57 (sprot)',
#       'leucine-rich repeat-containing protein 57 (human)']}]},
#   'NCBIGene:7779': {'categories': ['biolink:Gene'],
#    'name': 'SLC30A1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7779',
#       'ENSEMBL:ENSG00000170385',
#       'HGNC:11012',
#       'OMIM:609521',
#       'UMLS:C1420178',
#       'UniProtKB:Q9Y6M5',
#       'PR:Q9Y6M5',
#       'ENSEMBL:ENSP00000355968',
#       'ENSEMBL:ENSP00000355968.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLC30A1',
#       'SLC30A1 gene',
#       'ZNT1_HUMAN Zinc transporter 1 (sprot)',
#       'zinc transporter 1 (human)']}]},
#   'NCBIGene:6768': {'categories': ['biolink:Gene'],
#    'name': 'ST14',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6768',
#       'ENSEMBL:ENSG00000149418',
#       'HGNC:11344',
#       'OMIM:606797',
#       'UMLS:C1366520',
#       'UniProtKB:Q9Y5Y6',
#       'PR:Q9Y5Y6',
#       'ENSEMBL:ENSP00000278742',
#       'ENSEMBL:ENSP00000278742.5',
#       'UMLS:C1451644']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['ST14',
#       'ST14 gene',
#       'ST14_HUMAN Suppressor of tumorigenicity 14 protein (sprot)',
#       'suppressor of tumorigenicity 14 protein (human)',
#       'ST14 protein, human']}]},
#   'NCBIGene:9497': {'categories': ['biolink:Gene'],
#    'name': 'SLC4A7',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:9497',
#       'ENSEMBL:ENSG00000033867',
#       'HGNC:11033',
#       'OMIM:603353',
#       'UMLS:C1420197',
#       'UniProtKB:B5M450',
#       'UniProtKB:E9PFN4',
#       'ENSEMBL:ENSP00000406804',
#       'ENSEMBL:ENSP00000406804.1',
#       'UniProtKB:Q9Y6M7',
#       'PR:Q9Y6M7',
#       'UMLS:C1448554']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLC4A7',
#       'SLC4A7 gene',
#       'B5M450_HUMAN Anion exchange protein (trembl)',
#       'E9PFN4_HUMAN Anion exchange protein (trembl)',
#       'S4A7_HUMAN Sodium bicarbonate cotransporter 3 (sprot)',
#       'sodium bicarbonate cotransporter 3 (human)',
#       'SLC4A7 protein, human']}]},
#   'NCBIGene:55789': {'categories': ['biolink:Gene'],
#    'name': 'DEPDC1B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:55789',
#       'ENSEMBL:ENSG00000035499',
#       'HGNC:24902',
#       'OMIM:616073',
#       'UMLS:C1539267',
#       'UniProtKB:Q8WUY9',
#       'PR:Q8WUY9']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['DEPDC1B',
#       'DEPDC1B gene',
#       'DEP1B_HUMAN DEP domain-containing protein 1B (sprot)',
#       'DEP domain-containing protein 1B (human)']}]},
#   'NCBIGene:6558': {'categories': ['biolink:Gene'],
#    'name': 'SLC12A2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6558',
#       'ENSEMBL:ENSG00000064651',
#       'HGNC:10911',
#       'OMIM:600840',
#       'UMLS:C1420091',
#       'UniProtKB:B7ZM24',
#       'UniProtKB:P55011',
#       'PR:P55011',
#       'UMLS:C3711655',
#       'UniProtKB:Q53ZR1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLC12A2',
#       'SLC12A2 gene',
#       'B7ZM24_HUMAN SLC12A2 protein (trembl)',
#       'S12A2_HUMAN Solute carrier family 12 member 2 (sprot)',
#       'solute carrier family 12 member 2 (human)',
#       'SLC12A2 protein, human',
#       'Q53ZR1_HUMAN Bumetanide-sensitive Na-K-Cl cotransporter (trembl)']}]},
#   'NCBIGene:5870': {'categories': ['biolink:Gene'],
#    'name': 'RAB6A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5870',
#       'ENSEMBL:ENSG00000175582',
#       'HGNC:9786',
#       'OMIM:179513',
#       'UMLS:C1419215',
#       'UniProtKB:A0A024R5H8',
#       'UniProtKB:A0A024R5J5',
#       'UniProtKB:P20340',
#       'PR:P20340',
#       'UniProtKB:Q53ET8']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAB6A',
#       'RAB6A gene',
#       'A0A024R5H8_HUMAN RAB6A, member RAS oncogene family, isoform CRA_b (trembl)',
#       'A0A024R5J5_HUMAN H.sapiens ras-related Hrab6 protein (trembl)',
#       'RAB6A_HUMAN Ras-related protein Rab-6A (sprot)',
#       'Ras-related protein Rab-6A (human)',
#       'Q53ET8_HUMAN RAB6A, member RAS oncogene family isoform a variant (Fragment) (trembl)']}]},
#   'NCBIGene:5297': {'categories': ['biolink:Gene'],
#    'name': 'PI4KA',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5297',
#       'ENSEMBL:ENSG00000241973',
#       'HGNC:8983',
#       'OMIM:600286',
#       'UMLS:C1418579',
#       'UniProtKB:B4DYG5',
#       'UniProtKB:P42356',
#       'PR:P42356',
#       'UniProtKB:Q4LE69']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PI4KA',
#       'PI4KA gene',
#       'B4DYG5_HUMAN 1-phosphatidylinositol 4-kinase (trembl)',
#       'PI4KA_HUMAN Phosphatidylinositol 4-kinase alpha (sprot)',
#       'phosphatidylinositol 4-kinase alpha (human)',
#       'Q4LE69_HUMAN 1-phosphatidylinositol 4-kinase (Fragment) (trembl)']}]},
#   'NCBIGene:2030': {'categories': ['biolink:Gene'],
#    'name': 'SLC29A1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:2030',
#       'ENSEMBL:ENSG00000112759',
#       'HGNC:11003',
#       'OMIM:602193',
#       'UMLS:C1420171',
#       'UniProtKB:Q99808',
#       'PR:Q99808',
#       'UMLS:C1130454']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLC29A1',
#       'SLC29A1 gene',
#       'S29A1_HUMAN Equilibrative nucleoside transporter 1 (sprot)',
#       'equilibrative nucleoside transporter 1 (human)',
#       'SLC29A1 protein, human']}]},
#   'NCBIGene:65010': {'categories': ['biolink:Gene'],
#    'name': 'SLC26A6',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:65010',
#       'ENSEMBL:ENSG00000225697',
#       'HGNC:14472',
#       'OMIM:610068',
#       'UMLS:C1422678',
#       'UniProtKB:A0A0C4DFT5',
#       'ENSEMBL:ENSP00000351597',
#       'ENSEMBL:ENSP00000351597.6',
#       'UniProtKB:G3XAC1',
#       'ENSEMBL:ENSP00000337648',
#       'ENSEMBL:ENSP00000337648.8',
#       'UniProtKB:Q96MZ1',
#       'UniProtKB:Q9BXS9',
#       'PR:Q9BXS9',
#       'UMLS:C1434701',
#       'UniProtKB:Q9Y3Y1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLC26A6',
#       'SLC26A6 gene',
#       'A0A0C4DFT5_HUMAN Solute carrier family 26 member 6 (trembl)',
#       'G3XAC1_HUMAN Solute carrier family 26 member 6 (trembl)',
#       'Q96MZ1_HUMAN cDNA FLJ31675 fis, clone NT2RI2005087, highly similar to Homo sapiens putative anion transporter 1 mRNA (trembl)',
#       'S26A6_HUMAN Solute carrier family 26 member 6 (sprot)',
#       'solute carrier family 26 member 6 (human)',
#       'SLC26A6 protein, human',
#       'Q9Y3Y1_HUMAN Uncharacterized protein DKFZp586E1422 (Fragment) (trembl)']}]},
#   'NCBIGene:79572': {'categories': ['biolink:Gene'],
#    'name': 'ATP13A3',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:79572',
#       'ENSEMBL:ENSG00000133657',
#       'HGNC:24113',
#       'OMIM:610232',
#       'UMLS:C1540216',
#       'UniProtKB:A0A2R8Y635',
#       'ENSEMBL:ENSP00000494937',
#       'ENSEMBL:ENSP00000494937.2',
#       'UniProtKB:Q9H7F0',
#       'PR:Q9H7F0']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['ATP13A3',
#       'ATP13A3 gene',
#       'A0A2R8Y635_HUMAN Polyamine-transporting ATPase 13A3 (trembl)',
#       'AT133_HUMAN Polyamine-transporting ATPase 13A3 (sprot)',
#       'polyamine-transporting ATPase 13A3 (human)']}]},
#   'NCBIGene:55742': {'categories': ['biolink:Gene'],
#    'name': 'PARVA',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:55742',
#       'ENSEMBL:ENSG00000197702',
#       'HGNC:14652',
#       'OMIM:608120',
#       'UMLS:C1422815',
#       'UniProtKB:Q9NVD7',
#       'PR:Q9NVD7']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PARVA',
#       'PARVA gene',
#       'PARVA_HUMAN Alpha-parvin (sprot)',
#       'alpha-parvin (human)']}]},
#   'NCBIGene:6548': {'categories': ['biolink:Gene'],
#    'name': 'SLC9A1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6548',
#       'ENSEMBL:ENSG00000090020',
#       'HGNC:11071',
#       'OMIM:107310',
#       'UMLS:C1420232',
#       'UniProtKB:B2RAH2',
#       'UniProtKB:P19634',
#       'PR:P19634',
#       'UMLS:C1453959']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLC9A1',
#       'SLC9A1 gene',
#       'B2RAH2_HUMAN Sodium/hydrogen exchanger (trembl)',
#       'SL9A1_HUMAN Sodium/hydrogen exchanger 1 (sprot)',
#       'sodium/hydrogen exchanger 1 (human)',
#       'SLC9A1 protein, human']}]},
#   'NCBIGene:57446': {'categories': ['biolink:Gene'],
#    'name': 'NDRG3',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:57446',
#       'ENSEMBL:ENSG00000101079',
#       'HGNC:14462',
#       'OMIM:605273',
#       'UMLS:C1422668',
#       'UniProtKB:Q5TH30',
#       'ENSEMBL:ENSP00000362909',
#       'ENSEMBL:ENSP00000362909.2',
#       'UniProtKB:Q9UGV2',
#       'PR:Q9UGV2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NDRG3',
#       'NDRG3 gene',
#       'Q5TH30_HUMAN Protein NDRG3 (trembl)',
#       'NDRG3_HUMAN Protein NDRG3 (sprot)',
#       'protein NDRG3 (human)']}]},
#   'NCBIGene:10205': {'categories': ['biolink:Gene'],
#    'name': 'MPZL2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10205',
#       'ENSEMBL:ENSG00000149573',
#       'HGNC:3496',
#       'OMIM:604873',
#       'UMLS:C1414478',
#       'UniProtKB:A0A024R3K1',
#       'UniProtKB:O60487',
#       'PR:O60487',
#       'ENSEMBL:ENSP00000278937',
#       'ENSEMBL:ENSP00000278937.2',
#       'ENSEMBL:ENSP00000408362',
#       'ENSEMBL:ENSP00000408362.2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MPZL2',
#       'MPZL2 gene',
#       'A0A024R3K1_HUMAN Epithelial V-like antigen 1, isoform CRA_a (trembl)',
#       'MPZL2_HUMAN Myelin protein zero-like protein 2 (sprot)',
#       'myelin protein zero-like protein 2 (human)']}]},
#   'NCBIGene:284352': {'categories': ['biolink:Gene'],
#    'name': 'PPP1R37',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:284352',
#       'ENSEMBL:ENSG00000104866',
#       'HGNC:27607',
#       'UMLS:C3471439',
#       'UniProtKB:O75864',
#       'PR:O75864']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PPP1R37',
#       'PPP1R37 gene',
#       'PPR37_HUMAN Protein phosphatase 1 regulatory subunit 37 (sprot)',
#       'protein phosphatase 1 regulatory subunit 37 (human)']}]},
#   'NCBIGene:6674': {'categories': ['biolink:Gene'],
#    'name': 'SPAG1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6674',
#       'ENSEMBL:ENSG00000104450',
#       'HGNC:11212',
#       'OMIM:603395',
#       'UMLS:C1420337',
#       'UniProtKB:Q07617',
#       'PR:Q07617']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SPAG1',
#       'SPAG1 gene',
#       'SPAG1_HUMAN Sperm-associated antigen 1 (sprot)',
#       'sperm-associated antigen 1 (human)']}]},
#   'NCBIGene:2041': {'categories': ['biolink:Gene'],
#    'name': 'EPHA1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:2041',
#       'ENSEMBL:ENSG00000146904',
#       'HGNC:3385',
#       'OMIM:179610',
#       'UMLS:C0812262',
#       'UniProtKB:P21709',
#       'PR:P21709',
#       'UMLS:C1370509']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['EPHA1',
#       'EPHA1 gene',
#       'EPHA1_HUMAN Ephrin type-A receptor 1 (sprot)',
#       'ephrin type-A receptor 1 (human)',
#       'Ephrin Type-A Receptor 1, human']}]},
#   'NCBIGene:2319': {'categories': ['biolink:Gene'],
#    'name': 'FLOT2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:2319',
#       'ENSEMBL:ENSG00000132589',
#       'HGNC:3758',
#       'OMIM:131560',
#       'UMLS:C1414639',
#       'UniProtKB:A0A024QZ62',
#       'UniProtKB:J3QLD9',
#       'ENSEMBL:ENSP00000463503',
#       'ENSEMBL:ENSP00000463503.1',
#       'UniProtKB:Q14254',
#       'PR:Q14254',
#       'ENSEMBL:ENSP00000378368',
#       'ENSEMBL:ENSP00000378368.3',
#       'UMLS:C1579837',
#       'UniProtKB:Q6FG43',
#       'UniProtKB:Q9BTI6']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['FLOT2',
#       'FLOT2 gene',
#       'A0A024QZ62_HUMAN Flotillin (trembl)',
#       'J3QLD9_HUMAN Flotillin (trembl)',
#       'FLOT2_HUMAN Flotillin-2 (sprot)',
#       'flotillin-2 (human)',
#       'FLOT2 protein, human',
#       'Q6FG43_HUMAN Flotillin (trembl)',
#       'Q9BTI6_HUMAN Flotillin (trembl)']}]},
#   'NCBIGene:10298': {'categories': ['biolink:Gene'],
#    'name': 'PAK4',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10298',
#       'ENSEMBL:ENSG00000130669',
#       'HGNC:16059',
#       'OMIM:605451',
#       'UMLS:C1423944',
#       'UniProtKB:A0A024R0J1',
#       'UniProtKB:A0A024R0L8',
#       'UniProtKB:O96013',
#       'PR:O96013',
#       'UMLS:C1449211']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PAK4',
#       'PAK4 gene',
#       'A0A024R0J1_HUMAN Non-specific serine/threonine protein kinase (trembl)',
#       'A0A024R0L8_HUMAN Non-specific serine/threonine protein kinase (trembl)',
#       'PAK4_HUMAN Serine/threonine-protein kinase PAK 4 (sprot)',
#       'serine/threonine-protein kinase PAK 4 (human)',
#       'PAK4 protein, human']}]},
#   'NCBIGene:91833': {'categories': ['biolink:Gene'],
#    'name': 'WDR20',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:91833',
#       'ENSEMBL:ENSG00000140153',
#       'HGNC:19667',
#       'OMIM:617741',
#       'UMLS:C1426317',
#       'UniProtKB:A0A088AWN2',
#       'ENSEMBL:ENSP00000395793',
#       'ENSEMBL:ENSP00000395793.3',
#       'UniProtKB:Q5JPH5',
#       'UniProtKB:Q8TBZ3',
#       'PR:Q8TBZ3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['WDR20',
#       'WDR20 gene',
#       'A0A088AWN2_HUMAN WD repeat-containing protein 20 (trembl)',
#       'Q5JPH5_HUMAN Uncharacterized protein DKFZp686P0251 (trembl)',
#       'WDR20_HUMAN WD repeat-containing protein 20 (sprot)',
#       'WD repeat-containing protein 20 (human)']}]},
#   'NCBIGene:9779': {'categories': ['biolink:Gene'],
#    'name': 'TBC1D5',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:9779',
#       'ENSEMBL:ENSG00000131374',
#       'HGNC:19166',
#       'OMIM:615740',
#       'UMLS:C1426057',
#       'UniProtKB:B9A6K1',
#       'UniProtKB:Q92609',
#       'PR:Q92609']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TBC1D5',
#       'TBC1D5 gene',
#       'B9A6K1_HUMAN TBC1 domain family, member 5 (trembl)',
#       'TBCD5_HUMAN TBC1 domain family member 5 (sprot)',
#       'TBC1 domain family member 5 (human)']}]},
#   'NCBIGene:85461': {'categories': ['biolink:Gene'],
#    'name': 'TANC1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:85461',
#       'ENSEMBL:ENSG00000115183',
#       'HGNC:29364',
#       'OMIM:611397',
#       'UMLS:C1823226',
#       'UniProtKB:B9EK39',
#       'UniProtKB:Q9C0D5',
#       'PR:Q9C0D5']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TANC1',
#       'TANC1 gene',
#       'B9EK39_HUMAN TANC1 protein (trembl)',
#       'TANC1_HUMAN Protein TANC1 (sprot)',
#       'protein TANC1 (human)']}]},
#   'NCBIGene:10160': {'categories': ['biolink:Gene'],
#    'name': 'FARP1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10160',
#       'ENSEMBL:ENSG00000152767',
#       'HGNC:3591',
#       'OMIM:602654',
#       'UMLS:C1414533',
#       'UniProtKB:A0A2X0TVY0',
#       'UniProtKB:C9JME2',
#       'ENSEMBL:ENSP00000471242',
#       'ENSEMBL:ENSP00000471242.1',
#       'ENSEMBL:ENSP00000486285',
#       'ENSEMBL:ENSP00000486285.1',
#       'UniProtKB:Q9Y4F1',
#       'PR:Q9Y4F1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['FARP1',
#       'FARP1 gene',
#       'A0A2X0TVY0_HUMAN FARP1 (Fragment) (trembl)',
#       'C9JME2_HUMAN FERM, ARHGEF and pleckstrin domain-containing protein 1 (trembl)',
#       'FARP1_HUMAN FERM, ARHGEF and pleckstrin domain-containing protein 1 (sprot)',
#       'FERM, ARHGEF and pleckstrin domain-containing protein 1 (human)']}]},
#   'NCBIGene:120': {'categories': ['biolink:Gene'],
#    'name': 'ADD3',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:120',
#       'ENSEMBL:ENSG00000148700',
#       'HGNC:245',
#       'OMIM:601568',
#       'UMLS:C1412232',
#       'UniProtKB:Q53FL4',
#       'UniProtKB:Q59EK1',
#       'UniProtKB:Q5VU08',
#       'UniProtKB:Q9UEY8',
#       'PR:Q9UEY8',
#       'UMLS:C0531011']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['ADD3',
#       'ADD3 gene',
#       'Q53FL4_HUMAN Adducin 3 isoform a variant (Fragment) (trembl)',
#       'Q59EK1_HUMAN Adducin 3 isoform a variant (Fragment) (trembl)',
#       'Q5VU08_HUMAN Adducin 3 (Gamma), isoform CRA_a (trembl)',
#       'ADDG_HUMAN Gamma-adducin (sprot)',
#       'gamma-adducin (human)',
#       'ADD3 protein, human']}]},
#   'NCBIGene:285282': {'categories': ['biolink:Gene'],
#    'name': 'RABL3',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:285282',
#       'ENSEMBL:ENSG00000144840',
#       'HGNC:18072',
#       'OMIM:618542',
#       'UMLS:C1425283',
#       'UniProtKB:Q5HYI8',
#       'PR:Q5HYI8',
#       'ENSEMBL:ENSP00000273375',
#       'ENSEMBL:ENSP00000273375.4',
#       'UMLS:C5401454']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RABL3',
#       'RABL3 gene',
#       'RABL3_HUMAN Rab-like protein 3 (sprot)',
#       'Rab-like protein 3 (human)',
#       'Rab-Like Protein 3']}]},
#   'NCBIGene:9076': {'categories': ['biolink:Gene'],
#    'name': 'CLDN1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:9076',
#       'ENSEMBL:ENSG00000163347',
#       'HGNC:2032',
#       'OMIM:603718',
#       'UMLS:C1413460',
#       'UniProtKB:A5JSJ9',
#       'UniProtKB:O95832',
#       'PR:O95832',
#       'ENSEMBL:ENSP00000295522',
#       'ENSEMBL:ENSP00000295522.3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['CLDN1',
#       'CLDN1 gene',
#       'A5JSJ9_HUMAN Claudin (trembl)',
#       'CLD1_HUMAN Claudin-1 (sprot)',
#       'claudin-1 (human)']}]},
#   'NCBIGene:200734': {'categories': ['biolink:Gene'],
#    'name': 'SPRED2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:200734',
#       'ENSEMBL:ENSG00000198369',
#       'HGNC:17722',
#       'OMIM:609292',
#       'UMLS:C1425048',
#       'UniProtKB:B3KPL5',
#       'UniProtKB:Q7Z698',
#       'PR:Q7Z698',
#       'UMLS:C1569473']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SPRED2',
#       'SPRED2 gene',
#       'B3KPL5_HUMAN cDNA FLJ31917 fis, clone NT2RP7004925, highly similar to Sprouty-related, EVH1 domain-containing protein 2 (trembl)',
#       'SPRE2_HUMAN Sprouty-related, EVH1 domain-containing protein 2 (sprot)',
#       'sprouty-related, EVH1 domain-containing protein 2 (human)',
#       'SPRED2 protein, human']}]},
#   'NCBIGene:26499': {'categories': ['biolink:Gene'],
#    'name': 'PLEK2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:26499',
#       'ENSEMBL:ENSG00000100558',
#       'HGNC:19238',
#       'OMIM:608007',
#       'UMLS:C1426105',
#       'UniProtKB:Q9NYT0',
#       'PR:Q9NYT0',
#       'ENSEMBL:ENSP00000216446',
#       'ENSEMBL:ENSP00000216446.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PLEK2',
#       'PLEK2 gene',
#       'PLEK2_HUMAN Pleckstrin-2 (sprot)',
#       'pleckstrin-2 (human)']}]},
#   'NCBIGene:196527': {'categories': ['biolink:Gene'],
#    'name': 'ANO6',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:196527',
#       'ENSEMBL:ENSG00000177119',
#       'HGNC:25240',
#       'OMIM:608663',
#       'UMLS:C1428459',
#       'UniProtKB:A0A7P0TBC5',
#       'ENSEMBL:ENSP00000506600',
#       'ENSEMBL:ENSP00000506600.1',
#       'UniProtKB:B3KX12',
#       'UniProtKB:Q4KMQ2',
#       'PR:Q4KMQ2',
#       'UMLS:C2974729']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['ANO6',
#       'ANO6 gene',
#       'A0A7P0TBC5_HUMAN Anoctamin (trembl)',
#       'B3KX12_HUMAN Anoctamin (trembl)',
#       'ANO6_HUMAN Anoctamin-6 (sprot)',
#       'anoctamin-6 (human)',
#       'ANO6 protein, human']}]},
#   'NCBIGene:79834': {'categories': ['biolink:Gene'],
#    'name': 'PEAK1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:79834',
#       'ENSEMBL:ENSG00000173517',
#       'HGNC:29431',
#       'OMIM:614248',
#       'UMLS:C3280264',
#       'UniProtKB:Q9H792',
#       'PR:Q9H792',
#       'ENSEMBL:ENSP00000309230',
#       'ENSEMBL:ENSP00000309230.4',
#       'ENSEMBL:ENSP00000452796',
#       'ENSEMBL:ENSP00000452796.2',
#       'ENSEMBL:ENSP00000507603',
#       'ENSEMBL:ENSP00000507603.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PEAK1',
#       'PEAK1 gene',
#       'PEAK1_HUMAN Inactive tyrosine-protein kinase PEAK1 (sprot)',
#       'inactive tyrosine-protein kinase PEAK1 (human)']}]},
#   'NCBIGene:56704': {'categories': ['biolink:Gene'],
#    'name': 'JPH1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:56704',
#       'ENSEMBL:ENSG00000104369',
#       'HGNC:14201',
#       'OMIM:605266',
#       'UMLS:C1422482',
#       'UniProtKB:Q7Z682',
#       'UniProtKB:Q86VR1',
#       'UniProtKB:Q9HDC5',
#       'PR:Q9HDC5',
#       'ENSEMBL:ENSP00000344488',
#       'ENSEMBL:ENSP00000344488.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['JPH1',
#       'JPH1 gene',
#       'Q7Z682_HUMAN Uncharacterized protein DKFZp779I2251 (Fragment) (trembl)',
#       'Q86VR1_HUMAN JPH1 protein (Fragment) (trembl)',
#       'JPH1_HUMAN Junctophilin-1 (sprot)',
#       'junctophilin-1 (human)']}]},
#   'NCBIGene:4354': {'categories': ['biolink:Gene'],
#    'name': 'MPP1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:4354',
#       'ENSEMBL:ENSG00000130830',
#       'HGNC:7219',
#       'OMIM:305360',
#       'UMLS:C1334525',
#       'UniProtKB:B4E325',
#       'UniProtKB:Q00013',
#       'PR:Q00013',
#       'UMLS:C1335296']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MPP1',
#       'MPP1 gene',
#       'B4E325_HUMAN 55 kDa erythrocyte membrane protein (trembl)',
#       'EM55_HUMAN 55 kDa erythrocyte membrane protein (sprot)',
#       '55 kDa erythrocyte membrane protein (human)',
#       'MPP1 protein, human']}]},
#   'NCBIGene:4162': {'categories': ['biolink:Gene'],
#    'name': 'MCAM',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:4162',
#       'ENSEMBL:ENSG00000076706',
#       'HGNC:6934',
#       'OMIM:155735',
#       'UMLS:C1334487',
#       'UniProtKB:A0A024R3I5',
#       'UniProtKB:P43121',
#       'PR:P43121',
#       'UMLS:C0386212']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MCAM',
#       'MCAM gene',
#       'A0A024R3I5_HUMAN Melanoma cell adhesion molecule, isoform CRA_a (trembl)',
#       'MUC18_HUMAN Cell surface glycoprotein MUC18 (sprot)',
#       'cell surface glycoprotein MUC18 (human)',
#       'MCAM protein, human']}]},
#   'NCBIGene:22874': {'categories': ['biolink:Gene'],
#    'name': 'PLEKHA6',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:22874',
#       'ENSEMBL:ENSG00000143850',
#       'HGNC:17053',
#       'OMIM:607771',
#       'UMLS:C1538669',
#       'UniProtKB:Q9Y2H5',
#       'PR:Q9Y2H5',
#       'ENSEMBL:ENSP00000272203',
#       'ENSEMBL:ENSP00000272203.2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PLEKHA6',
#       'PLEKHA6 gene',
#       'PKHA6_HUMAN Pleckstrin homology domain-containing family A member 6 (sprot)',
#       'pleckstrin homology domain-containing family A member 6 (human)']}]},
#   'NCBIGene:143098': {'categories': ['biolink:Gene'],
#    'name': 'MPP7',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:143098',
#       'ENSEMBL:ENSG00000150054',
#       'HGNC:26542',
#       'OMIM:610973',
#       'UMLS:C1428604',
#       'UniProtKB:Q5T2T1',
#       'PR:Q5T2T1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MPP7',
#       'MPP7 gene',
#       'MPP7_HUMAN MAGUK p55 subfamily member 7 (sprot)',
#       'MAGUK p55 subfamily member 7 (human)']}]},
#   'NCBIGene:80224': {'categories': ['biolink:Gene'],
#    'name': 'NUBPL',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:80224',
#       'ENSEMBL:ENSG00000151413',
#       'HGNC:20278',
#       'OMIM:613621',
#       'UMLS:C1538495',
#       'UniProtKB:B3KSK2',
#       'UniProtKB:B4DWB0',
#       'UniProtKB:Q8TB37',
#       'PR:Q8TB37',
#       'UniProtKB:X5D2R5']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NUBPL',
#       'NUBPL gene',
#       'B3KSK2_HUMAN cDNA FLJ36470 fis, clone THYMU2015918, highly similar to Nucleotide-binding protein-like (trembl)',
#       'B4DWB0_HUMAN cDNA FLJ59772, highly similar to Nucleotide-binding protein-like (trembl)',
#       'NUBPL_HUMAN Iron-sulfur protein NUBPL (sprot)',
#       'iron-sulfur protein NUBPL (human)',
#       'X5D2R5_HUMAN Nucleotide binding protein-like isoform A (Fragment) (trembl)']}]},
#   'NCBIGene:285761': {'categories': ['biolink:Gene'],
#    'name': 'DCBLD1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:285761',
#       'ENSEMBL:ENSG00000164465',
#       'HGNC:21479',
#       'UMLS:C1427570',
#       'UniProtKB:Q8N8Z6',
#       'PR:Q8N8Z6']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['DCBLD1',
#       'DCBLD1 gene',
#       'DCBD1_HUMAN Discoidin, CUB and LCCL domain-containing protein 1 (sprot)',
#       'discoidin, CUB and LCCL domain-containing protein 1 (human)']}]},
#   'NCBIGene:6533': {'categories': ['biolink:Gene'],
#    'name': 'SLC6A6',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6533',
#       'ENSEMBL:ENSG00000131389',
#       'HGNC:11052',
#       'OMIM:186854',
#       'UMLS:C1420216',
#       'UniProtKB:A0A087WY96',
#       'ENSEMBL:ENSP00000481625',
#       'ENSEMBL:ENSP00000481625.1',
#       'UniProtKB:B4E140',
#       'UniProtKB:P31641',
#       'PR:P31641',
#       'UniProtKB:Q59GD7']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLC6A6',
#       'SLC6A6 gene',
#       'A0A087WY96_HUMAN Transporter (trembl)',
#       'B4E140_HUMAN Transporter (trembl)',
#       'SC6A6_HUMAN Sodium- and chloride-dependent taurine transporter (sprot)',
#       'sodium- and chloride-dependent taurine transporter (human)',
#       'Q59GD7_HUMAN Transporter (Fragment) (trembl)']}]},
#   'NCBIGene:55218': {'categories': ['biolink:Gene'],
#    'name': 'EXD2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:55218',
#       'ENSEMBL:ENSG00000081177',
#       'HGNC:20217',
#       'OMIM:616940',
#       'UMLS:C1825073',
#       'UniProtKB:A8K948',
#       'UniProtKB:Q86TX3',
#       'UniProtKB:Q9NVH0',
#       'PR:Q9NVH0']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['EXD2',
#       'EXD2 gene',
#       'A8K948_HUMAN cDNA FLJ78298 (trembl)',
#       'Q86TX3_HUMAN Full-length cDNA clone CS0DC026YP23 of Neuroblastoma of Homo sapiens (human) (trembl)',
#       "EXD2_HUMAN Exonuclease 3'-5' domain-containing protein 2 (sprot)",
#       "exonuclease 3'-5' domain-containing protein 2 (human)"]}]},
#   'NCBIGene:6564': {'categories': ['biolink:Gene'],
#    'name': 'SLC15A1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6564',
#       'ENSEMBL:ENSG00000088386',
#       'HGNC:10920',
#       'OMIM:600544',
#       'UMLS:C1420100',
#       'UniProtKB:B2CQT6',
#       'UniProtKB:P46059',
#       'PR:P46059',
#       'ENSEMBL:ENSP00000365686',
#       'ENSEMBL:ENSP00000365686.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLC15A1',
#       'SLC15A1 gene',
#       'B2CQT6_HUMAN Solute carrier family 15 oligopeptide transporter member 1 (trembl)',
#       'S15A1_HUMAN Solute carrier family 15 member 1 (sprot)',
#       'solute carrier family 15 member 1 (human)']}]},
#   'NCBIGene:23705': {'categories': ['biolink:Gene'],
#    'name': 'CADM1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23705',
#       'ENSEMBL:ENSG00000182985',
#       'HGNC:5951',
#       'OMIM:605686',
#       'UMLS:C1416373',
#       'UniProtKB:A0A4Z1',
#       'UniProtKB:Q9BY67',
#       'PR:Q9BY67',
#       'UMLS:C1309370',
#       'UniProtKB:X5D7A8',
#       'UniProtKB:X5D8W0',
#       'UniProtKB:X5DQR8',
#       'UniProtKB:X5DQS5',
#       'ENSEMBL:ENSP00000440322',
#       'ENSEMBL:ENSP00000440322.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['CADM1',
#       'CADM1 gene',
#       'A0A4Z1_HUMAN CADM1 protein (trembl)',
#       'CADM1_HUMAN Cell adhesion molecule 1 (sprot)',
#       'cell adhesion molecule 1 (human)',
#       'CADM1 protein, human',
#       'X5D7A8_HUMAN Cell adhesion molecule 1 isoform A (Fragment) (trembl)',
#       'X5D8W0_HUMAN Cell adhesion molecule 1 isoform D (Fragment) (trembl)',
#       'X5DQR8_HUMAN Cell adhesion molecule 1 isoform B (Fragment) (trembl)',
#       'X5DQS5_HUMAN Cell adhesion molecule 1 (Fragment) (trembl)']}]},
#   'NCBIGene:23767': {'categories': ['biolink:Gene'],
#    'name': 'FLRT3',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23767',
#       'ENSEMBL:ENSG00000125848',
#       'HGNC:3762',
#       'OMIM:604808',
#       'UMLS:C1333566',
#       'UniProtKB:Q9NZU0',
#       'PR:Q9NZU0',
#       'ENSEMBL:ENSP00000339912',
#       'ENSEMBL:ENSP00000339912.4',
#       'ENSEMBL:ENSP00000367292',
#       'ENSEMBL:ENSP00000367292.3',
#       'UMLS:C1309390']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['FLRT3',
#       'FLRT3 gene',
#       'FLRT3_HUMAN Leucine-rich repeat transmembrane protein FLRT3 (sprot)',
#       'leucine-rich repeat transmembrane protein FLRT3 (human)',
#       'FLRT3 protein, human']}]},
#   'NCBIGene:1525': {'categories': ['biolink:Gene'],
#    'name': 'CXADR',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:1525',
#       'ENSEMBL:ENSG00000154639',
#       'HGNC:2559',
#       'OMIM:602621',
#       'UMLS:C1413828',
#       'UniProtKB:P78310',
#       'PR:P78310',
#       'UMLS:C3539542']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['CXADR',
#       'CXADR gene',
#       'CXAR_HUMAN Coxsackievirus and adenovirus receptor (sprot)',
#       'coxsackievirus and adenovirus receptor (human)',
#       'Coxsackievirus and Adenovirus Receptor, human']}]},
#   'NCBIGene:147007': {'categories': ['biolink:Gene'],
#    'name': 'TMEM199',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:147007',
#       'ENSEMBL:ENSG00000244045',
#       'HGNC:18085',
#       'OMIM:616815',
#       'UMLS:C1425293',
#       'UniProtKB:Q8N511',
#       'PR:Q8N511',
#       'ENSEMBL:ENSP00000292114',
#       'ENSEMBL:ENSP00000292114.3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TMEM199',
#       'TMEM199 gene',
#       'TM199_HUMAN Transmembrane protein 199 (sprot)',
#       'transmembrane protein 199 (human)']}]},
#   'NCBIGene:57514': {'categories': ['biolink:Gene'],
#    'name': 'ARHGAP31',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:57514',
#       'ENSEMBL:ENSG00000031081',
#       'HGNC:29216',
#       'OMIM:610911',
#       'UMLS:C1970471',
#       'UniProtKB:Q2M1Z3',
#       'PR:Q2M1Z3',
#       'ENSEMBL:ENSP00000264245',
#       'ENSEMBL:ENSP00000264245.4',
#       'UMLS:C1742421']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['ARHGAP31',
#       'ARHGAP31 gene',
#       'RHG31_HUMAN Rho GTPase-activating protein 31 (sprot)',
#       'Rho GTPase-activating protein 31 (human)',
#       'ARHGAP31 protein, human']}]},
#   'NCBIGene:57609': {'categories': ['biolink:Gene'],
#    'name': 'DIP2B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:57609',
#       'ENSEMBL:ENSG00000066084',
#       'HGNC:29284',
#       'OMIM:611379',
#       'UMLS:C1824938',
#       'UniProtKB:Q7Z3H2',
#       'UniProtKB:Q96IB4',
#       'UniProtKB:Q9P265',
#       'PR:Q9P265',
#       'ENSEMBL:ENSP00000301180',
#       'ENSEMBL:ENSP00000301180.5']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['DIP2B',
#       'DIP2B gene',
#       'Q7Z3H2_HUMAN Uncharacterized protein DKFZp686M1483 (Fragment) (trembl)',
#       'Q96IB4_HUMAN DIP2B protein (Fragment) (trembl)',
#       'DIP2B_HUMAN Disco-interacting protein 2 homolog B (sprot)',
#       'disco-interacting protein 2 homolog B (human)']}]},
#   'NCBIGene:55246': {'categories': ['biolink:Gene'],
#    'name': 'CCDC25',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:55246',
#       'ENSEMBL:ENSG00000147419',
#       'HGNC:25591',
#       'OMIM:619100',
#       'UMLS:C1824550',
#       'UniProtKB:G3V121',
#       'ENSEMBL:ENSP00000429861',
#       'ENSEMBL:ENSP00000429861.1',
#       'UniProtKB:Q86WR0',
#       'PR:Q86WR0']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['CCDC25',
#       'CCDC25 gene',
#       'G3V121_HUMAN Coiled-coil domain-containing protein 25 (trembl)',
#       'CCD25_HUMAN Coiled-coil domain-containing protein 25 (sprot)',
#       'coiled-coil domain-containing protein 25 (human)']}]},
#   'NCBIGene:57048': {'categories': ['biolink:Gene'],
#    'name': 'PLSCR3',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:57048',
#       'ENSEMBL:ENSG00000187838',
#       'HGNC:16495',
#       'OMIM:607611',
#       'UMLS:C1424327',
#       'UniProtKB:Q9NRY6',
#       'PR:Q9NRY6',
#       'ENSEMBL:ENSP00000316021',
#       'ENSEMBL:ENSP00000316021.11',
#       'ENSEMBL:ENSP00000459019',
#       'ENSEMBL:ENSP00000459019.1',
#       'ENSEMBL:ENSP00000459419',
#       'ENSEMBL:ENSP00000459419.1',
#       'ENSEMBL:ENSP00000483743',
#       'ENSEMBL:ENSP00000483743.2',
#       'ENSEMBL:ENSP00000491350',
#       'ENSEMBL:ENSP00000491350.1',
#       'ENSEMBL:ENSP00000491393',
#       'ENSEMBL:ENSP00000491393.1',
#       'ENSEMBL:ENSP00000492026',
#       'ENSEMBL:ENSP00000492026.2',
#       'ENSEMBL:ENSP00000492083',
#       'ENSEMBL:ENSP00000492083.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PLSCR3',
#       'PLSCR3 gene',
#       'PLS3_HUMAN Phospholipid scramblase 3 (sprot)',
#       'phospholipid scramblase 3 (human)']}]},
#   'NCBIGene:9498': {'categories': ['biolink:Gene'],
#    'name': 'SLC4A8',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:9498',
#       'ENSEMBL:ENSG00000050438',
#       'HGNC:11034',
#       'OMIM:605024',
#       'UMLS:C1420198',
#       'UniProtKB:Q2Y0W8',
#       'PR:Q2Y0W8']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLC4A8',
#       'SLC4A8 gene',
#       'S4A8_HUMAN Electroneutral sodium bicarbonate exchanger 1 (sprot)',
#       'electroneutral sodium bicarbonate exchanger 1 (human)']}]},
#   'NCBIGene:8573': {'categories': ['biolink:Gene'],
#    'name': 'CASK',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:8573',
#       'ENSEMBL:ENSG00000147044',
#       'HGNC:1497',
#       'OMIM:300172',
# ...
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '8f9a1809683b15261f914d8b52624a2e': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:8673',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '9aa9fbd7f3bb5cf5402fc8036f8c191e': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:2885',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '469eb0a73058fd1b12d950472e25efa3': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:254102',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'f51508f6a32c216e2b619b823cd1cad4': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:81704',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '16a2695f98d25babd54c51d4c4e43afb': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:10542',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'e230e10bb5ca148907591cfac28b21ba': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:11187',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'a7b4a0683feb5430fc54d24978c30bd2': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:79084',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'a5abd2990c8cce57959ce6a1cd436f37': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:9846',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'a4d64beebb902a4de18d97691a139e65': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:58533',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'd3912d80dca065a7a8fdc8762d0303d6': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:3936',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '159d3bd30e13529fa4db81864383d8bb': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:121355',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'f9631879306d8af0bcd59bae3663fbc5': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:6059',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '1bb2eb3fceb832712b7d33557b5889ff': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:6708',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '84f9aed91b9405ca2eb26adc03764750': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:64092',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '305fa4beed6db61c12ba0452b359e801': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:695',
#    'attributes': [{'attribute_type_id': 'biolink:publications',
#      'value': 'PMID:30442766'},
#     {'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:biogrid'}],
#      'value': 'infores:biogrid'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:biogrid',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biogrid']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   ...}}

# %%
#Example: which drugs shows sensitivity with KRAS (NCBIGene:3845) altered?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids":["NCBIGene:3845"],
                    "categories":["biolink:Gene"]
                },
                "n1": {

                    "categories":["biolink:SmallMolecule"]
               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:associated_with_sensitivity_to"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL,json=query_json)
result = response.json()["message"]

# %%
print(len(result['knowledge_graph']['nodes']))
result['knowledge_graph']
# Out:
# 11
# {'nodes': {'NCBIGene:3845': {'categories': ['biolink:Gene'],
#    'name': 'KRAS',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3845',
#       'ENSEMBL:ENSG00000133703',
#       'HGNC:6407',
#       'OMIM:190070',
#       'UMLS:C1537502',
#       'UniProtKB:A0A024RAV5',
#       'UniProtKB:I1SRC5',
#       'UniProtKB:L7RSL8',
#       'UniProtKB:P01116',
#       'PR:P01116',
#       'UMLS:C0763464']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['KRAS',
#       'KRAS gene',
#       'A0A024RAV5_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog, isoform CRA_b (trembl)',
#       'I1SRC5_HUMAN UBE2L3/KRAS fusion protein (trembl)',
#       'L7RSL8_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog (trembl)',
#       'RASK_HUMAN GTPase KRas (sprot)',
#       'GTPase KRas (human)',
#       'KRAS protein, human']}]},
#   'PUBCHEM.COMPOUND:135400873': {'categories': ['biolink:SmallMolecule'],
#    'name': '(5Z)-5-(quinolin-6-ylmethylidene)-2-[(thiophen-2-ylmethyl)amino]-1,3-thiazol-4(5H)-one',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:135400873',
#       'CHEMBL.COMPOUND:CHEMBL393929',
#       'MESH:C512984',
#       'INCHIKEY:XOLMRFUGOINFDQ-YBEGLDIGSA-N',
#       'UMLS:C1743488']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['(5Z)-5-(quinolin-6-ylmethylidene)-2-[(thiophen-2-ylmethyl)amino]-1,3-thiazol-4(5H)-one',
#       'CHEMBL393929',
#       'RO 3306']}]},
#   'PUBCHEM.COMPOUND:46844147': {'categories': ['biolink:SmallMolecule'],
#    'name': 'Erk5-IN-1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:46844147',
#       'CHEMBL.COMPOUND:CHEMBL1673039',
#       'CHEBI:91375',
#       'CAS:1234479-76-5',
#       'INCHIKEY:DDTPGANIPBKTNU-UHFFFAOYSA-N']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Erk5-IN-1',
#       'CHEMBL1673039',
#       '2-[2-methoxy-4-(4-methyl-1-piperazinyl)anilino]-5,11-dimethyl-6-pyrimido[4,5-b][1,4]benzodiazepinone']}]},
#   'PUBCHEM.COMPOUND:5284616': {'categories': ['biolink:SmallMolecule'],
#    'name': 'Sirolimus',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:5284616',
#       'CHEMBL.COMPOUND:CHEMBL413',
#       'UNII:W36ZG6FT64',
#       'CHEBI:9168',
#       'DRUGBANK:DB00877',
#       'MESH:D020123',
#       'CAS:53123-88-9',
#       'DrugCentral:2446',
#       'GTOPDB:6031',
#       'KEGG.COMPOUND:C07909',
#       'INCHIKEY:QFJCIRLUMZQUOT-HPLJOQBZSA-N',
#       'UMLS:C0072980']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Sirolimus', 'SIROLIMUS', 'sirolimus']}]},
#   'PUBCHEM.COMPOUND:11455910': {'categories': ['biolink:SmallMolecule'],
#    'name': 'N-[4-(2-tert-Butylphenylsulfonyl)phenyl]-2,3,4-trihydroxy-5-(2-isopropylbenzyl)benzamide',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:11455910',
#       'CHEMBL.COMPOUND:CHEMBL217354',
#       'UNII:FQ8NY4LUO5',
#       'CHEBI:95008',
#       'CAS:877877-35-5',
#       'INCHIKEY:PQAPVTKIEGUPRN-UHFFFAOYSA-N']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['N-[4-(2-tert-Butylphenylsulfonyl)phenyl]-2,3,4-trihydroxy-5-(2-isopropylbenzyl)benzamide',
#       'CHEMBL217354',
#       'TW-37',
#       'N-[4-(2-tert-butylphenyl)sulfonylphenyl]-2,3,4-trihydroxy-5-[(2-propan-2-ylphenyl)methyl]benzamide']}]},
#   'PUBCHEM.COMPOUND:46843772': {'categories': ['biolink:SmallMolecule'],
#    'name': '2-{[2-ethoxy-4-(4-hydroxypiperidin-1-yl)phenyl]amino}-5,11-dimethyl-5,11-dihydro-6H-pyrimido[4,5-b][1,4]benzodiazepin-6-one',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:46843772',
#       'CHEMBL.COMPOUND:CHEMBL1673046',
#       'CHEBI:60325',
#       'MESH:C568790',
#       'CAS:1234480-50-2',
#       'GTOPDB:8057',
#       'INCHIKEY:QAPAJIZPZGWAND-UHFFFAOYSA-N',
#       'UMLS:C3252765']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['2-{[2-ethoxy-4-(4-hydroxypiperidin-1-yl)phenyl]amino}-5,11-dimethyl-5,11-dihydro-6H-pyrimido[4,5-b][1,4]benzodiazepin-6-one',
#       'CHEMBL1673046',
#       'XMD8-92',
#       'XMD 8-92']}]},
#   'PUBCHEM.COMPOUND:11707110': {'categories': ['biolink:SmallMolecule'],
#    'name': 'Trametinib',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:11707110',
#       'CHEMBL.COMPOUND:CHEMBL2103875',
#       'UNII:33E86K87QN',
#       'CHEBI:75998',
#       'DRUGBANK:DB08911',
#       'MESH:C560077',
#       'CAS:871700-17-3',
#       'DrugCentral:4802',
#       'GTOPDB:6495',
#       'INCHIKEY:LIRYPHYGHXZJBZ-UHFFFAOYSA-N',
#       'UMLS:C2697961']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Trametinib', 'TRAMETINIB', 'trametinib']}]},
#   'PUBCHEM.COMPOUND:25226117': {'categories': ['biolink:SmallMolecule'],
#    'name': '1-[4-[[4-Amino-5-chloro-6-(2-propan-2-ylsulfonylanilino)-2-pyrimidinyl]amino]-3-methoxyphenyl]-4-piperidinecarboxamide',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:25226117',
#       'CHEMBL.COMPOUND:CHEMBL3392893',
#       'CHEBI:94486',
#       'CAS:1125593-85-2',
#       'INCHIKEY:IMEGLYUXMGWVQA-UHFFFAOYSA-N']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['1-[4-[[4-Amino-5-chloro-6-(2-propan-2-ylsulfonylanilino)-2-pyrimidinyl]amino]-3-methoxyphenyl]-4-piperidinecarboxamide',
#       'CHEMBL3392893',
#       '1-[4-[[4-amino-5-chloro-6-(2-propan-2-ylsulfonylanilino)-2-pyrimidinyl]amino]-3-methoxyphenyl]-4-piperidinecarboxamide']}]},
#   'PUBCHEM.COMPOUND:25227436': {'categories': ['biolink:SmallMolecule'],
#    'name': 'Capivasertib',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:25227436',
#       'CHEMBL.COMPOUND:CHEMBL2325741',
#       'UNII:WFR23M21IE',
#       'DRUGBANK:DB12218',
#       'MESH:C575618',
#       'CAS:1143532-39-1',
#       'GTOPDB:7709',
#       'INCHIKEY:JDUBGYFRJFOXQC-KRWDZBQOSA-N',
#       'UMLS:C4682387']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Capivasertib', 'CAPIVASERTIB', 'capivasertib']}]},
#   'PUBCHEM.COMPOUND:71748056': {'categories': ['biolink:SmallMolecule'],
#    'name': '9-(1-Methyl-4-pyrazolyl)-1-[1-(1-oxoprop-2-enyl)-2,3-dihydroindol-6-yl]-2-benzo[h][1,6]naphthyridinone',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:71748056',
#       'CHEMBL.COMPOUND:CHEMBL4077064',
#       'CHEBI:94815',
#       'CAS:1469988-75-7',
#       'INCHIKEY:RTRNJQOBEOISFQ-UHFFFAOYSA-N']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['9-(1-Methyl-4-pyrazolyl)-1-[1-(1-oxoprop-2-enyl)-2,3-dihydroindol-6-yl]-2-benzo[h][1,6]naphthyridinone',
#       'CHEMBL4077064',
#       '9-(1-methyl-4-pyrazolyl)-1-[1-(1-oxoprop-2-enyl)-2,3-dihydroindol-6-yl]-2-benzo[h][1,6]naphthyridinone']}]},
#   'PUBCHEM.COMPOUND:3062316': {'categories': ['biolink:SmallMolecule'],
#    'name': 'Dasatinib',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:3062316',
#       'CHEMBL.COMPOUND:CHEMBL1421',
#       'UNII:X78UG0A0RN',
#       'CHEBI:49375',
#       'DRUGBANK:DB01254',
#       'CAS:302962-49-8',
#       'DrugCentral:785',
#       'GTOPDB:5678',
#       'HMDB:HMDB0015384',
#       'INCHIKEY:ZBNZXTGUTAYRHI-UHFFFAOYSA-N',
#       'UMLS:C1455147',
#       'UMLS:C2699562']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Dasatinib',
#       'DASATINIB',
#       'DASATINIB ANHYDROUS',
#       'dasatinib (anhydrous)',
#       'dasatinib',
#       'dasatinib anhydrous']}]}},
#  'edges': {'6c05513229d3e26fcf05bca6c9aac160': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:135400873',
#    'attributes': [{'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 'Spearman Correlation Test was used to extract the association',
#        'value': 'NCIT:C53249',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0097595359599169,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 11},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Gene expression'},
#     {'attribute_type_id': 'biolink:object_aspect_qualifier', 'value': 'AUC'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0005005'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gdsc', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '85cf8421925542909bcc20d17894bb74': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:46844147',
#    'attributes': [{'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 'Spearman Correlation Test was used to extract the association',
#        'value': 'NCIT:C53249',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.002445197640446,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 14},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Gene expression'},
#     {'attribute_type_id': 'biolink:object_aspect_qualifier', 'value': 'AUC'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0007256'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gdsc', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '298807ccc8503a8864bf80d9d66baabc': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:5284616',
#    'attributes': [{'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 'Spearman Correlation Test was used to extract the association',
#        'value': 'NCIT:C53249',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0045477337439671,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 13},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Gene expression'},
#     {'attribute_type_id': 'biolink:object_aspect_qualifier', 'value': 'AUC'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0006143'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gdsc', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '75eb4a95ab74679a90d786dba01578de': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:11455910',
#    'attributes': [{'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 'Spearman Correlation Test was used to extract the association',
#        'value': 'NCIT:C53249',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0052129065583094,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 29},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Gene expression'},
#     {'attribute_type_id': 'biolink:object_aspect_qualifier', 'value': 'AUC'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0005005'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gdsc', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '35c4ccce66b69e12e6dd9d8583718c98': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:46843772',
#    'attributes': [{'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 'Spearman Correlation Test was used to extract the association',
#        'value': 'NCIT:C53249',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0046770192376274,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 23},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Gene expression'},
#     {'attribute_type_id': 'biolink:object_aspect_qualifier', 'value': 'AUC'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0005005'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gdsc', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'eb6b6667258e5ba79f1079fc9a73b0dd': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:11707110',
#    'attributes': [{'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 't-test was used to compute the p-value for the association',
#        'value': 'NCIT:C53231',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0001374022258134,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 59},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Genetic variants'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0005061'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gdsc', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'bf55c24d8ddaa9de56bed45d95a597b9': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:25226117',
#    'attributes': [{'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 't-test was used to compute the p-value for the association',
#        'value': 'NCIT:C53231',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0244706215734285,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 31},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Genetic variants'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0006046'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gdsc', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '8fb8ccdb0a4d69d8a1873f33ea5ac94f': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:25227436',
#    'attributes': [{'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 't-test was used to compute the p-value for the association',
#        'value': 'NCIT:C53231',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0030981662650149,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 31},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Genetic variants'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0006046'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gdsc', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '406f9563b274e950f2db239f752d79b4': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:71748056',
#    'attributes': [{'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 't-test was used to compute the p-value for the association',
#        'value': 'NCIT:C53231',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.0129453501806996,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 31},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Genetic variants'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0006046'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gdsc', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'c6fcd1a9bb98d66b16b82010e5792e7e': {'predicate': 'biolink:associated_with_sensitivity_to',
#    'subject': 'NCBIGene:3845',
#    'object': 'PUBCHEM.COMPOUND:3062316',
#    'attributes': [{'attribute_type_id': 'EDAM:data_0951',
#      'attributes': [{'attribute_type_id': 'NCIT:C53236',
#        'description': 't-test was used to compute the p-value for the association',
#        'value': 'NCIT:C53231',
#        'value_type_id': 'biolink:id'}],
#      'value': 0.003351248050487,
#      'value_type_id': 'EDAM:data_1669'},
#     {'attribute_type_id': 'biolink:supporting_study_size', 'value': 31},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GDSC'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:27397505'},
#     {'attribute_type_id': 'biolink:subject_aspect_qualifier',
#      'value': 'Genetic variants'},
#     {'attribute_source': 'infores:biothings-multiomics-biggim-drugresponse',
#      'attribute_type_id': 'biolink:context_qualifier',
#      'value': 'MONDO:0006046'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gdsc', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]}}}

# %%
# Example: what drugs or small molecules that target BCL2 (NCBIGene: 596)?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "categories":["biolink:SmallMolecule"]
                },
                "n1": {
                    "ids":["NCBIGene:596"],
                    "categories":["biolink:Gene"]
                    
               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:physically_interacts_with"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL,json=query_json)
result = response.json()["message"]

# %%
print(len(result['knowledge_graph']['nodes']))
result['knowledge_graph']
# Out:
# 7
# {'nodes': {'NCBIGene:596': {'categories': ['biolink:Gene'],
#    'name': 'BCL2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:596',
#       'ENSEMBL:ENSG00000171791',
#       'HGNC:990',
#       'OMIM:151430',
#       'UMLS:C0376515',
#       'UniProtKB:A0A024R2B3',
#       'UniProtKB:A0A024R2C4',
#       'UniProtKB:A0A7I2V3S7',
#       'ENSEMBL:ENSP00000503628',
#       'ENSEMBL:ENSP00000503628.1',
#       'UniProtKB:P10415',
#       'PR:P10415',
#       'UMLS:C4042483']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['BCL2',
#       'BCL2 gene',
#       'A0A024R2B3_HUMAN Apoptosis regulator Bcl-2 (trembl)',
#       'A0A024R2C4_HUMAN Apoptosis regulator Bcl-2 (trembl)',
#       'A0A7I2V3S7_HUMAN Apoptosis regulator Bcl-2 (trembl)',
#       'BCL2_HUMAN Apoptosis regulator Bcl-2 (sprot)',
#       'apoptosis regulator Bcl-2 (human)',
#       'BCL2 protein, human']}]},
#   'PUBCHEM.COMPOUND:454878': {'categories': ['biolink:SmallMolecule'],
#    'name': 'Apogossypol',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:454878',
#       'CHEMBL.COMPOUND:CHEMBL551288',
#       'MESH:C492806',
#       'INCHIKEY:PBJKWGWHZVXBGU-UHFFFAOYSA-N',
#       'UMLS:C1528430']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Apogossypol', 'APOGOSSYPOL', 'apogossypol']}]},
#   'PUBCHEM.COMPOUND:3503': {'categories': ['biolink:SmallMolecule'],
#    'name': 'Gossypol',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:3503',
#       'CHEMBL.COMPOUND:CHEMBL51483',
#       'UNII:8DY2X8LXW4',
#       'UNII:KAV15B369O',
#       'UNII:XNA7DR63CQ',
#       'DRUGBANK:DB13044',
#       'MESH:D006072',
#       'CAS:20300-26-9',
#       'DrugCentral:1328',
#       'GTOPDB:4204',
#       'HMDB:HMDB0040723',
#       'KEGG.COMPOUND:C07667',
#       'INCHIKEY:QBKSWRVVCFFDOT-UHFFFAOYSA-N',
#       'UMLS:C0018096']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Gossypol',
#       'GOSSYPOL',
#       'GOSSYPOL, (R)-',
#       'GOSSYPOL, (S)-',
#       'gossypol',
#       '(-)-Gossypol']}]},
#   'PUBCHEM.COMPOUND:11228183': {'categories': ['biolink:SmallMolecule'],
#    'name': 'Abt-737',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:11228183',
#       'CHEMBL.COMPOUND:CHEMBL376408',
#       'UNII:Z5NFR173NV',
#       'CHEBI:47575',
#       'MESH:C501332',
#       'CAS:852808-04-9',
#       'GTOPDB:8320',
#       'INCHIKEY:HPLNQCPCUACXLM-PGUFJCEWSA-N',
#       'UMLS:C1570187']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Abt-737', 'ABT 737', 'ABT-737']}]},
#   'PUBCHEM.COMPOUND:2710': {'categories': ['biolink:SmallMolecule'],
#    'name': 'Chlorcyclizine',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:2710',
#       'CHEMBL.COMPOUND:CHEMBL22150',
#       'UNII:M26C4IP44P',
#       'CHEBI:94402',
#       'DRUGBANK:DB08936',
#       'MESH:C084597',
#       'CAS:82-93-9',
#       'DrugCentral:593',
#       'HMDB:HMDB0240224',
#       'INCHIKEY:WFNAKBGANONZEQ-UHFFFAOYSA-N',
#       'UMLS:C0008183']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Chlorcyclizine',
#       'CHLORCYCLIZINE',
#       '1-[(4-chlorophenyl)-phenylmethyl]-4-methylpiperazine',
#       'chlorcyclizine']}]},
#   'PUBCHEM.COMPOUND:49846579': {'categories': ['biolink:SmallMolecule'],
#    'name': 'Venetoclax',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:49846579',
#       'CHEMBL.COMPOUND:CHEMBL3137309',
#       'UNII:N54AIC43PW',
#       'CHEBI:133021',
#       'DRUGBANK:DB11581',
#       'MESH:C579720',
#       'CAS:1257044-40-8',
#       'DrugCentral:5133',
#       'GTOPDB:8318',
#       'INCHIKEY:LQBVNQSMGBZMKD-UHFFFAOYSA-N',
#       'UMLS:C4079830']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['Venetoclax', 'VENETOCLAX', 'venetoclax']}]},
#   'PUBCHEM.COMPOUND:11404337': {'categories': ['biolink:SmallMolecule'],
#    'name': 'Obatoclax',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['PUBCHEM.COMPOUND:11404337',
#       'INCHIKEY:CVCLJVVBHYOXDC-IAZSKANUSA-N']},
#     {'attribute_type_id': 'biolink:synonym', 'value': ['Obatoclax']}]}},
#  'edges': {'0e1167b374501d027ceb90c6bb57b25d': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:454878',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:ttd'}],
#      'value': 'infores:ttd'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:ttd',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:ttd']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'd06de37ea2107e5390950a12ced2eac3': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:3503',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:drugcentral'}],
#      'value': 'infores:drugcentral'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:ttd',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:ttd', 'infores:drugcentral']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']},
#     {'resource_id': 'infores:drugcentral',
#      'resource_role': 'primary_knowledge_source'}]},
#   'b159a5aebecf8422f4436aa9d3602b72': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:11228183',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:ttd'}],
#      'value': 'infores:ttd'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:ttd',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:ttd']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'decc6f2a06cde6693bf53a8797855ead': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:2710',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:drugcentral'}],
#      'value': 'infores:drugcentral'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:drugcentral',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:drugcentral']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'c326da9c79d204d816053f95b1d470a2': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:49846579',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:drugcentral'}],
#      'value': 'infores:drugcentral'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:drugcentral',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:drugcentral']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '81caf80b13672b2a53386557ce4304fb': {'predicate': 'biolink:physically_interacts_with',
#    'subject': 'PUBCHEM.COMPOUND:11404337',
#    'object': 'NCBIGene:596',
#    'attributes': [{'attribute_type_id': 'biolink:primary_knowledge_source',
#      'attributes': [{'attribute_type_id': 'biolink:source_infores',
#        'value': 'infores:ttd'}],
#      'value': 'infores:ttd'},
#     {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#      'value': 'infores:biothings-multiomics-biggim-drugresponse'}],
#    'sources': [{'resource_id': 'infores:ttd',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:ttd']},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]}}}

# %%
# Example: what are the potential biomarkser for liver cancer (MONDO:0007256)?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids":["MONDO:0007256"],
                    "categories":["biolink:Disease"]
                },
                "n1": {
                    "categories":["biolink:Gene"]
                    
               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:has_biomarker"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL,json=query_json)
result = response.json()["message"]

# %%
result
# Out:
# {'query_graph': {'nodes': {'n0': {'ids': ['MONDO:0007256'],
#     'categories': ['biolink:Disease']},
#    'n1': {'categories': ['biolink:Gene']}},
#   'edges': {'e1': {'subject': 'n0',
#     'object': 'n1',
#     'predicates': ['biolink:has_biomarker']}}},
#  'knowledge_graph': {'nodes': {'MONDO:0007256': {'categories': ['biolink:Disease'],
#     'name': 'hepatocellular carcinoma',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['MONDO:0007256',
#        'DOID:684',
#        'DOID:686',
#        'OMIM:114550',
#        'ORPHANET:88673',
#        'EFO:0000182',
#        'UMLS:C1862761',
#        'UMLS:C1867955',
#        'UMLS:C2239176',
#        'UMLS:C2676033',
#        'MESH:C567299',
#        'MESH:D006528',
#        'MEDDRA:10007416',
#        'MEDDRA:10019838',
#        'MEDDRA:10024658',
#        'MEDDRA:10048491',
#        'MEDDRA:10049010',
#        'MEDDRA:10073071',
#        'NCIT:C3099',
#        'SNOMEDCT:109841003',
#        'SNOMEDCT:1186630006',
#        'SNOMEDCT:187769009',
#        'SNOMEDCT:25370001',
#        'ICD10:C22.0',
#        'HP:0001402']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['hepatocellular carcinoma',
#        'liver carcinoma',
#        'Increased hepatocellular carcinoma risk',
#        'Increased incidence of hepatocellular carcinoma',
#        'Liver carcinoma',
#        'Hepatoblastoma Caused By Somatic Mutation',
#        'Carcinoma, Hepatocellular',
#        'Hepatocellular Carcinoma',
#        'Hepatocellular carcinoma']}]},
#    'NCBIGene:140738': {'categories': ['biolink:Gene'],
#     'name': 'TMEM37',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:140738',
#        'ENSEMBL:ENSG00000171227',
#        'HGNC:18216',
#        'OMIM:618831',
#        'UMLS:C1540007',
#        'UniProtKB:E7EMC0',
#        'ENSEMBL:ENSP00000387015',
#        'ENSEMBL:ENSP00000387015.1',
#        'UniProtKB:Q86SV2',
#        'UniProtKB:Q8WXS4',
#        'PR:Q8WXS4',
#        'ENSEMBL:ENSP00000303148',
#        'ENSEMBL:ENSP00000303148.4',
#        'UMLS:C4085567']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['TMEM37',
#        'TMEM37 gene',
#        'E7EMC0_HUMAN Voltage-dependent calcium channel gamma-like subunit (trembl)',
#        'Q86SV2_HUMAN TMEM37 protein (trembl)',
#        'CCGL_HUMAN Voltage-dependent calcium channel gamma-like subunit (sprot)',
#        'voltage-dependent calcium channel gamma-like subunit (human)',
#        'Voltage-Dependent Calcium Channel Gamma-Like Subunit, human']}]},
#    'NCBIGene:54898': {'categories': ['biolink:Gene'],
#     'name': 'ELOVL2',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:54898',
#        'ENSEMBL:ENSG00000197977',
#        'HGNC:14416',
#        'OMIM:611814',
#        'UMLS:C1422633',
#        'UniProtKB:A0A024QZV3',
#        'UniProtKB:Q9NXB9',
#        'PR:Q9NXB9',
#        'ENSEMBL:ENSP00000346693',
#        'ENSEMBL:ENSP00000346693.3']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['ELOVL2',
#        'ELOVL2 gene',
#        'A0A024QZV3_HUMAN Elongation of very long chain fatty acids protein 2 (trembl)',
#        'ELOV2_HUMAN Elongation of very long chain fatty acids protein 2 (sprot)',
#        'elongation of very long chain fatty acids protein 2 (human)']}]},
#    'NCBIGene:10642': {'categories': ['biolink:Gene'],
#     'name': 'IGF2BP1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:10642',
#        'ENSEMBL:ENSG00000159217',
#        'HGNC:28866',
#        'OMIM:608288',
#        'UMLS:C1825576',
#        'UniProtKB:Q9NZI8',
#        'PR:Q9NZI8']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['IGF2BP1',
#        'IGF2BP1 gene',
#        'IF2B1_HUMAN Insulin-like growth factor 2 mRNA-binding protein 1 (sprot)',
#        'insulin-like growth factor 2 mRNA-binding protein 1 (human)']}]},
#    'NCBIGene:341': {'categories': ['biolink:Gene'],
#     'name': 'APOC1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:341',
#        'ENSEMBL:ENSG00000130208',
#        'HGNC:607',
#        'OMIM:107710',
#        'UMLS:C1412475',
#        'UniProtKB:A0A024R0T8',
#        'UniProtKB:P02654',
#        'PR:P02654',
#        'ENSEMBL:ENSP00000465356',
#        'ENSEMBL:ENSP00000465356.1',
#        'ENSEMBL:ENSP00000468029',
#        'ENSEMBL:ENSP00000468029.1',
#        'ENSEMBL:ENSP00000468276',
#        'ENSEMBL:ENSP00000468276.2',
#        'UMLS:C0608460']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['APOC1',
#        'APOC1 gene',
#        'A0A024R0T8_HUMAN Apolipoprotein C-I, isoform CRA_a (trembl)',
#        'APOC1_HUMAN Apolipoprotein C-I (sprot)',
#        'apolipoprotein C-I (human)',
#        'Apolipoprotein C-I, Human']}]},
#    'NCBIGene:80781': {'categories': ['biolink:Gene'],
#     'name': 'COL18A1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:80781',
#        'ENSEMBL:ENSG00000182871',
#        'HGNC:2195',
#        'OMIM:120328',
#        'UMLS:C1332771',
#        'UniProtKB:D3DSM4',
#        'UniProtKB:D3DSM5',
#        'UniProtKB:P39060',
#        'PR:P39060',
#        'UMLS:C3887702',
#        'UMLS:C4082596']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['COL18A1',
#        'COL18A1 gene',
#        'D3DSM4_HUMAN Collagen, type XVIII, alpha 1, isoform CRA_d (trembl)',
#        'D3DSM5_HUMAN Collagen, type XVIII, alpha 1, isoform CRA_b (trembl)',
#        'COIA1_HUMAN Collagen alpha-1(XVIII) chain (sprot)',
#        'collagen alpha-1(XVIII) chain (human)',
#        'Endostatin, human',
#        'Collagen Alpha-1(XVIII) Chain, human']}]},
#    'NCBIGene:80201': {'categories': ['biolink:Gene'],
#     'name': 'HKDC1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:80201',
#        'ENSEMBL:ENSG00000156510',
#        'HGNC:23302',
#        'OMIM:617221',
#        'UMLS:C1539669',
#        'UniProtKB:B3KT70',
#        'UniProtKB:Q2TB90',
#        'PR:Q2TB90']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['HKDC1',
#        'HKDC1 gene',
#        'B3KT70_HUMAN Hexokinase (trembl)',
#        'HKDC1_HUMAN Hexokinase HKDC1 (sprot)',
#        'hexokinase HKDC1 (human)']}]},
#    'NCBIGene:26133': {'categories': ['biolink:Gene'],
#     'name': 'TRPC4AP',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:26133',
#        'ENSEMBL:ENSG00000100991',
#        'HGNC:16181',
#        'OMIM:608430',
#        'UMLS:C1424058',
#        'UniProtKB:B4DW48',
#        'UniProtKB:Q8TEL6',
#        'PR:Q8TEL6',
#        'UMLS:C2934853']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['TRPC4AP',
#        'TRPC4AP gene',
#        'B4DW48_HUMAN cDNA FLJ50256, highly similar to Trpc4-associated protein (trembl)',
#        'TP4AP_HUMAN Short transient receptor potential channel 4-associated protein (sprot)',
#        'short transient receptor potential channel 4-associated protein (human)',
#        'TRPC4AP protein, human']}]},
#    'NCBIGene:389421': {'categories': ['biolink:Gene'],
#     'name': 'LIN28B',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:389421',
#        'ENSEMBL:ENSG00000187772',
#        'HGNC:32207',
#        'OMIM:611044',
#        'UMLS:C1825819',
#        'UniProtKB:A0A1B0GVD3',
#        'ENSEMBL:ENSP00000490468',
#        'ENSEMBL:ENSP00000490468.1',
#        'UniProtKB:Q6ZN17',
#        'PR:Q6ZN17',
#        'UMLS:C3640107']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['LIN28B',
#        'LIN28B gene',
#        'A0A1B0GVD3_HUMAN Protein lin-28 homolog B (trembl)',
#        'LN28B_HUMAN Protein lin-28 homolog B (sprot)',
#        'protein lin-28 homolog B (human)',
#        'Protein Lin-28 Homolog B']}]},
#    'NCBIGene:1290': {'categories': ['biolink:Gene'],
#     'name': 'COL5A2',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:1290',
#        'ENSEMBL:ENSG00000204262',
#        'HGNC:2210',
#        'OMIM:120190',
#        'UMLS:C1413588',
#        'UniProtKB:P05997',
#        'PR:P05997',
#        'ENSEMBL:ENSP00000364000',
#        'ENSEMBL:ENSP00000364000.3',
#        'UMLS:C5444636']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['COL5A2',
#        'COL5A2 gene',
#        'CO5A2_HUMAN Collagen alpha-2(V) chain (sprot)',
#        'collagen alpha-2(V) chain (human)',
#        'Collagen Alpha-2(V) Chain, Human']}]},
#    'NCBIGene:154043': {'categories': ['biolink:Gene'],
#     'name': 'CNKSR3',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:154043',
#        'ENSEMBL:ENSG00000153721',
#        'HGNC:23034',
#        'OMIM:617476',
#        'UMLS:C1539115',
#        'UniProtKB:Q6P9H4',
#        'PR:Q6P9H4']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['CNKSR3',
#        'CNKSR3 gene',
#        'CNKR3_HUMAN Connector enhancer of kinase suppressor of ras 3 (sprot)',
#        'connector enhancer of kinase suppressor of ras 3 (human)']}]},
#    'NCBIGene:7276': {'categories': ['biolink:Gene'],
#     'name': 'TTR',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:7276',
#        'ENSEMBL:ENSG00000118271',
#        'HGNC:12405',
#        'OMIM:176300',
#        'UMLS:C1421224',
#        'UniProtKB:E9KL36',
#        'UniProtKB:P02766',
#        'PR:P02766',
#        'ENSEMBL:ENSP00000237014',
#        'ENSEMBL:ENSP00000237014.4',
#        'ENSEMBL:ENSP00000497927',
#        'ENSEMBL:ENSP00000497927.1',
#        'UMLS:C5196842']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['TTR',
#        'TTR gene',
#        'E9KL36_HUMAN Transthyretin (trembl)',
#        'TTHY_HUMAN Transthyretin (sprot)',
#        'transthyretin (human)',
#        'TTR protein, human']}]},
#    'NCBIGene:6594': {'categories': ['biolink:Gene'],
#     'name': 'SMARCA1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:6594',
#        'ENSEMBL:ENSG00000102038',
#        'HGNC:11097',
#        'OMIM:300012',
#        'UMLS:C1335840',
#        'UniProtKB:A0A0A0MRP6',
#        'ENSEMBL:ENSP00000360164',
#        'ENSEMBL:ENSP00000360164.2',
#        'UniProtKB:B7ZLQ5',
#        'ENSEMBL:ENSP00000360162',
#        'ENSEMBL:ENSP00000360162.4',
#        'UniProtKB:P28370',
#        'PR:P28370',
#        'UMLS:C0165820']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['SMARCA1',
#        'SMARCA1 gene',
#        'A0A0A0MRP6_HUMAN Probable global transcription activator SNF2L1 (trembl)',
#        'B7ZLQ5_HUMAN Probable global transcription activator SNF2L1 (trembl)',
#        'SMCA1_HUMAN Probable global transcription activator SNF2L1 (sprot)',
#        'probable global transcription activator SNF2L1 (human)',
#        'SMARCA1 protein, human']}]},
#    'NCBIGene:6780': {'categories': ['biolink:Gene'],
#     'name': 'STAU1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:6780',
#        'ENSEMBL:ENSG00000124214',
#        'HGNC:11370',
#        'OMIM:601716',
#        'UMLS:C1823131',
#        'UniProtKB:B3KRE0',
#        'UniProtKB:O95793',
#        'PR:O95793',
#        'UniProtKB:Q59F99',
#        'UniProtKB:Q6PJX3']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['STAU1',
#        'STAU1 gene',
#        'B3KRE0_HUMAN cDNA FLJ34086 fis, clone FCBBF3005320, highly similar to Double-stranded RNA-binding protein Staufen homolog 1 (trembl)',
#        'STAU1_HUMAN Double-stranded RNA-binding protein Staufen homolog 1 (sprot)',
#        'double-stranded RNA-binding protein Staufen homolog 1 (human)',
#        'Q59F99_HUMAN Staufen isoform b variant (Fragment) (trembl)',
#        'Q6PJX3_HUMAN STAU1 protein (Fragment) (trembl)']}]},
#    'NCBIGene:3162': {'categories': ['biolink:Gene'],
#     'name': 'HMOX1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:3162',
#        'ENSEMBL:ENSG00000100292',
#        'HGNC:5013',
#        'OMIM:141250',
#        'UMLS:C1415619',
#        'UniProtKB:P09601',
#        'PR:P09601',
#        'ENSEMBL:ENSP00000216117',
#        'ENSEMBL:ENSP00000216117.8',
#        'UMLS:C1565861',
#        'UniProtKB:Q6FH11']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['HMOX1',
#        'HMOX1 gene',
#        'HMOX1_HUMAN Heme oxygenase 1 (sprot)',
#        'heme oxygenase 1 (human)',
#        'HMOX1 protein, human',
#        'Q6FH11_HUMAN Heme oxygenase (trembl)']}]},
#    'NCBIGene:10486': {'categories': ['biolink:Gene'],
#     'name': 'CAP2',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:10486',
#        'ENSEMBL:ENSG00000112186',
#        'HGNC:20039',
#        'OMIM:618385',
#        'UMLS:C1426629',
#        'UniProtKB:P40123',
#        'PR:P40123',
#        'UniProtKB:Q5JPJ8']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['CAP2',
#        'CAP2 gene',
#        'CAP2_HUMAN Adenylyl cyclase-associated protein 2 (sprot)',
#        'adenylyl cyclase-associated protein 2 (human)',
#        'Q5JPJ8_HUMAN Adenylyl cyclase-associated protein (trembl)']}]},
#    'NCBIGene:29931': {'categories': ['biolink:Gene'],
#     'name': 'LINC00312',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:29931',
#        'HGNC:6662',
#        'OMIM:610485',
#        'UMLS:C1416896']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['LINC00312', 'LINC00312 gene']}]},
#    'NCBIGene:285381': {'categories': ['biolink:Gene'],
#     'name': 'DPH3',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:285381',
#        'ENSEMBL:ENSG00000154813',
#        'HGNC:27717',
#        'OMIM:608959',
#        'UMLS:C1538164',
#        'UniProtKB:Q96FX2',
#        'PR:Q96FX2']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['DPH3',
#        'DPH3 gene',
#        'DPH3_HUMAN Diphthamide biosynthesis protein 3 (sprot)',
#        'diphthamide biosynthesis protein 3 (human)']}]},
#    'NCBIGene:11259': {'categories': ['biolink:Gene'],
#     'name': 'FILIP1L',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:11259',
#        'ENSEMBL:ENSG00000168386',
#        'HGNC:24589',
#        'OMIM:612993',
#        'UMLS:C1825299',
#        'UniProtKB:Q4L180',
#        'PR:Q4L180',
#        'UMLS:C1620167']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['FILIP1L',
#        'FILIP1L gene',
#        'FIL1L_HUMAN Filamin A-interacting protein 1-like (sprot)',
#        'filamin A-interacting protein 1-like (human)',
#        'FILIP1L protein, human']}]},
#    'NCBIGene:282679': {'categories': ['biolink:Gene'],
#     'name': 'AQP11',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:282679',
#        'ENSEMBL:ENSG00000178301',
#        'HGNC:19940',
#        'OMIM:609914',
#        'UMLS:C1426548',
#        'UniProtKB:Q8NBQ7',
#        'PR:Q8NBQ7',
#        'ENSEMBL:ENSP00000318770',
#        'ENSEMBL:ENSP00000318770.3']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['AQP11',
#        'AQP11 gene',
#        'AQP11_HUMAN Aquaporin-11 (sprot)',
#        'aquaporin-11 (human)']}]},
#    'NCBIGene:10110': {'categories': ['biolink:Gene'],
#     'name': 'SGK2',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:10110',
#        'ENSEMBL:ENSG00000101049',
#        'HGNC:13900',
#        'OMIM:607589',
#        'UMLS:C1422258',
#        'UniProtKB:Q9HBY8',
#        'PR:Q9HBY8']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['SGK2',
#        'SGK2 gene',
#        'SGK2_HUMAN Serine/threonine-protein kinase Sgk2 (sprot)',
#        'serine/threonine-protein kinase Sgk2 (human)']}]},
#    'NCBIGene:344838': {'categories': ['biolink:Gene'],
#     'name': 'PAQR9',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:344838',
#        'ENSEMBL:ENSG00000188582',
#        'HGNC:30131',
#        'OMIM:614580',
#        'UMLS:C1538575',
#        'UniProtKB:Q6ZVX9',
#        'PR:Q6ZVX9',
#        'ENSEMBL:ENSP00000341564',
#        'ENSEMBL:ENSP00000341564.4']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['PAQR9',
#        'PAQR9 gene',
#        'PAQR9_HUMAN Membrane progestin receptor epsilon (sprot)',
#        'membrane progestin receptor epsilon (human)']}]},
#    'NCBIGene:1244': {'categories': ['biolink:Gene'],
#     'name': 'ABCC2',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:1244',
#        'ENSEMBL:ENSG00000023839',
#        'HGNC:53',
#        'OMIM:601107',
#        'UMLS:C1412077',
#        'UniProtKB:Q92887',
#        'PR:Q92887',
#        'ENSEMBL:ENSP00000497274',
#        'ENSEMBL:ENSP00000497274.1',
#        'UMLS:C3540577']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['ABCC2',
#        'ABCC2 gene',
#        'MRP2_HUMAN ATP-binding cassette sub-family C member 2 (sprot)',
#        'ATP-binding cassette sub-family C member 2 (human)',
#        'Canalicular Multispecific Organic Anion Transporter 1']}]},
#    'NCBIGene:9540': {'categories': ['biolink:Gene'],
#     'name': 'TP53I3',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:9540',
#        'ENSEMBL:ENSG00000115129',
#        'HGNC:19373',
#        'OMIM:605171',
#        'UMLS:C1426201',
#        'UniProtKB:B4DMQ7',
#        'UniProtKB:Q53FA7',
#        'PR:Q53FA7']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['TP53I3',
#        'TP53I3 gene',
#        'B4DMQ7_HUMAN Tumor protein p53 inducible protein 3, isoform CRA_c (trembl)',
#        'QORX_HUMAN Quinone oxidoreductase PIG3 (sprot)',
#        'quinone oxidoreductase PIG3 (human)']}]},
#    'NCBIGene:54873': {'categories': ['biolink:Gene'],
#     'name': 'PALMD',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:54873',
#        'ENSEMBL:ENSG00000099260',
#        'HGNC:15846',
#        'OMIM:610182',
#        'UMLS:C1423769',
#        'UniProtKB:A0A0S2Z5E7',
#        'UniProtKB:Q9NP74',
#        'PR:Q9NP74',
#        'UMLS:C1310324']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['PALMD',
#        'PALMD gene',
#        'A0A0S2Z5E7_HUMAN Palmdelphin isoform 1 (Fragment) (trembl)',
#        'PALMD_HUMAN Palmdelphin (sprot)',
#        'palmdelphin (human)',
#        'PALMD protein, human']}]},
#    'NCBIGene:10404': {'categories': ['biolink:Gene'],
#     'name': 'CPQ',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:10404',
#        'ENSEMBL:ENSG00000104324',
#        'HGNC:16910',
#        'OMIM:618754',
#        'UMLS:C2985237',
#        'UniProtKB:A0A024R9B8',
#        'UniProtKB:Q9Y646',
#        'PR:Q9Y646',
#        'ENSEMBL:ENSP00000220763',
#        'ENSEMBL:ENSP00000220763.5',
#        'UMLS:C2985239']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['CPQ',
#        'CPQ gene',
#        'A0A024R9B8_HUMAN Carboxypeptidase Q (trembl)',
#        'CBPQ_HUMAN Carboxypeptidase Q (sprot)',
#        'carboxypeptidase Q (human)',
#        'Plasma Glutamate Carboxypeptidase']}]},
#    'NCBIGene:5507': {'categories': ['biolink:Gene'],
#     'name': 'PPP1R3C',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:5507',
#        'ENSEMBL:ENSG00000119938',
#        'HGNC:9293',
#        'OMIM:602999',
#        'UMLS:C1418830',
#        'UniProtKB:Q9UQK1',
#        'PR:Q9UQK1',
#        'ENSEMBL:ENSP00000238994',
#        'ENSEMBL:ENSP00000238994.5']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['PPP1R3C',
#        'PPP1R3C gene',
#        'PPR3C_HUMAN Protein phosphatase 1 regulatory subunit 3C (sprot)',
#        'protein phosphatase 1 regulatory subunit 3C (human)']}]},
#    'NCBIGene:2770': {'categories': ['biolink:Gene'],
#     'name': 'GNAI1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:2770',
#        'ENSEMBL:ENSG00000127955',
#        'HGNC:4384',
#        'OMIM:139310',
#        'UMLS:C1415142',
#        'UniProtKB:P63096',
#        'PR:P63096',
#        'UMLS:C1517337']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['GNAI1',
#        'GNAI1 gene',
#        'GNAI1_HUMAN Guanine nucleotide-binding protein G(i) subunit alpha-1 (sprot)',
#        'guanine nucleotide-binding protein G(i) subunit alpha-1 (human)',
#        'GNAI1 protein, human']}]},
#    'NCBIGene:3176': {'categories': ['biolink:Gene'],
#     'name': 'HNMT',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:3176',
#        'ENSEMBL:ENSG00000150540',
#        'HGNC:5028',
#        'OMIM:605238',
#        'UMLS:C1415632',
#        'UniProtKB:B4DWC1',
#        'UniProtKB:P50135',
#        'PR:P50135']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['HNMT',
#        'HNMT gene',
#        'B4DWC1_HUMAN Histamine N-methyltransferase (trembl)',
#        'HNMT_HUMAN Histamine N-methyltransferase (sprot)',
#        'histamine N-methyltransferase (human)']}]},
#    'NCBIGene:4758': {'categories': ['biolink:Gene'],
#     'name': 'NEU1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:4758',
#        'ENSEMBL:ENSG00000204386',
#        'HGNC:7758',
#        'OMIM:608272',
#        'UMLS:C1417680',
#        'UniProtKB:Q5JQI0',
#        'UniProtKB:Q99519',
#        'PR:Q99519',
#        'ENSEMBL:ENSP00000229725',
#        'ENSEMBL:ENSP00000229725.4',
#        'ENSEMBL:ENSP00000364782',
#        'ENSEMBL:ENSP00000364782.4',
#        'ENSEMBL:ENSP00000399309',
#        'ENSEMBL:ENSP00000399309.3',
#        'ENSEMBL:ENSP00000401067',
#        'ENSEMBL:ENSP00000401067.2',
#        'ENSEMBL:ENSP00000403720',
#        'ENSEMBL:ENSP00000403720.2',
#        'ENSEMBL:ENSP00000408207',
#        'ENSEMBL:ENSP00000408207.2',
#        'ENSEMBL:ENSP00000408957',
#        'ENSEMBL:ENSP00000408957.2',
#        'ENSEMBL:ENSP00000409489',
#        'ENSEMBL:ENSP00000409489.2']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['NEU1',
#        'NEU1 gene',
#        'Q5JQI0_HUMAN Exo-alpha-sialidase (trembl)',
#        'NEUR1_HUMAN Sialidase-1 (sprot)',
#        'sialidase-1 (human)']}]},
#    'NCBIGene:2677': {'categories': ['biolink:Gene'],
#     'name': 'GGCX',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:2677',
#        'ENSEMBL:ENSG00000115486',
#        'HGNC:4247',
#        'OMIM:137167',
#        'UMLS:C1415050',
#        'UniProtKB:A0A8I5QJA4',
#        'ENSEMBL:ENSP00000508856',
#        'ENSEMBL:ENSP00000508856.1',
#        'UniProtKB:P38435',
#        'PR:P38435']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['GGCX',
#        'GGCX gene',
#        'A0A8I5QJA4_HUMAN Gamma-glutamyl carboxylase, isoform CRA_a (trembl)',
#        'VKGC_HUMAN Vitamin K-dependent gamma-carboxylase (sprot)',
#        'vitamin K-dependent gamma-carboxylase (human)']}]},
#    'NCBIGene:26585': {'categories': ['biolink:Gene'],
#     'name': 'GREM1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:26585',
#        'ENSEMBL:ENSG00000166923',
#        'HGNC:2001',
#        'OMIM:603054',
#        'UMLS:C1539614',
#        'UniProtKB:A6XAA7',
#        'UniProtKB:B3KTR9',
#        'UniProtKB:O60565',
#        'PR:O60565',
#        'UMLS:C1438932']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['GREM1',
#        'GREM1 gene',
#        'A6XAA7_HUMAN Gremlin (trembl)',
#        'B3KTR9_HUMAN Gremlin 1, cysteine knot superfamily, homolog (Xenopus laevis), isoform CRA_c (trembl)',
#        'GREM1_HUMAN Gremlin-1 (sprot)',
#        'gremlin-1 (human)',
#        'GREM1 protein, human']}]},
#    'NCBIGene:729862': {'categories': ['biolink:Gene'],
#     'name': 'LSP1P3',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:729862', 'HGNC:39718', 'UMLS:C3147761']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['LSP1P3', 'LSP1P3 gene']}]},
#    'NCBIGene:48': {'categories': ['biolink:Gene'],
#     'name': 'ACO1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:48',
#        'ENSEMBL:ENSG00000122729',
#        'HGNC:117',
#        'OMIM:100880',
#        'UMLS:C1412126',
#        'UniProtKB:P21399',
#        'PR:P21399',
#        'ENSEMBL:ENSP00000309477',
#        'ENSEMBL:ENSP00000309477.5',
#        'ENSEMBL:ENSP00000369255',
#        'ENSEMBL:ENSP00000369255.1',
#        'ENSEMBL:ENSP00000438733',
#        'ENSEMBL:ENSP00000438733.2',
#        'UniProtKB:Q9HBB2',
#        'UniProtKB:V9HWB7']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['ACO1',
#        'ACO1 gene',
#        'ACOHC_HUMAN Cytoplasmic aconitate hydratase (sprot)',
#        'cytoplasmic aconitate hydratase (human)',
#        'Q9HBB2_HUMAN Cytoplasmic aconitate hydratase (trembl)',
#        'V9HWB7_HUMAN Cytoplasmic aconitate hydratase (trembl)']}]},
#    'NCBIGene:64838': {'categories': ['biolink:Gene'],
#     'name': 'FNDC4',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:64838',
#        'ENSEMBL:ENSG00000115226',
#        'HGNC:20239',
#        'OMIM:611905',
#        'UMLS:C1426802',
#        'UniProtKB:Q9H6D8',
#        'PR:Q9H6D8',
#        'ENSEMBL:ENSP00000264703',
#        'ENSEMBL:ENSP00000264703.3']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['FNDC4',
#        'FNDC4 gene',
#        'FNDC4_HUMAN Fibronectin type III domain-containing protein 4 (sprot)',
#        'fibronectin type III domain-containing protein 4 (human)']}]},
#    'NCBIGene:123': {'categories': ['biolink:Gene'],
#     'name': 'PLIN2',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:123',
#        'ENSEMBL:ENSG00000147872',
#        'HGNC:248',
#        'OMIM:103195',
#        'UMLS:C1412234',
#        'UniProtKB:Q6FHZ7',
#        'UniProtKB:Q99541',
#        'PR:Q99541',
#        'ENSEMBL:ENSP00000276914',
#        'ENSEMBL:ENSP00000276914.2',
#        'UMLS:C1505480']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['PLIN2',
#        'PLIN2 gene',
#        'Q6FHZ7_HUMAN Perilipin (trembl)',
#        'PLIN2_HUMAN Perilipin-2 (sprot)',
#        'perilipin-2 (human)',
#        'Perilipin-2, human']}]},
#    'NCBIGene:1803': {'categories': ['biolink:Gene'],
#     'name': 'DPP4',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:1803',
#        'ENSEMBL:ENSG00000197635',
#        'HGNC:3009',
#        'OMIM:102720',
#        'UMLS:C1414141',
#        'UniProtKB:P27487',
#        'PR:P27487',
#        'ENSEMBL:ENSP00000353731',
#        'ENSEMBL:ENSP00000353731.3',
#        'UMLS:C1447020']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['DPP4',
#        'DPP4 gene',
#        'DPP4_HUMAN Dipeptidyl peptidase 4 (sprot)',
#        'dipeptidyl peptidase 4 (human)',
#        'DPP4 protein, human']}]},
#    'NCBIGene:7068': {'categories': ['biolink:Gene'],
#     'name': 'THRB',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:7068',
#        'ENSEMBL:ENSG00000151090',
#        'HGNC:11799',
#        'OMIM:190160',
#        'UMLS:C0242988',
#        'UniProtKB:A0A024R2I8',
#        'UniProtKB:P10828',
#        'PR:P10828',
#        'UMLS:C5441595']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['THRB',
#        'THRB gene',
#        'A0A024R2I8_HUMAN Thyroid hormone nuclear receptor beta variant 1 (trembl)',
#        'THB_HUMAN Thyroid hormone receptor beta (sprot)',
#        'thyroid hormone receptor beta (human)',
#        'THRB protein, human']}]},
#    'NCBIGene:10741': {'categories': ['biolink:Gene'],
#     'name': 'RBBP9',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:10741',
#        'ENSEMBL:ENSG00000089050',
#        'HGNC:9892',
#        'OMIM:602908',
#        'UMLS:C1419294',
#        'UniProtKB:O75884',
#        'PR:O75884',
#        'UMLS:C1313695']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['RBBP9',
#        'RBBP9 gene',
#        'RBBP9_HUMAN Serine hydrolase RBBP9 (sprot)',
#        'serine hydrolase RBBP9 (human)',
#        'RBBP9 protein, human']}]},
#    'NCBIGene:3912': {'categories': ['biolink:Gene'],
#     'name': 'LAMB1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:3912',
#        'ENSEMBL:ENSG00000091136',
#        'HGNC:6486',
#        'OMIM:150240',
#        'UMLS:C1416780',
#        'UniProtKB:G3XAI2',
#        'ENSEMBL:ENSP00000377191',
#        'ENSEMBL:ENSP00000377191.2',
#        'UniProtKB:P07942',
#        'PR:P07942',
#        'ENSEMBL:ENSP00000222399',
#        'ENSEMBL:ENSP00000222399.6',
#        'UniProtKB:Q8TAS6']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['LAMB1',
#        'LAMB1 gene',
#        'G3XAI2_HUMAN Laminin subunit beta-1 (trembl)',
#        'LAMB1_HUMAN Laminin subunit beta-1 (sprot)',
#        'laminin subunit beta-1 (human)',
#        'Q8TAS6_HUMAN LAMB1 protein (Fragment) (trembl)']}]},
#    'NCBIGene:5476': {'categories': ['biolink:Gene'],
#     'name': 'CTSA',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:5476',
#        'ENSEMBL:ENSG00000064601',
#        'HGNC:9251',
#        'OMIM:613111',
#        'UMLS:C1824812',
#        'UniProtKB:B4E324',
#        'UniProtKB:P10619',
#        'PR:P10619',
#        'UniProtKB:X6R5C5',
#        'ENSEMBL:ENSP00000346952',
#        'ENSEMBL:ENSP00000346952.4',
#        'UniProtKB:X6R8A1',
#        'ENSEMBL:ENSP00000361562',
#        'ENSEMBL:ENSP00000361562.3',
#        'ENSEMBL:ENSP00000504790',
#        'ENSEMBL:ENSP00000504790.1']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['CTSA',
#        'CTSA gene',
#        'B4E324_HUMAN cDNA FLJ60397, highly similar to Lysosomal protective protein (trembl)',
#        'PPGB_HUMAN Lysosomal protective protein (sprot)',
#        'lysosomal protective protein (human)',
#        'X6R5C5_HUMAN Carboxypeptidase (trembl)',
#        'X6R8A1_HUMAN Carboxypeptidase (trembl)']}]},
#    'NCBIGene:4035': {'categories': ['biolink:Gene'],
#     'name': 'LRP1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:4035',
#        'ENSEMBL:ENSG00000123384',
#        'HGNC:6692',
#        'OMIM:107770',
#        'UMLS:C1416912',
#        'UniProtKB:Q07954',
#        'PR:Q07954',
#        'UMLS:C2987172',
#        'UniProtKB:Q59FG2']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['LRP1',
#        'LRP1 gene',
#        'LRP1_HUMAN Prolow-density lipoprotein receptor-related protein 1 (sprot)',
#        'prolow-density lipoprotein receptor-related protein 1 (human)',
#        'Prolow-Density Lipoprotein Receptor-Related Protein 1',
#        'Q59FG2_HUMAN Low density lipoprotein-related protein 1 variant (Fragment) (trembl)']}]},
#    'NCBIGene:2281': {'categories': ['biolink:Gene'],
#     'name': 'FKBP1B',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:2281',
#        'ENSEMBL:ENSG00000119782',
#        'HGNC:3712',
#        'OMIM:600620',
#        'UMLS:C1414619',
#        'UniProtKB:F8W6G9',
#        'ENSEMBL:ENSP00000406593',
#        'ENSEMBL:ENSP00000406593.1',
#        'UniProtKB:P68106',
#        'PR:P68106']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['FKBP1B',
#        'FKBP1B gene',
#        'F8W6G9_HUMAN Peptidylprolyl isomerase (trembl)',
#        'FKB1B_HUMAN Peptidyl-prolyl cis-trans isomerase FKBP1B (sprot)',
#        'peptidyl-prolyl cis-trans isomerase FKBP1B (human)']}]},
#    'NCBIGene:63895': {'categories': ['biolink:Gene'],
#     'name': 'PIEZO2',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:63895',
#        'ENSEMBL:ENSG00000154864',
#        'HGNC:26270',
#        'OMIM:613629',
#        'UMLS:C1539429',
#        'UniProtKB:Q9H5I5',
#        'PR:Q9H5I5',
#        'UMLS:C3814819']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['PIEZO2',
#        'PIEZO2 gene',
#        'PIEZ2_HUMAN Piezo-type mechanosensitive ion channel component 2 (sprot)',
#        'piezo-type mechanosensitive ion channel component 2 (human)',
#        'Piezo-Type Mechanosensitive Ion Channel Component 2']}]},
#    'NCBIGene:283219': {'categories': ['biolink:Gene'],
#     'name': 'KCTD21',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:283219',
#        'ENSEMBL:ENSG00000188997',
#        'HGNC:27452',
#        'OMIM:618790',
#        'UMLS:C1825647',
#        'UniProtKB:Q4G0X4',
#        'PR:Q4G0X4',
#        'ENSEMBL:ENSP00000339340',
#        'ENSEMBL:ENSP00000339340.3']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['KCTD21',
#        'KCTD21 gene',
#        'KCD21_HUMAN BTB/POZ domain-containing protein KCTD21 (sprot)',
#        'BTB/POZ domain-containing protein KCTD21 (human)']}]},
#    'NCBIGene:462': {'categories': ['biolink:Gene'],
#     'name': 'SERPINC1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:462',
#        'ENSEMBL:ENSG00000117601',
#        'HGNC:775',
#        'OMIM:107300',
#        'UMLS:C1412610',
#        'UniProtKB:A0A024R944',
#        'UniProtKB:P01008',
#        'PR:P01008',
#        'ENSEMBL:ENSP00000356671',
#        'ENSEMBL:ENSP00000356671.3',
#        'UMLS:C2717481']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['SERPINC1',
#        'SERPINC1 gene',
#        'A0A024R944_HUMAN Antithrombin-III (trembl)',
#        'ANT3_HUMAN Antithrombin-III (sprot)',
#        'antithrombin-III (human)',
#        'SERPINC1 protein, human']}]},
#    'NCBIGene:56288': {'categories': ['biolink:Gene'],
#     'name': 'PARD3',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:56288',
#        'ENSEMBL:ENSG00000148498',
#        'HGNC:16051',
#        'OMIM:606745',
#        'UMLS:C1423939',
#        'UniProtKB:Q8TEW0',
#        'PR:Q8TEW0',
#        'UMLS:C4085255']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['PARD3',
#        'PARD3 gene',
#        'PARD3_HUMAN Partitioning defective 3 homolog (sprot)',
#        'partitioning defective 3 homolog (human)',
#        'Partitioning Defective 3 Homolog']}]},
#    'NCBIGene:4811': {'categories': ['biolink:Gene'],
#     'name': 'NID1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:4811',
#        'ENSEMBL:ENSG00000116962',
#        'HGNC:7821',
#        'OMIM:131390',
#        'UMLS:C1334880',
#        'UniProtKB:P14543',
#        'PR:P14543',
#        'UMLS:C1615511']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['NID1',
#        'NID1 gene',
#        'NID1_HUMAN Nidogen-1 (sprot)',
#        'nidogen-1 (human)',
#        'NID1 protein, human']}]},
#    'NCBIGene:1593': {'categories': ['biolink:Gene'],
#     'name': 'CYP27A1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:1593',
#        'ENSEMBL:ENSG00000135929',
#        'HGNC:2605',
#        'OMIM:606530',
#        'UMLS:C1413864',
#        'UniProtKB:Q02318',
#        'PR:Q02318',
#        'ENSEMBL:ENSP00000258415',
#        'ENSEMBL:ENSP00000258415.4',
#        'UMLS:C3538880']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['CYP27A1',
#        'CYP27A1 gene',
#        'CP27A_HUMAN Sterol 26-hydroxylase, mitochondrial (sprot)',
#        'sterol 26-hydroxylase, mitochondrial (human)',
#        'Sterol 26-Hydroxylase, Mitochondrial, Human']}]},
#    'NCBIGene:5054': {'categories': ['biolink:Gene'],
#     'name': 'SERPINE1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:5054',
#        'ENSEMBL:ENSG00000106366',
#        'HGNC:8583',
#        'OMIM:173360',
#        'UMLS:C1418252',
#        'UniProtKB:A0A024QYT5',
#        'UniProtKB:P05121',
#        'PR:P05121',
#        'UMLS:C1620101']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['SERPINE1',
#        'SERPINE1 gene',
#        'A0A024QYT5_HUMAN Serpin peptidase inhibitor, clade E (Nexin, plasminogen activator inhibitor type 1), member 1, isoform CRA_b (trembl)',
#        'PAI1_HUMAN Plasminogen activator inhibitor 1 (sprot)',
#        'plasminogen activator inhibitor 1 (human)',
#        'SERPINE1 protein, human']}]},
#    'NCBIGene:22927': {'categories': ['biolink:Gene'],
#     'name': 'HABP4',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:22927',
#        'ENSEMBL:ENSG00000130956',
#        'HGNC:17062',
#        'OMIM:617369',
#        'UMLS:C1424719',
#        'UniProtKB:Q5JVS0',
#        'PR:Q5JVS0']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['HABP4',
#        'HABP4 gene',
#        'HABP4_HUMAN Intracellular hyaluronan-binding protein 4 (sprot)',
#        'intracellular hyaluronan-binding protein 4 (human)']}]},
#    'NCBIGene:64283': {'categories': ['biolink:Gene'],
#     'name': 'ARHGEF28',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:64283',
#        'ENSEMBL:ENSG00000214944',
#        'HGNC:30322',
#        'OMIM:612790',
#        'UMLS:C2748553',
#        'UniProtKB:Q8N1W1',
#        'PR:Q8N1W1',
#        'UMLS:C2935655']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['ARHGEF28',
#        'ARHGEF28 gene',
#        'ARG28_HUMAN Rho guanine nucleotide exchange factor 28 (sprot)',
#        'Rho guanine nucleotide exchange factor 28 (human)',
#        'RGNEF protein, human']}]},
#    'NCBIGene:144402': {'categories': ['biolink:Gene'],
#     'name': 'CPNE8',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:144402',
#        'ENSEMBL:ENSG00000139117',
#        'HGNC:23498',
#        'UMLS:C1428104',
#        'UniProtKB:Q86YQ8',
#        'PR:Q86YQ8']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['CPNE8',
#        'CPNE8 gene',
#        'CPNE8_HUMAN Copine-8 (sprot)',
#        'copine-8 (human)']}]},
#    'NCBIGene:90411': {'categories': ['biolink:Gene'],
#     'name': 'MCFD2',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:90411',
#        'ENSEMBL:ENSG00000180398',
#        'HGNC:18451',
#        'OMIM:607788',
#        'UMLS:C1425524',
#        'UniProtKB:B4DF17',
#        'UniProtKB:Q8NI22',
#        'PR:Q8NI22']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['MCFD2',
#        'MCFD2 gene',
#        'B4DF17_HUMAN cDNA FLJ59187, highly similar to Multiple coagulation factor deficiency protein 2 homolog (trembl)',
#        'MCFD2_HUMAN Multiple coagulation factor deficiency protein 2 (sprot)',
#        'multiple coagulation factor deficiency protein 2 (human)']}]},
#    'NCBIGene:866': {'categories': ['biolink:Gene'],
#     'name': 'SERPINA6',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:866',
#        'ENSEMBL:ENSG00000170099',
#        'HGNC:1540',
#        'OMIM:122500',
#        'UMLS:C1413150',
#        'UniProtKB:A0A2Z4LCH4',
#        'UniProtKB:P08185',
#        'PR:P08185',
#        'ENSEMBL:ENSP00000342850',
#        'ENSEMBL:ENSP00000342850.3',
#        'ENSEMBL:ENSP00000484501',
#        'ENSEMBL:ENSP00000484501.1']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['SERPINA6',
#        'SERPINA6 gene',
#        'A0A2Z4LCH4_HUMAN Corticosteroid-binding globulin (trembl)',
#        'CBG_HUMAN Corticosteroid-binding globulin (sprot)',
#        'corticosteroid-binding globulin (human)']}]},
#    'NCBIGene:2819': {'categories': ['biolink:Gene'],
#     'name': 'GPD1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:2819',
#        'ENSEMBL:ENSG00000167588',
#        'HGNC:4455',
#        'OMIM:138420',
#        'UMLS:C1415199',
#        'UniProtKB:A0A024R138',
#        'UniProtKB:P21695',
#        'PR:P21695']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['GPD1',
#        'GPD1 gene',
#        'A0A024R138_HUMAN Glycerol-3-phosphate dehydrogenase [NAD(+)] (trembl)',
#        'GPDA_HUMAN Glycerol-3-phosphate dehydrogenase [NAD(+)], cytoplasmic (sprot)',
#        'glycerol-3-phosphate dehydrogenase [NAD(+)], cytoplasmic (human)']}]},
#    'NCBIGene:55670': {'categories': ['biolink:Gene'],
#     'name': 'PEX26',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:55670',
#        'ENSEMBL:ENSG00000215193',
#        'HGNC:22965',
#        'OMIM:608666',
#        'UMLS:C1427818',
#        'UniProtKB:A0A024R100',
#        'UniProtKB:A0A0S2Z5M7',
#        'UniProtKB:Q7Z2D7',
#        'UniProtKB:Q7Z412',
#        'PR:Q7Z412']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['PEX26',
#        'PEX26 gene',
#        'A0A024R100_HUMAN Peroxisomal biogenesis factor 26 isoform 1 (trembl)',
#        'A0A0S2Z5M7_HUMAN Peroxisomal biogenesis factor 26 isoform 2 (Fragment) (trembl)',
#        'Q7Z2D7_HUMAN Pex26pT35insC (trembl)',
#        'PEX26_HUMAN Peroxisome assembly protein 26 (sprot)',
#        'peroxisome assembly protein 26 (human)']}]},
#    'NCBIGene:115701': {'categories': ['biolink:Gene'],
#     'name': 'ALPK2',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:115701',
#        'ENSEMBL:ENSG00000198796',
#        'HGNC:20565',
#        'OMIM:619965',
#        'UMLS:C1538266',
#        'UniProtKB:Q86TB3',
#        'PR:Q86TB3',
#        'ENSEMBL:ENSP00000354991',
#        'ENSEMBL:ENSP00000354991.3',
#        'UMLS:C3493756']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['ALPK2',
#        'ALPK2 gene',
#        'ALPK2_HUMAN Alpha-protein kinase 2 (sprot)',
#        'alpha-protein kinase 2 (human)',
#        'ALPK2 protein, human']}]},
#    'NCBIGene:3484': {'categories': ['biolink:Gene'],
#     'name': 'IGFBP1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:3484',
#        'ENSEMBL:ENSG00000146678',
#        'HGNC:5469',
#        'OMIM:146730',
#        'UMLS:C1334092',
#        'UniProtKB:P08833',
#        'PR:P08833',
#        'ENSEMBL:ENSP00000275525',
#        'ENSEMBL:ENSP00000275525.3',
#        'UMLS:C0071189']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['IGFBP1',
#        'IGFBP1 gene',
#        'IBP1_HUMAN Insulin-like growth factor-binding protein 1 (sprot)',
#        'insulin-like growth factor-binding protein 1 (human)',
#        'IGFBP1 protein, human']}]},
#    'NCBIGene:8540': {'categories': ['biolink:Gene'],
#     'name': 'AGPS',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:8540',
#        'ENSEMBL:ENSG00000018510',
#        'HGNC:327',
#        'OMIM:603051',
#        'UMLS:C1412284',
#        'UniProtKB:B7Z3Q4',
#        'ENSEMBL:ENSP00000504957',
#        'ENSEMBL:ENSP00000504957.1',
#        'ENSEMBL:ENSP00000505333',
#        'ENSEMBL:ENSP00000505333.1',
#        'ENSEMBL:ENSP00000505342',
#        'ENSEMBL:ENSP00000505342.1',
#        'ENSEMBL:ENSP00000506484',
#        'ENSEMBL:ENSP00000506484.1',
#        'UniProtKB:O00116',
#        'PR:O00116',
#        'ENSEMBL:ENSP00000264167',
#        'ENSEMBL:ENSP00000264167.4']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['AGPS',
#        'AGPS gene',
#        'B7Z3Q4_HUMAN Alkylglycerone-phosphate synthase (trembl)',
#        'ADAS_HUMAN Alkyldihydroxyacetonephosphate synthase, peroxisomal (sprot)',
#        'alkyldihydroxyacetonephosphate synthase, peroxisomal (human)']}]},
#    'NCBIGene:9936': {'categories': ['biolink:Gene'],
#     'name': 'CD302',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:9936',
#        'ENSEMBL:ENSG00000241399',
#        'HGNC:30843',
#        'OMIM:612246',
#        'UMLS:C1540296',
#        'UniProtKB:A0A087WT00',
#        'ENSEMBL:ENSP00000451446',
#        'ENSEMBL:ENSP00000451446.2',
#        'UniProtKB:Q8IX05',
#        'PR:Q8IX05',
#        'UMLS:C1312017']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['CD302',
#        'CD302 gene',
#        'A0A087WT00_HUMAN CD302 antigen (trembl)',
#        'CD302_HUMAN CD302 antigen (sprot)',
#        'CD302 antigen (human)',
#        'CD302 Antigen, Human']}]},
#    'NCBIGene:10484': {'categories': ['biolink:Gene'],
#     'name': 'SEC23A',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:10484',
#        'ENSEMBL:ENSG00000100934',
#        'HGNC:10701',
#        'OMIM:610511',
#        'UMLS:C1419925',
#        'UniProtKB:Q15436',
#        'PR:Q15436']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['SEC23A',
#        'SEC23A gene',
#        'SC23A_HUMAN Protein transport protein Sec23A (sprot)',
#        'protein transport protein Sec23A (human)']}]},
#    'NCBIGene:185': {'categories': ['biolink:Gene'],
#     'name': 'AGTR1',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:185',
#        'ENSEMBL:ENSG00000144891',
#        'HGNC:336',
#        'OMIM:106165',
#        'UMLS:C1439284',
#        'UniProtKB:A0A0A0MSE3',
#        'UniProtKB:D3DNG8',
#        'UniProtKB:P30556',
#        'PR:P30556',
#        'ENSEMBL:ENSP00000273430',
#        'ENSEMBL:ENSP00000273430.3',
#        'ENSEMBL:ENSP00000385612',
#        'ENSEMBL:ENSP00000385612.2',
#        'ENSEMBL:ENSP00000385641',
#        'ENSEMBL:ENSP00000385641.3',
#        'ENSEMBL:ENSP00000398832',
#        'ENSEMBL:ENSP00000398832.4',
#        'ENSEMBL:ENSP00000418084',
#        'ENSEMBL:ENSP00000418084.1',
#        'ENSEMBL:ENSP00000418851',
#        'ENSEMBL:ENSP00000418851.1',
#        'ENSEMBL:ENSP00000419422',
#        'ENSEMBL:ENSP00000419422.1',
#        'ENSEMBL:ENSP00000419783',
#        'ENSEMBL:ENSP00000419783.1',
#        'UMLS:C2743340',
#        'UniProtKB:Q53YY0',
#        'UniProtKB:Q6NUP5']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['AGTR1',
#        'AGTR1 gene',
#        'A0A0A0MSE3_HUMAN Type-1 angiotensin II receptor (trembl)',
#        'D3DNG8_HUMAN Type-1 angiotensin II receptor (trembl)',
#        'AGTR1_HUMAN Type-1 angiotensin II receptor (sprot)',
#        'type-1 angiotensin II receptor (human)',
#        'AGTR1 protein, human',
#        'Q53YY0_HUMAN Type-1 angiotensin II receptor (trembl)',
#        'Q6NUP5_HUMAN Type-1 angiotensin II receptor (trembl)']}]},
#    'NCBIGene:387263': {'categories': ['biolink:Gene'],
#     'name': 'C6orf120',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:387263',
#        'ENSEMBL:ENSG00000185127',
#        'HGNC:21247',
#        'OMIM:616987',
#        'UMLS:C1427451',
#        'UniProtKB:B4DJ79',
#        'UniProtKB:Q7Z4R8',
#        'PR:Q7Z4R8',
#        'ENSEMBL:ENSP00000346931',
#        'ENSEMBL:ENSP00000346931.1']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['C6orf120',
#        'C6orf120 gene',
#        'B4DJ79_HUMAN cDNA FLJ55847 (trembl)',
#        'CF120_HUMAN UPF0669 protein C6orf120 (sprot)',
#        'UPF0669 protein C6orf120 (human)']}]},
#    'NCBIGene:8563': {'categories': ['biolink:Gene'],
#     'name': 'THOC5',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:8563',
#        'ENSEMBL:ENSG00000100296',
#        'HGNC:19074',
#        'OMIM:612733',
#        'UMLS:C1425991',
#        'UniProtKB:A0A024R1D6',
#        'UniProtKB:Q13769',
#        'PR:Q13769',
#        'ENSEMBL:ENSP00000380969',
#        'ENSEMBL:ENSP00000380969.1',
#        'ENSEMBL:ENSP00000380970',
#        'ENSEMBL:ENSP00000380970.1',
#        'ENSEMBL:ENSP00000380971',
#        'ENSEMBL:ENSP00000380971.2',
#        'ENSEMBL:ENSP00000420306',
#        'ENSEMBL:ENSP00000420306.1',
#        'UMLS:C1334876']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['THOC5',
#        'THOC5 gene',
#        'A0A024R1D6_HUMAN HCG2011153, isoform CRA_b (trembl)',
#        'THOC5_HUMAN THO complex subunit 5 homolog (sprot)',
#        'THO complex subunit 5 homolog (human)',
#        'Chromosome 22 Open Reading Frame 19 Protein, Human']}]},
#    'NCBIGene:4638': {'categories': ['biolink:Gene'],
#     'name': 'MYLK',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:4638',
#        'ENSEMBL:ENSG00000065534',
#        'HGNC:7590',
#        'OMIM:600922',
#        'UMLS:C1334539',
#        'UniProtKB:A0A8I5KTQ1',
#        'ENSEMBL:ENSP00000510593',
#        'ENSEMBL:ENSP00000510593.1',
#        'UniProtKB:Q05B97',
#        'UniProtKB:Q05B98',
#        'UniProtKB:Q15746',
#        'PR:Q15746',
#        'UMLS:C1567740']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['MYLK',
#        'MYLK gene',
#        'A0A8I5KTQ1_HUMAN Myosin light chain kinase, smooth muscle (trembl)',
#        'Q05B97_HUMAN MYLK protein (Fragment) (trembl)',
#        'Q05B98_HUMAN MYLK protein (Fragment) (trembl)',
#        'MYLK_HUMAN Myosin light chain kinase, smooth muscle (sprot)',
#        'myosin light chain kinase, smooth muscle (human)',
#        'MYLK protein, human']}]},
#    'NCBIGene:5825': {'categories': ['biolink:Gene'],
#     'name': 'ABCD3',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:5825',
#        'ENSEMBL:ENSG00000117528',
#        'HGNC:67',
#        'OMIM:170995',
#        'UMLS:C1412090',
#        'UniProtKB:P28288',
#        'PR:P28288']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['ABCD3',
#        'ABCD3 gene',
#        'ABCD3_HUMAN ATP-binding cassette sub-family D member 3 (sprot)',
#        'ATP-binding cassette sub-family D member 3 (human)']}]},
#    'NCBIGene:1000': {'categories': ['biolink:Gene'],
#     'name': 'CDH2',
# ...
#      'edge_bindings': {'e1': [{'id': 'bf05581bac503b17d08523bf471a1896'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:9973'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '982f01b6eab12e219744977f4ef9e712'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:2494'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'ab97185e312ece8b57664f2fa208a145'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:23531'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'c3058d2eb114a2bb9d8ca544fc8d6385'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:23528'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '6b0700eaf21471bcf19754b3b1489647'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:113220'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '0bac944cb65049616822699ba0524ab0'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:51473'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '45997ab20324edecb4fde6294088ebdf'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:13'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '35d0bbb3c3bb59ee574af710165b3d1e'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:2243'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'b53a9ed6b6b1084fc86ad181f38cd016'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:22837'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '6a26cefdbbc0e8c9e21d0705b3ecb70b'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:570'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '274d27696311b98207554d9706ce8e59'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:63910'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '9da5f4e40d7339bc35cf366ddf331c5f'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:3053'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '05eed3107768882e5988d74a467c54c3'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:5919'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '700a9fda59a48e33fd6c1a27a30d8791'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:174'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '171387ff77848c08a660cd51d01d1d24'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:140801'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '3956a56b26c64f693e9de8b522ee4564'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:151258'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '1f0ee612259d1b14ca329e8c023a53c1'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:131405'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '38866fcdb0f8ae89d3680135b09b9ce7'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:1004'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '6069e587e48a1cc11bc2e56dc78ed4fd'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:10893'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '9ecc9ca7d6ee6e7a63c0baf45695dd7f'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:114793'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'a6efc0b602cc31b7ce1003eb9576941d'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:432'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '4014dc603c87242b6fb4e0943c9b81cc'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:60685'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '759e08c9e99db331f372303ac60a0e93'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:84647'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '5cd3436b33deafab1da31d07466172c1'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:2266'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '8d8c206f4964b77c6768a365bbf46210'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:3929'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '1224a86595b2635bfa61a5cec1457fd5'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:55937'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'e6e8cc1270baf389d0ab3e21bdccff4f'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:2646'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'b2054d7041a5ac31f4036f4f4dab2c95'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:55244'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'f2008813033b4e0a66bc5f9c191b5bc1'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:1845'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'ada9a858b2ce23d3d4567480cb3881a3'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:7105'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '09fcb3d2419ac1eeba0ac3ba4c152815'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:11046'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '2d939996a1d6ffafbff37656eb859059'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:55281'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '3e559e7fe5d680efddc574249a3892bb'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:64080'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '8d4146af6adbc63c4a28ba593a5515e2'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:448834'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'f74ae40bba64afaee7a7da896984e64b'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:57404'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'd141fb6c18e5f527f47c4770e01b568f'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:80323'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'c4ba44ca7440536b383afed7dea4edea'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:388610'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '911970a685f8a7cae9d5d6111a92ad3f'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:9076'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'c7e0ef2befed48912257b847bd16dffc'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:130013'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'aab75697df24c11976a291ee8148f60b'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:26090'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '46151bbc223ea32429ddd4d435c52243'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:8455'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '37c28f515b7fad497609cd3a783375a0'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:11135'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '8845f16eac97329cceff6064bdd4b964'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:257407'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '11243b79b2f60a377dd9d9cc7f00871f'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:23743'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'e488fe346f9fb3cda7031384c55698fe'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:100130933'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '095d000323e0a6d090a18c0af25b3793'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:745'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'bbbc129eb7378ab13b8f63fbeae7b06c'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:9732'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'af3f01098d7bb780bb7254ab4e1bd23d'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:224'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '0d0dde47a257d3c17b832ca95faeb152'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:216'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '569fec794e74fb956684f84dedcf797c'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:29775'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '076466535ca166f6d5ee19a51acf674c'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:8460'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '360c3326bd775620bbb17ccaa2384cb5'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:2077'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '9f26d76b7c415941a5fc2a1e0bc70ffe'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:5468'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '3c33557110b392d16cf58bb4c2af77fe'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:84952'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '1c3aa17ef2746e15002c44326ad42c70'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:7402'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'aac9f64f564fb58644841e9406bcc288'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:130589'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '972c4a2875683fb2de9973171d5a78f1'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:121227'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '1581a917a65433e1c33ff775aed92755'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:30061'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'dfe8d3c74767270d3eb3006bc443a4a6'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:9886'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '9838495e2e0a48cf026c4f91858afe62'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:80704'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'd4e5e40fcc81ca9185a1c780ece582ab'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:731'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '354f79a214ba5d4b06105185355fd200'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:4148'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'ab86a80a42213b52a0a26262c53d7e63'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:7088'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '8d98d96a496ea25276dc4367c3bcf533'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:725'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '4e3ebd0168f7fe72657218f1f158bdbf'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:10981'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'f3d700cfac64c7333992a9f808ab65fd'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:710'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '75968dbc09a4a55d5294d07f02b6707d'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'MONDO:0007256'}],
#     'n1': [{'id': 'NCBIGene:55968'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '99d3637c2ab364a32a7077e87dfbf2d8'}]}}]}]}

# %%
# Example: Find the potential drugs that target KRAS (NCBIGene: 3845) and show sensitivity with KRAS (NCBIGene:3845) altered?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids":["NCBIGene:930"],
                    "categories":["biolink:Gene"]
                },
                "n1": {
                    "categories":["biolink:Cell"]
                    
               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:expressed_in"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL,json=query_json)
result = response.json()["message"]

# %%
result
# Out:
# {'query_graph': {'nodes': {'n0': {'ids': ['NCBIGene:930'],
#     'categories': ['biolink:Gene']},
#    'n1': {'categories': ['biolink:Cell']}},
#   'edges': {'e1': {'subject': 'n0',
#     'object': 'n1',
#     'predicates': ['biolink:expressed_in']}}},
#  'knowledge_graph': {'nodes': {'NCBIGene:930': {'categories': ['biolink:Gene'],
#     'name': 'CD19',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:930',
#        'ENSEMBL:ENSG00000177455',
#        'HGNC:1633',
#        'OMIM:107265',
#        'UMLS:C1413206',
#        'UniProtKB:P15391',
#        'PR:P15391',
#        'UMLS:C4316926']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['CD19',
#        'CD19 gene',
#        'CD19_HUMAN B-lymphocyte antigen CD19 (sprot)',
#        'B-lymphocyte antigen CD19 (human)',
#        'B-Lymphocyte Antigen CD19, human']}]},
#    'CL:0000236': {'categories': ['biolink:Cell'],
#     'name': 'B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000236']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['B cell']}]},
#    'CL:0000787': {'categories': ['biolink:Cell'],
#     'name': 'memory B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000787']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['memory B cell']}]},
#    'CL:0000786': {'categories': ['biolink:Cell'],
#     'name': 'plasma cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000786']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['plasma cell']}]},
#    'CL:0000738': {'categories': ['biolink:Cell'],
#     'name': 'leukocyte',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000738']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['leukocyte']}]},
#    'CL:0000134': {'categories': ['biolink:Cell'],
#     'name': 'mesenchymal stem cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000134']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['mesenchymal stem cell']}]},
#    'CL:0000451': {'categories': ['biolink:Cell'],
#     'name': 'dendritic cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000451']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['dendritic cell']}]},
#    'CL:0000845': {'categories': ['biolink:Cell'],
#     'name': 'marginal zone B cell of spleen',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000845']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['marginal zone B cell of spleen']}]},
#    'CL:0000843': {'categories': ['biolink:Cell'],
#     'name': 'follicular B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000843']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['follicular B cell']}]},
#    'CL:0000788': {'categories': ['biolink:Cell'],
#     'name': 'naive B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000788']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['naive B cell']}]},
#    'CL:0000844': {'categories': ['biolink:Cell'],
#     'name': 'germinal center B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000844']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['germinal center B cell']}]},
#    'CL:0000576': {'categories': ['biolink:Cell'],
#     'name': 'monocyte',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000576']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['monocyte']}]},
#    'CL:0000818': {'categories': ['biolink:Cell'],
#     'name': 'transitional stage B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000818']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['transitional stage B cell']}]},
#    'CL:0000980': {'categories': ['biolink:Cell'],
#     'name': 'plasmablast',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000980']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['plasmablast']}]},
#    'CL:0000084': {'categories': ['biolink:Cell'],
#     'name': 'T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000084']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['T cell']}]},
#    'CL:0000623': {'categories': ['biolink:Cell'],
#     'name': 'natural killer cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000623']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['natural killer cell']}]},
#    'CL:0000955': {'categories': ['biolink:Cell'],
#     'name': 'pre-B-II cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000955']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['pre-B-II cell']}]},
#    'CL:0000972': {'categories': ['biolink:Cell'],
#     'name': 'class switched memory B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000972']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['class switched memory B cell']}]},
#    'CL:0000775': {'categories': ['biolink:Cell'],
#     'name': 'neutrophil',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000775']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['neutrophil']}]},
#    'CL:0000969': {'categories': ['biolink:Cell'],
#     'name': 'regulatory B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000969']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['regulatory B cell']}]},
#    'CL:0000970': {'categories': ['biolink:Cell'],
#     'name': 'unswitched memory B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000970']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['unswitched memory B cell']}]},
#    'CL:0000946': {'categories': ['biolink:Cell'],
#     'name': 'antibody secreting cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000946']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['antibody secreting cell']}]},
#    'CL:0001043': {'categories': ['biolink:Cell'],
#     'name': 'activated CD4-positive, alpha-beta T cell, human',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0001043']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['activated CD4-positive, alpha-beta T cell, human']}]},
#    'CL:0001065': {'categories': ['biolink:Cell'],
#     'name': 'innate lymphoid cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0001065']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['innate lymphoid cell']}]},
#    'CL:0001064': {'categories': ['biolink:Cell'],
#     'name': 'malignant cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0001064']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['malignant cell']}]},
#    'CL:0000235': {'categories': ['biolink:Cell'],
#     'name': 'macrophage',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000235']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['macrophage']}]},
#    'CL:0000784': {'categories': ['biolink:Cell'],
#     'name': 'plasmacytoid dendritic cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000784']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['plasmacytoid dendritic cell']}]},
#    'CL:0000826': {'categories': ['biolink:Cell'],
#     'name': 'pro-B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000826']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['pro-B cell']}]},
#    'CL:0000816': {'categories': ['biolink:Cell'],
#     'name': 'immature B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000816']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['immature B cell']}]},
#    'CL:0000669': {'categories': ['biolink:Cell'],
#     'name': 'pericyte',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000669']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['pericyte']}]},
#    'CL:0000499': {'categories': ['biolink:Cell'],
#     'name': 'stromal cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000499']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['stromal cell']}]},
#    'CL:2000001': {'categories': ['biolink:Cell'],
#     'name': 'peripheral blood mononuclear cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:2000001']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['peripheral blood mononuclear cell']}]},
#    'CL:0000817': {'categories': ['biolink:Cell'],
#     'name': 'precursor B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000817']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['precursor B cell']}]},
#    'CL:0000959': {'categories': ['biolink:Cell'],
#     'name': 'T2 B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000959']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['T2 B cell']}]},
#    'CL:0000988': {'categories': ['biolink:Cell'],
#     'name': 'hematopoietic cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000988']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['hematopoietic cell']}]},
#    'CL:0000958': {'categories': ['biolink:Cell'],
#     'name': 'T1 B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000958']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['T1 B cell']}]},
#    'CL:0000542': {'categories': ['biolink:Cell'],
#     'name': 'lymphocyte',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000542']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['lymphocyte']}]},
#    'CL:0000763': {'categories': ['biolink:Cell'],
#     'name': 'myeloid cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000763']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['myeloid cell']}]},
#    'CL:0000767': {'categories': ['biolink:Cell'],
#     'name': 'basophil',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000767']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['basophil']}]},
#    'CL:0000785': {'categories': ['biolink:Cell'],
#     'name': 'mature B cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000785']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['mature B cell']}]}},
#   'edges': {'bc76be3316fb09288584a5333a839376': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000236',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:35048186'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '36d144fb4a320cce0634d27ca3a8e819': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000787',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:34621273'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '0f66632fcc3fb71ac449d185b28477fd': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000786',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33593977'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '47e0a0c9a33f69b7e9ae7537f0cbafed': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000738',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:35027754'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '9b12198edbd30f9d1a10e2bad8caed08': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000134',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:23572135'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002371'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '2d4b22ae752c462aa6f15fa9723edf09': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000451',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:35154907'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000995'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'ac1d5ffe3a55d82616808efb9b206747': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000845',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:34872616'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002106'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'ed1934d743badeab9fd6fd6673755a2c': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000843',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33212097'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0001264'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'f5516f5322f4ff90f7c26268301b81f4': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000788',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:35386690'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'a45b36872e72a9bbd12a28045ca754ec': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000844',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:31209070'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0001044'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'df00135379024858e206afdc15c83c88': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000576',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:29610856'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0005408'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '0151ba47d40e4ed1a0ccf3747308ca99': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000818',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:23731328'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002371'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '1f97a5e9c2435c307fc10afc32941c4b': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000980',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33593977'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '863e26ee57bdd68766f54c0356115671': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000084',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:32245502'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '17f64bb63e5c9508bca8a95a91ae48f1': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000623',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33986022'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '81b6996fcbb9e48fc60824db200944fe': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000955',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33248023'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002107'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '3d51257fa9270aff88643ab3ad79e2d2': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000972',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:34557188'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '3af48fce91dcf90f4049c895ff8e9c32': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000775',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:32912924'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '5e229b17e4c247139e9262265c50b589': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000969',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33040362'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0005408'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '77f99a5e1f5ec3d8b8e9e6702a0535bf': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000970',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:34621273'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '0a9842829a330f1256c62f94674f800f': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000946',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:31045577'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0005408'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '8b2c06fb8aab58a60b17fbea0b5a9456': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0001043',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:28566371'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'de01d8abf8caf8f8a549852c4e437bc9': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0001065',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33168949'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'cdd96ad69a942dc892dabac694d21564': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0001064',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33293583'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0001043'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '87853020c7b8c7e83a1586469783dc33': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000235',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:30746468'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '06170235e0d3f1e6fd23c9b2c3f7a03e': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000784',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:31552044'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0005408'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'ef1b295a7e538edfa8a63440fe6f4ba9': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000826',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33248023'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002107'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'b125b55ccfb065ba9a4c050a372976d5': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000816',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:34557188'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '739175d66d5f064249ba2e7d97e8c0d7': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000669',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:32961131'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000955'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'd907ca682d627c3d014356ec01ab4c11': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000499',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:16923606'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002371'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '088341d8325763af1e9c0b44072ab88e': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:2000001',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:34083792'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0005408'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '5fc8314f8e76b70ab9f26930a76a68ef': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000817',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:34349096'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002371'}],
# ...
#       'value': 'PMID:21551058'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002371'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '39ba9ac46b35a703cc3e37682ac5cfaf': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000958',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:23731328'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002371'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '80c6e88d0b4acbbff28c84645bb811b2': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000542',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33087716'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002371'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'ad47c133ee2a27ef5658f906f078077b': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000763',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33087716'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002371'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '09111ef0fa4f8f584f37670e842ba487': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000767',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:10520197'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '1d3a67e5a6500270124c32325647bb8c': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:930',
#     'object': 'CL:0000785',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:35185925'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]}}},
#  'auxiliary_graphs': {},
#  'results': [{'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000236'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'bc76be3316fb09288584a5333a839376'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000787'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '36d144fb4a320cce0634d27ca3a8e819'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000786'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '0f66632fcc3fb71ac449d185b28477fd'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000738'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '47e0a0c9a33f69b7e9ae7537f0cbafed'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000134'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '9b12198edbd30f9d1a10e2bad8caed08'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000451'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '2d4b22ae752c462aa6f15fa9723edf09'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000845'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'ac1d5ffe3a55d82616808efb9b206747'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000843'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'ed1934d743badeab9fd6fd6673755a2c'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000788'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'f5516f5322f4ff90f7c26268301b81f4'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000844'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'a45b36872e72a9bbd12a28045ca754ec'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000576'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'df00135379024858e206afdc15c83c88'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000818'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '0151ba47d40e4ed1a0ccf3747308ca99'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000980'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '1f97a5e9c2435c307fc10afc32941c4b'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000084'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '863e26ee57bdd68766f54c0356115671'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000623'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '17f64bb63e5c9508bca8a95a91ae48f1'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000955'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '81b6996fcbb9e48fc60824db200944fe'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000972'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '3d51257fa9270aff88643ab3ad79e2d2'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000775'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '3af48fce91dcf90f4049c895ff8e9c32'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000969'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '5e229b17e4c247139e9262265c50b589'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000970'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '77f99a5e1f5ec3d8b8e9e6702a0535bf'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000946'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '0a9842829a330f1256c62f94674f800f'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0001043'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '8b2c06fb8aab58a60b17fbea0b5a9456'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0001065'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'de01d8abf8caf8f8a549852c4e437bc9'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0001064'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'cdd96ad69a942dc892dabac694d21564'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000235'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '87853020c7b8c7e83a1586469783dc33'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000784'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '06170235e0d3f1e6fd23c9b2c3f7a03e'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000826'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'ef1b295a7e538edfa8a63440fe6f4ba9'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000816'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'b125b55ccfb065ba9a4c050a372976d5'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000669'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '739175d66d5f064249ba2e7d97e8c0d7'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000499'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'd907ca682d627c3d014356ec01ab4c11'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:2000001'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '088341d8325763af1e9c0b44072ab88e'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000817'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '5fc8314f8e76b70ab9f26930a76a68ef'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000959'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'f3776f04c0859cd00874f56fc14fd88d'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000988'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '8d3d032a9cf502ff3706c8dde733f210'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000958'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '39ba9ac46b35a703cc3e37682ac5cfaf'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000542'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '80c6e88d0b4acbbff28c84645bb811b2'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000763'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'ad47c133ee2a27ef5658f906f078077b'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000767'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '09111ef0fa4f8f584f37670e842ba487'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:930'}],
#     'n1': [{'id': 'CL:0000785'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '1d3a67e5a6500270124c32325647bb8c'}]}}]}]}

# %%
# Example: what are the genes that are negatively correlcted with KRAS (NCBIGene:3845) ?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids":["NCBIGene:3845"],
                    "categories":["biolink:Gene"]
                },
                "n1": {
                    "categories":["biolink:Gene"]
                    
               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:positively_correlated_with"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL,json=query_json)
result = response.json()["message"]

# %%
result['knowledge_graph']
# Out:
# {'nodes': {'NCBIGene:3845': {'categories': ['biolink:Gene'],
#    'name': 'KRAS',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3845',
#       'ENSEMBL:ENSG00000133703',
#       'HGNC:6407',
#       'OMIM:190070',
#       'UMLS:C1537502',
#       'UniProtKB:A0A024RAV5',
#       'UniProtKB:I1SRC5',
#       'UniProtKB:L7RSL8',
#       'UniProtKB:P01116',
#       'PR:P01116',
#       'UMLS:C0763464']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['KRAS',
#       'KRAS gene',
#       'A0A024RAV5_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog, isoform CRA_b (trembl)',
#       'I1SRC5_HUMAN UBE2L3/KRAS fusion protein (trembl)',
#       'L7RSL8_HUMAN V-Ki-ras2 Kirsten rat sarcoma viral oncogene homolog (trembl)',
#       'RASK_HUMAN GTPase KRas (sprot)',
#       'GTPase KRas (human)',
#       'KRAS protein, human']}]},
#   'NCBIGene:23673': {'categories': ['biolink:Gene'],
#    'name': 'STX12',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23673',
#       'ENSEMBL:ENSG00000117758',
#       'HGNC:11430',
#       'OMIM:606892',
#       'UMLS:C1420495',
#       'UniProtKB:Q86Y82',
#       'PR:Q86Y82',
#       'ENSEMBL:ENSP00000363054',
#       'ENSEMBL:ENSP00000363054.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['STX12',
#       'STX12 gene',
#       'STX12_HUMAN Syntaxin-12 (sprot)',
#       'syntaxin-12 (human)']}]},
#   'NCBIGene:51441': {'categories': ['biolink:Gene'],
#    'name': 'YTHDF2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:51441',
#       'ENSEMBL:ENSG00000198492',
#       'HGNC:31675',
#       'OMIM:610640',
#       'UMLS:C1538134',
#       'UniProtKB:Q9Y5A9',
#       'PR:Q9Y5A9',
#       'UMLS:C3273756']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['YTHDF2',
#       'YTHDF2 gene',
#       'YTHD2_HUMAN YTH domain-containing family protein 2 (sprot)',
#       'YTH domain-containing family protein 2 (human)',
#       'YTH Domain Family Protein 2']}]},
#   'NCBIGene:8073': {'categories': ['biolink:Gene'],
#    'name': 'PTP4A2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:8073',
#       'ENSEMBL:ENSG00000184007',
#       'HGNC:9635',
#       'OMIM:601584',
#       'UMLS:C1419089',
#       'UniProtKB:Q12974',
#       'PR:Q12974']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PTP4A2',
#       'PTP4A2 gene',
#       'TP4A2_HUMAN Protein tyrosine phosphatase type IVA 2 (sprot)',
#       'protein tyrosine phosphatase type IVA 2 (human)']}]},
#   'NCBIGene:57708': {'categories': ['biolink:Gene'],
#    'name': 'MIER1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:57708',
#       'ENSEMBL:ENSG00000198160',
#       'HGNC:29657',
#       'OMIM:616848',
#       'UMLS:C1825991',
#       'UniProtKB:Q8N108',
#       'PR:Q8N108']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MIER1',
#       'MIER1 gene',
#       'MIER1_HUMAN Mesoderm induction early response protein 1 (sprot)',
#       'mesoderm induction early response protein 1 (human)']}]},
#   'NCBIGene:23507': {'categories': ['biolink:Gene'],
#    'name': 'LRRC8B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23507',
#       'ENSEMBL:ENSG00000197147',
#       'HGNC:30692',
#       'OMIM:612888',
#       'UMLS:C1825877',
#       'UniProtKB:A0A384N5V6',
#       'UniProtKB:A0A7I2RK03',
#       'ENSEMBL:ENSP00000400704',
#       'ENSEMBL:ENSP00000400704.2',
#       'UniProtKB:Q6P9F7',
#       'PR:Q6P9F7',
#       'ENSEMBL:ENSP00000332674',
#       'ENSEMBL:ENSP00000332674.2',
#       'ENSEMBL:ENSP00000491377',
#       'ENSEMBL:ENSP00000491377.1',
#       'ENSEMBL:ENSP00000492151',
#       'ENSEMBL:ENSP00000492151.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['LRRC8B',
#       'LRRC8B gene',
#       'A0A384N5V6_HUMAN Epididymis secretory sperm binding protein (trembl)',
#       'A0A7I2RK03_HUMAN Volume-regulated anion channel subunit LRRC8B (trembl)',
#       'LRC8B_HUMAN Volume-regulated anion channel subunit LRRC8B (sprot)',
#       'volume-regulated anion channel subunit LRRC8B (human)']}]},
#   'NCBIGene:6884': {'categories': ['biolink:Gene'],
#    'name': 'TAF13',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6884',
#       'ENSEMBL:ENSG00000197780',
#       'HGNC:11546',
#       'OMIM:600774',
#       'UMLS:C1336563',
#       'UniProtKB:A0A024R089',
#       'UniProtKB:Q15543',
#       'PR:Q15543',
#       'ENSEMBL:ENSP00000355051',
#       'ENSEMBL:ENSP00000355051.4',
#       'UMLS:C0756346']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TAF13',
#       'TAF13 gene',
#       'A0A024R089_HUMAN TAF13 RNA polymerase II, TATA box binding protein (TBP)-associated factor, 18kDa, isoform CRA_a (trembl)',
#       'TAF13_HUMAN Transcription initiation factor TFIID subunit 13 (sprot)',
#       'transcription initiation factor TFIID subunit 13 (human)',
#       'TAF13 protein, human']}]},
#   'NCBIGene:23215': {'categories': ['biolink:Gene'],
#    'name': 'PRRC2C',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23215',
#       'ENSEMBL:ENSG00000117523',
#       'HGNC:24903',
#       'OMIM:617373',
#       'UMLS:C1538318',
#       'UniProtKB:E7EPN9',
#       'ENSEMBL:ENSP00000356716',
#       'ENSEMBL:ENSP00000356716.3',
#       'UniProtKB:Q9Y520',
#       'PR:Q9Y520']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PRRC2C',
#       'PRRC2C gene',
#       'E7EPN9_HUMAN Protein PRRC2C (trembl)',
#       'PRC2C_HUMAN Protein PRRC2C (sprot)',
#       'protein PRRC2C (human)']}]},
#   'NCBIGene:84919': {'categories': ['biolink:Gene'],
#    'name': 'PPP1R15B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:84919',
#       'ENSEMBL:ENSG00000158615',
#       'HGNC:14951',
#       'OMIM:613257',
#       'UMLS:C1423081',
#       'UniProtKB:A0A8I5KSH1',
#       'ENSEMBL:ENSP00000508814',
#       'ENSEMBL:ENSP00000508814.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PPP1R15B',
#       'PPP1R15B gene',
#       'A0A8I5KSH1_HUMAN Protein phosphatase 1 regulatory subunit 15B (trembl)']}]},
#   'NCBIGene:5861': {'categories': ['biolink:Gene'],
#    'name': 'RAB1A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5861',
#       'ENSEMBL:ENSG00000138069',
#       'HGNC:9758',
#       'OMIM:179508',
#       'UMLS:C1419187',
#       'UniProtKB:B7Z8M7',
#       'UniProtKB:P62820',
#       'PR:P62820',
#       'UniProtKB:Q5U0I6']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAB1A',
#       'RAB1A gene',
#       'B7Z8M7_HUMAN cDNA FLJ57768, highly similar to Ras-related protein Rab-1A (trembl)',
#       'RAB1A_HUMAN Ras-related protein Rab-1A (sprot)',
#       'Ras-related protein Rab-1A (human)',
#       'Q5U0I6_HUMAN H.sapiens ras-related Hrab1A protein (trembl)']}]},
#   'NCBIGene:56902': {'categories': ['biolink:Gene'],
#    'name': 'PNO1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:56902',
#       'ENSEMBL:ENSG00000115946',
#       'HGNC:32790',
#       'OMIM:618710',
#       'UMLS:C1826636',
#       'UniProtKB:Q9NRX1',
#       'PR:Q9NRX1',
#       'ENSEMBL:ENSP00000263657',
#       'ENSEMBL:ENSP00000263657.2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PNO1',
#       'PNO1 gene',
#       'PNO1_HUMAN RNA-binding protein PNO1 (sprot)',
#       'RNA-binding protein PNO1 (human)']}]},
#   'NCBIGene:3987': {'categories': ['biolink:Gene'],
#    'name': 'LIMS1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:3987',
#       'ENSEMBL:ENSG00000169756',
#       'HGNC:6616',
#       'OMIM:602567',
#       'UMLS:C1366510',
#       'UniProtKB:P48059',
#       'PR:P48059',
#       'UMLS:C0256491']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['LIMS1',
#       'LIMS1 gene',
#       'LIMS1_HUMAN LIM and senescent cell antigen-like-containing domain protein 1 (sprot)',
#       'LIM and senescent cell antigen-like-containing domain protein 1 (human)',
#       'LIMS1 protein, human']}]},
#   'NCBIGene:65977': {'categories': ['biolink:Gene'],
#    'name': 'PLEKHA3',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:65977',
#       'ENSEMBL:ENSG00000116095',
#       'HGNC:14338',
#       'OMIM:607774',
#       'UMLS:C1422575',
#       'UniProtKB:Q9HB20',
#       'PR:Q9HB20',
#       'ENSEMBL:ENSP00000234453',
#       'ENSEMBL:ENSP00000234453.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PLEKHA3',
#       'PLEKHA3 gene',
#       'PKHA3_HUMAN Pleckstrin homology domain-containing family A member 3 (sprot)',
#       'pleckstrin homology domain-containing family A member 3 (human)']}]},
#   'NCBIGene:5868': {'categories': ['biolink:Gene'],
#    'name': 'RAB5A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5868',
#       'ENSEMBL:ENSG00000144566',
#       'HGNC:9783',
#       'OMIM:179512',
#       'UMLS:C1419212',
#       'UniProtKB:A0A024R2K1',
#       'UniProtKB:P20339',
#       'PR:P20339',
#       'UMLS:C5400795']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAB5A',
#       'RAB5A gene',
#       'A0A024R2K1_HUMAN RAB5A, member RAS oncogene family, isoform CRA_a (trembl)',
#       'RAB5A_HUMAN Ras-related protein Rab-5A (sprot)',
#       'Ras-related protein Rab-5A (human)',
#       'Ras-Related Protein Rab-5A']}]},
#   'NCBIGene:7871': {'categories': ['biolink:Gene'],
#    'name': 'SLMAP',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7871',
#       'ENSEMBL:ENSG00000163681',
#       'HGNC:16643',
#       'OMIM:602701',
#       'UMLS:C1424461',
#       'UniProtKB:B7Z6C7',
#       'UniProtKB:B7Z964',
#       'UniProtKB:Q14BN4',
#       'PR:Q14BN4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLMAP',
#       'SLMAP gene',
#       'B7Z6C7_HUMAN cDNA FLJ54546, highly similar to Homo sapiens sarcolemma associated protein (SLMAP), mRNA (trembl)',
#       'B7Z964_HUMAN cDNA FLJ60222, highly similar to Homo sapiens sarcolemma associated protein (SLMAP), mRNA (trembl)',
#       'SLMAP_HUMAN Sarcolemmal membrane-associated protein (sprot)',
#       'sarcolemmal membrane-associated protein (human)']}]},
#   'NCBIGene:7110': {'categories': ['biolink:Gene'],
#    'name': 'TMF1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7110',
#       'ENSEMBL:ENSG00000144747',
#       'HGNC:11870',
#       'OMIM:601126',
#       'UMLS:C1420778',
#       'UniProtKB:A0A024R370',
#       'UniProtKB:P82094',
#       'PR:P82094',
#       'UniProtKB:Q6PII6']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TMF1',
#       'TMF1 gene',
#       'A0A024R370_HUMAN TATA element modulatory factor 1, isoform CRA_a (trembl)',
#       'TMF1_HUMAN TATA element modulatory factor (sprot)',
#       'TATA element modulatory factor (human)',
#       'Q6PII6_HUMAN TMF1 protein (Fragment) (trembl)']}]},
#   'NCBIGene:79691': {'categories': ['biolink:Gene'],
#    'name': 'QTRT2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:79691',
#       'ENSEMBL:ENSG00000151576',
#       'HGNC:25771',
#       'UMLS:C1428518',
#       'UniProtKB:Q9H974',
#       'PR:Q9H974']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['QTRT2',
#       'QTRT2 gene',
#       'QTRT2_HUMAN Queuine tRNA-ribosyltransferase accessory subunit 2 (sprot)',
#       'queuine tRNA-ribosyltransferase accessory subunit 2 (human)']}]},
#   'NCBIGene:55153': {'categories': ['biolink:Gene'],
#    'name': 'SDAD1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:55153',
#       'ENSEMBL:ENSG00000198301',
#       'HGNC:25537',
#       'UMLS:C1428499',
#       'UniProtKB:B4DT66',
#       'UniProtKB:E7EW05',
#       'ENSEMBL:ENSP00000379061',
#       'ENSEMBL:ENSP00000379061.4',
#       'UniProtKB:Q9NVU7',
#       'PR:Q9NVU7']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SDAD1',
#       'SDAD1 gene',
#       'B4DT66_HUMAN Protein SDA1 (trembl)',
#       'E7EW05_HUMAN Protein SDA1 (trembl)',
#       'SDA1_HUMAN Protein SDA1 homolog (sprot)',
#       'protein SDA1 homolog (human)']}]},
#   'NCBIGene:10492': {'categories': ['biolink:Gene'],
#    'name': 'SYNCRIP',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10492',
#       'ENSEMBL:ENSG00000135316',
#       'HGNC:16918',
#       'OMIM:616686',
#       'UMLS:C1424633',
#       'UniProtKB:A0A7I2V309',
#       'ENSEMBL:ENSP00000503183',
#       'ENSEMBL:ENSP00000503183.1',
#       'UniProtKB:A0A7I2YQN2',
#       'ENSEMBL:ENSP00000504086',
#       'ENSEMBL:ENSP00000504086.1',
#       'ENSEMBL:ENSP00000504816',
#       'ENSEMBL:ENSP00000504816.1',
#       'UniProtKB:B7Z645',
#       'ENSEMBL:ENSP00000484577',
#       'ENSEMBL:ENSP00000484577.1',
#       'ENSEMBL:ENSP00000506874',
#       'ENSEMBL:ENSP00000506874.1',
#       'ENSEMBL:ENSP00000507008',
#       'ENSEMBL:ENSP00000507008.1',
#       'ENSEMBL:ENSP00000507581',
#       'ENSEMBL:ENSP00000507581.1',
#       'ENSEMBL:ENSP00000507623',
#       'ENSEMBL:ENSP00000507623.1',
#       'UniProtKB:O60506',
#       'PR:O60506',
#       'UniProtKB:Q59GL1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SYNCRIP',
#       'SYNCRIP gene',
#       'A0A7I2V309_HUMAN Heterogeneous nuclear ribonucleoprotein Q (trembl)',
#       'A0A7I2YQN2_HUMAN Heterogeneous nuclear ribonucleoprotein Q (trembl)',
#       'B7Z645_HUMAN Heterogeneous nuclear ribonucleoprotein Q (trembl)',
#       'HNRPQ_HUMAN Heterogeneous nuclear ribonucleoprotein Q (sprot)',
#       'heterogeneous nuclear ribonucleoprotein Q (human)',
#       'Q59GL1_HUMAN Synaptotagmin binding, cytoplasmic RNA interacting protein variant (Fragment) (trembl)']}]},
#   'NCBIGene:50640': {'categories': ['biolink:Gene'],
#    'name': 'PNPLA8',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:50640',
#       'ENSEMBL:ENSG00000135241',
#       'HGNC:28900',
#       'OMIM:612123',
#       'UMLS:C1826639',
#       'UniProtKB:A0A024R746',
#       'UniProtKB:Q9NP80',
#       'PR:Q9NP80']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PNPLA8',
#       'PNPLA8 gene',
#       'A0A024R746_HUMAN Intracellular membrane-associated calcium-independent phospholipase A2 gamma, isoform CRA_a (trembl)',
#       'PLPL8_HUMAN Calcium-independent phospholipase A2-gamma (sprot)',
#       'calcium-independent phospholipase A2-gamma (human)']}]},
#   'NCBIGene:5516': {'categories': ['biolink:Gene'],
#    'name': 'PPP2CB',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5516',
#       'ENSEMBL:ENSG00000104695',
#       'HGNC:9300',
#       'OMIM:176916',
#       'UMLS:C1335242',
#       'UniProtKB:A0A140VJS0',
#       'UniProtKB:P62714',
#       'PR:P62714',
#       'ENSEMBL:ENSP00000221138',
#       'ENSEMBL:ENSP00000221138.4',
#       'UMLS:C1335540']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PPP2CB',
#       'PPP2CB gene',
#       'A0A140VJS0_HUMAN Serine/threonine-protein phosphatase (trembl)',
#       'PP2AB_HUMAN Serine/threonine-protein phosphatase 2A catalytic subunit beta isoform (sprot)',
#       'serine/threonine-protein phosphatase 2A catalytic subunit beta isoform (human)',
#       'PPP2CB protein, human']}]},
#   'NCBIGene:7534': {'categories': ['biolink:Gene'],
#    'name': 'YWHAZ',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7534',
#       'ENSEMBL:ENSG00000164924',
#       'HGNC:12855',
#       'OMIM:601288',
#       'UMLS:C1421564',
#       'UniProtKB:D0PNI1',
#       'UniProtKB:P63104',
#       'PR:P63104']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['YWHAZ',
#       'YWHAZ gene',
#       'D0PNI1_HUMAN Epididymis luminal protein 4 (trembl)',
#       '1433Z_HUMAN 14-3-3 protein zeta/delta (sprot)',
#       '14-3-3 protein zeta/delta (human)']}]},
#   'NCBIGene:81034': {'categories': ['biolink:Gene'],
#    'name': 'SLC25A32',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:81034',
#       'ENSEMBL:ENSG00000164933',
#       'HGNC:29683',
#       'OMIM:138480',
#       'UMLS:C1822742',
#       'UniProtKB:Q9H2D1',
#       'PR:Q9H2D1',
#       'ENSEMBL:ENSP00000297578',
#       'ENSEMBL:ENSP00000297578.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SLC25A32',
#       'SLC25A32 gene',
#       'MFTC_HUMAN Mitochondrial folate transporter/carrier (sprot)',
#       'mitochondrial folate transporter/carrier (human)']}]},
#   'NCBIGene:29979': {'categories': ['biolink:Gene'],
#    'name': 'UBQLN1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:29979',
#       'ENSEMBL:ENSG00000135018',
#       'HGNC:12508',
#       'OMIM:605046',
#       'UMLS:C1421304',
#       'UniProtKB:A0A024R258',
#       'UniProtKB:Q9UMX0',
#       'PR:Q9UMX0']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['UBQLN1',
#       'UBQLN1 gene',
#       'A0A024R258_HUMAN Ubiquilin 1, isoform CRA_d (trembl)',
#       'UBQL1_HUMAN Ubiquilin-1 (sprot)',
#       'ubiquilin-1 (human)']}]},
#   'NCBIGene:29982': {'categories': ['biolink:Gene'],
#    'name': 'NRBF2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:29982',
#       'ENSEMBL:ENSG00000148572',
#       'HGNC:19692',
#       'OMIM:616477',
#       'UMLS:C1426338',
#       'UniProtKB:Q96F24',
#       'PR:Q96F24']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NRBF2',
#       'NRBF2 gene',
#       'NRBF2_HUMAN Nuclear receptor-binding factor 2 (sprot)',
#       'nuclear receptor-binding factor 2 (human)']}]},
#   'NCBIGene:10285': {'categories': ['biolink:Gene'],
#    'name': 'SMNDC1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10285',
#       'ENSEMBL:ENSG00000119953',
#       'HGNC:16900',
#       'OMIM:603519',
#       'UMLS:C1424623',
#       'UniProtKB:O75940',
#       'PR:O75940',
#       'ENSEMBL:ENSP00000358605',
#       'ENSEMBL:ENSP00000358605.1',
#       'ENSEMBL:ENSP00000358616',
#       'ENSEMBL:ENSP00000358616.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SMNDC1',
#       'SMNDC1 gene',
#       'SPF30_HUMAN Survival of motor neuron-related-splicing factor 30 (sprot)',
#       'survival of motor neuron-related-splicing factor 30 (human)']}]},
#   'NCBIGene:4928': {'categories': ['biolink:Gene'],
#    'name': 'NUP98',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:4928',
#       'ENSEMBL:ENSG00000110713',
#       'HGNC:8068',
#       'OMIM:601021',
#       'UMLS:C1334913',
#       'UniProtKB:P52948',
#       'PR:P52948',
#       'UMLS:C1143533',
#       'UMLS:C4522157']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NUP98',
#       'NUP98 gene',
#       'NUP98_HUMAN Nuclear pore complex protein Nup98-Nup96 (sprot)',
#       'nuclear pore complex protein Nup98-Nup96 (human)',
#       'NUP98 protein, human',
#       'Nuclear Pore Complex Protein Nup98-Nup96']}]},
#   'NCBIGene:10179': {'categories': ['biolink:Gene'],
#    'name': 'RBM7',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10179',
#       'ENSEMBL:ENSG00000076053',
#       'HGNC:9904',
#       'OMIM:612413',
#       'UMLS:C1419302',
#       'UniProtKB:G3V1T9',
#       'ENSEMBL:ENSP00000445848',
#       'ENSEMBL:ENSP00000445848.1',
#       'UniProtKB:J3KPD3',
#       'ENSEMBL:ENSP00000364639',
#       'ENSEMBL:ENSP00000364639.5',
#       'UniProtKB:Q9Y580',
#       'PR:Q9Y580',
#       'ENSEMBL:ENSP00000439918',
#       'ENSEMBL:ENSP00000439918.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RBM7',
#       'RBM7 gene',
#       'G3V1T9_HUMAN RNA binding motif protein 7, isoform CRA_a (trembl)',
#       'J3KPD3_HUMAN RNA binding motif protein 7, isoform CRA_c (trembl)',
#       'RBM7_HUMAN RNA-binding protein 7 (sprot)',
#       'RNA-binding protein 7 (human)']}]},
#   'NCBIGene:56270': {'categories': ['biolink:Gene'],
#    'name': 'WDR45B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:56270',
#       'ENSEMBL:ENSG00000141580',
#       'HGNC:25072',
#       'OMIM:609226',
#       'UMLS:C1538089',
#       'UniProtKB:Q5MNZ6',
#       'PR:Q5MNZ6',
#       'ENSEMBL:ENSP00000376139',
#       'ENSEMBL:ENSP00000376139.4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['WDR45B',
#       'WDR45B gene',
#       'WIPI3_HUMAN WD repeat domain phosphoinositide-interacting protein 3 (sprot)',
#       'WD repeat domain phosphoinositide-interacting protein 3 (human)']}]},
#   'NCBIGene:10054': {'categories': ['biolink:Gene'],
#    'name': 'UBA2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10054',
#       'ENSEMBL:ENSG00000126261',
#       'HGNC:30661',
#       'OMIM:613295',
#       'UMLS:C1826967',
#       'UniProtKB:Q9UBT2',
#       'PR:Q9UBT2',
#       'UMLS:C1306952']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['UBA2',
#       'UBA2 gene',
#       'SAE2_HUMAN SUMO-activating enzyme subunit 2 (sprot)',
#       'SUMO-activating enzyme subunit 2 (human)',
#       'UBA2 protein, human']}]},
#   'NCBIGene:5621': {'categories': ['biolink:Gene'],
#    'name': 'PRNP',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5621',
#       'ENSEMBL:ENSG00000171867',
#       'HGNC:9449',
#       'OMIM:176640',
#       'UMLS:C1418941',
#       'UniProtKB:F7VJQ1',
#       'UniProtKB:P04156',
#       'PR:P04156',
#       'UMLS:C2346932',
#       'UniProtKB:Q53YK7']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PRNP',
#       'PRNP gene',
#       'APRIO_HUMAN Alternative prion protein (sprot)',
#       'PRIO_HUMAN Major prion protein (sprot)',
#       'major prion protein (human)',
#       'Major Prion Protein, Human',
#       'Q53YK7_HUMAN Major prion protein (trembl)']}]},
#   'NCBIGene:7150': {'categories': ['biolink:Gene'],
#    'name': 'TOP1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7150',
#       'ENSEMBL:ENSG00000198900',
#       'HGNC:11986',
#       'OMIM:126420',
#       'UMLS:C1336656',
#       'UniProtKB:P11387',
#       'PR:P11387',
#       'ENSEMBL:ENSP00000354522',
#       'ENSEMBL:ENSP00000354522.2',
#       'UMLS:C1458146',
#       'UniProtKB:Q9BVT2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TOP1',
#       'TOP1 gene',
#       'TOP1_HUMAN DNA topoisomerase 1 (sprot)',
#       'DNA topoisomerase 1 (human)',
#       'TOP1 protein, human',
#       'Q9BVT2_HUMAN TOPEUc domain-containing protein (Fragment) (trembl)']}]},
#   'NCBIGene:57403': {'categories': ['biolink:Gene'],
#    'name': 'RAB22A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:57403',
#       'ENSEMBL:ENSG00000124209',
#       'HGNC:9764',
#       'OMIM:612966',
#       'UMLS:C1419193',
#       'UniProtKB:Q9UL26',
#       'PR:Q9UL26',
#       'ENSEMBL:ENSP00000244040',
#       'ENSEMBL:ENSP00000244040.3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAB22A',
#       'RAB22A gene',
#       'RB22A_HUMAN Ras-related protein Rab-22A (sprot)',
#       'Ras-related protein Rab-22A (human)']}]},
#   'NCBIGene:51012': {'categories': ['biolink:Gene'],
#    'name': 'PRELID3B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:51012',
#       'ENSEMBL:ENSG00000101166',
#       'HGNC:15892',
#       'UMLS:C1423812',
#       'UniProtKB:Q9Y3B1',
#       'PR:Q9Y3B1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PRELID3B',
#       'PRELID3B gene',
#       'PLD3B_HUMAN PRELI domain containing protein 3B (sprot)',
#       'PRELI domain containing protein 3B (human)']}]},
#   'NCBIGene:54915': {'categories': ['biolink:Gene'],
#    'name': 'YTHDF1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:54915',
#       'ENSEMBL:ENSG00000149658',
#       'HGNC:15867',
#       'OMIM:616529',
#       'UMLS:C1538132',
#       'UniProtKB:Q9BYJ9',
#       'PR:Q9BYJ9']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['YTHDF1',
#       'YTHDF1 gene',
#       'YTHD1_HUMAN YTH domain-containing family protein 1 (sprot)',
#       'YTH domain-containing family protein 1 (human)']}]},
#   'NCBIGene:80218': {'categories': ['biolink:Gene'],
#    'name': 'NAA50',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:80218',
#       'ENSEMBL:ENSG00000121579',
#       'HGNC:29533',
#       'OMIM:610834',
#       'UMLS:C1826357',
#       'UniProtKB:E7EQ69',
#       'ENSEMBL:ENSP00000417837',
#       'ENSEMBL:ENSP00000417837.1',
#       'UniProtKB:Q9GZZ1',
#       'PR:Q9GZZ1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NAA50',
#       'NAA50 gene',
#       'E7EQ69_HUMAN N-alpha-acetyltransferase 50 (trembl)',
#       'NAA50_HUMAN N-alpha-acetyltransferase 50 (sprot)',
#       'N-alpha-acetyltransferase 50 (human)']}]},
#   'NCBIGene:6434': {'categories': ['biolink:Gene'],
#    'name': 'TRA2B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6434',
#       'ENSEMBL:ENSG00000136527',
#       'HGNC:10781',
#       'OMIM:602719',
#       'UMLS:C1419990',
#       'UniProtKB:P62995',
#       'PR:P62995']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TRA2B',
#       'TRA2B gene',
#       'TRA2B_HUMAN Transformer-2 protein homolog beta (sprot)',
#       'transformer-2 protein homolog beta (human)']}]},
#   'NCBIGene:4790': {'categories': ['biolink:Gene'],
#    'name': 'NFKB1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:4790',
#       'ENSEMBL:ENSG00000109320',
#       'HGNC:7794',
#       'OMIM:164011',
#       'UMLS:C1417708',
#       'UniProtKB:P19838',
#       'PR:P19838',
#       'UMLS:C1452413',
#       'UMLS:C2986465']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NFKB1',
#       'NFKB1 gene',
#       'NFKB1_HUMAN Nuclear factor NF-kappa-B p105 subunit (sprot)',
#       'nuclear factor NF-kappa-B p105 subunit (human)',
#       'NFKB1 protein, human',
#       'Nuclear Factor NF-kappa-B p105 Subunit']}]},
#   'NCBIGene:166929': {'categories': ['biolink:Gene'],
#    'name': 'SGMS2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:166929',
#       'ENSEMBL:ENSG00000164023',
#       'HGNC:28395',
#       'OMIM:611574',
#       'UMLS:C1969043',
#       'UniProtKB:A0A024RDH4',
#       'UniProtKB:Q8NHU3',
#       'PR:Q8NHU3',
#       'ENSEMBL:ENSP00000351981',
#       'ENSEMBL:ENSP00000351981.4',
#       'ENSEMBL:ENSP00000378176',
#       'ENSEMBL:ENSP00000378176.4',
#       'ENSEMBL:ENSP00000378178',
#       'ENSEMBL:ENSP00000378178.3',
#       'ENSEMBL:ENSP00000508566',
#       'ENSEMBL:ENSP00000508566.1',
#       'UMLS:C3641910']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SGMS2',
#       'SGMS2 gene',
#       'A0A024RDH4_HUMAN PAP2_C domain-containing protein (trembl)',
#       'SMS2_HUMAN Phosphatidylcholine:ceramide cholinephosphotransferase 2 (sprot)',
#       'phosphatidylcholine:ceramide cholinephosphotransferase 2 (human)',
#       'Phosphatidylcholine:Ceramide Cholinephosphotransferase 2']}]},
#   'NCBIGene:80155': {'categories': ['biolink:Gene'],
#    'name': 'NAA15',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:80155',
#       'ENSEMBL:ENSG00000164134',
#       'HGNC:30782',
#       'OMIM:608000',
#       'UMLS:C1538040',
#       'UniProtKB:A0A0B4J1W3',
#       'ENSEMBL:ENSP00000381920',
#       'ENSEMBL:ENSP00000381920.1',
#       'UniProtKB:B2RBE5',
#       'UniProtKB:Q9BXJ9',
#       'PR:Q9BXJ9']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NAA15',
#       'NAA15 gene',
#       'A0A0B4J1W3_HUMAN N-alpha-acetyltransferase 15, NatA auxiliary subunit (trembl)',
#       'B2RBE5_HUMAN cDNA, FLJ95468, highly similar to Homo sapiens transcriptional coactivator tubedown-100 (TBDN100),transcript variant 1, mRNA (trembl)',
#       'NAA15_HUMAN N-alpha-acetyltransferase 15, NatA auxiliary subunit (sprot)',
#       'N-alpha-acetyltransferase 15, NatA auxiliary subunit (human)']}]},
#   'NCBIGene:54545': {'categories': ['biolink:Gene'],
#    'name': 'MTMR12',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:54545',
#       'ENSEMBL:ENSG00000150712',
#       'HGNC:18191',
#       'OMIM:606501',
#       'UMLS:C1538024',
#       'UniProtKB:Q9C0I1',
#       'PR:Q9C0I1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MTMR12',
#       'MTMR12 gene',
#       'MTMRC_HUMAN Myotubularin-related protein 12 (sprot)',
#       'myotubularin-related protein 12 (human)']}]},
#   'NCBIGene:83732': {'categories': ['biolink:Gene'],
#    'name': 'RIOK1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:83732',
#       'ENSEMBL:ENSG00000124784',
#       'HGNC:18656',
#       'OMIM:617753',
#       'UMLS:C1425683',
#       'UniProtKB:Q9BRS2',
#       'PR:Q9BRS2',
#       'ENSEMBL:ENSP00000369162',
#       'ENSEMBL:ENSP00000369162.2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RIOK1',
#       'RIOK1 gene',
#       'RIOK1_HUMAN Serine/threonine-protein kinase RIO1 (sprot)',
#       'serine/threonine-protein kinase RIO1 (human)']}]},
#   'NCBIGene:55003': {'categories': ['biolink:Gene'],
#    'name': 'PAK1IP1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:55003',
#       'ENSEMBL:ENSG00000111845',
#       'HGNC:20882',
#       'OMIM:607811',
#       'UMLS:C1427187',
#       'UniProtKB:A0A0S2Z5C3',
#       'UniProtKB:Q9NWT1',
#       'PR:Q9NWT1',
#       'ENSEMBL:ENSP00000368887',
#       'ENSEMBL:ENSP00000368887.3',
#       'ENSEMBL:ENSP00000496482',
#       'ENSEMBL:ENSP00000496482.1']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PAK1IP1',
#       'PAK1IP1 gene',
#       'A0A0S2Z5C3_HUMAN PAK1 interacting protein 1 isoform 1 (Fragment) (trembl)',
#       'PK1IP_HUMAN p21-activated protein kinase-interacting protein 1 (sprot)',
#       'p21-activated protein kinase-interacting protein 1 (human)']}]},
#   'NCBIGene:54887': {'categories': ['biolink:Gene'],
#    'name': 'BLTP3A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:54887',
#       'ENSEMBL:ENSG00000065060',
#       'HGNC:21216',
#       'OMIM:619570',
#       'UMLS:C1427423',
#       'UniProtKB:Q6BDS2',
#       'PR:Q6BDS2',
#       'ENSEMBL:ENSP00000192788',
#       'ENSEMBL:ENSP00000192788.5']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['BLTP3A',
#       'UHRF1BP1 gene',
#       'URFB1_HUMAN UHRF1-binding protein 1 (sprot)',
#       'UHRF1-binding protein 1 (human)']}]},
#   'NCBIGene:88745': {'categories': ['biolink:Gene'],
#    'name': 'RRP36',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:88745',
#       'ENSEMBL:ENSG00000124541',
#       'HGNC:21374',
#       'OMIM:613475',
#       'UMLS:C1427520',
#       'UniProtKB:Q96EU6',
#       'PR:Q96EU6']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RRP36',
#       'RRP36 gene',
#       'RRP36_HUMAN Ribosomal RNA processing protein 36 homolog (sprot)',
#       'ribosomal RNA processing protein 36 homolog (human)']}]},
#   'NCBIGene:9589': {'categories': ['biolink:Gene'],
#    'name': 'WTAP',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:9589',
#       'ENSEMBL:ENSG00000146457',
#       'HGNC:16846',
#       'OMIM:605442',
#       'UMLS:C1424590',
#       'UniProtKB:A0A087X1R4',
#       'ENSEMBL:ENSP00000484404',
#       'ENSEMBL:ENSP00000484404.1',
#       'ENSEMBL:ENSP00000487338',
#       'ENSEMBL:ENSP00000487338.1',
#       'UniProtKB:Q15007',
#       'PR:Q15007',
#       'UMLS:C1432048']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['WTAP',
#       'WTAP gene',
#       'A0A087X1R4_HUMAN Pre-mRNA-splicing regulator WTAP (trembl)',
#       'FL2D_HUMAN Pre-mRNA-splicing regulator WTAP (sprot)',
#       'pre-mRNA-splicing regulator WTAP (human)',
#       'WTAP protein, human']}]},
#   'NCBIGene:734': {'categories': ['biolink:Gene'],
#    'name': 'OSGIN2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:734',
#       'ENSEMBL:ENSG00000164823',
#       'HGNC:1355',
#       'OMIM:604598',
#       'UMLS:C1826518',
#       'UniProtKB:A0A024R9D5',
#       'UniProtKB:Q9Y236',
#       'PR:Q9Y236']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['OSGIN2',
#       'OSGIN2 gene',
#       'A0A024R9D5_HUMAN Chromosome 8 open reading frame 1, isoform CRA_a (trembl)',
#       'OSGI2_HUMAN Oxidative stress-induced growth inhibitor 2 (sprot)',
#       'oxidative stress-induced growth inhibitor 2 (human)']}]},
#   'NCBIGene:23760': {'categories': ['biolink:Gene'],
#    'name': 'PITPNB',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23760',
#       'ENSEMBL:ENSG00000180957',
#       'HGNC:9002',
#       'OMIM:606876',
#       'UMLS:C1418593',
#       'UniProtKB:P48739',
#       'PR:P48739']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PITPNB',
#       'PITPNB gene',
#       'PIPNB_HUMAN Phosphatidylinositol transfer protein beta isoform (sprot)',
#       'phosphatidylinositol transfer protein beta isoform (human)']}]},
#   'NCBIGene:64645': {'categories': ['biolink:Gene'],
#    'name': 'MFSD14A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:64645',
#       'ENSEMBL:ENSG00000156875',
#       'HGNC:23363',
#       'UMLS:C1428051',
#       'UniProtKB:Q96MC6',
#       'PR:Q96MC6',
#       'ENSEMBL:ENSP00000359171',
#       'ENSEMBL:ENSP00000359171.3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MFSD14A',
#       'MFSD14A gene',
#       'MF14A_HUMAN Hippocampus abundant transcript 1 protein (sprot)',
#       'hippocampus abundant transcript 1 protein (human)']}]},
#   'NCBIGene:261726': {'categories': ['biolink:Gene'],
#    'name': 'TIPRL',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:261726',
#       'ENSEMBL:ENSG00000143155',
#       'HGNC:30231',
#       'OMIM:611807',
#       'UMLS:C1823282',
#       'UniProtKB:O75663',
#       'PR:O75663']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TIPRL',
#       'TIPRL gene',
#       'TIPRL_HUMAN TIP41-like protein (sprot)',
#       'TIP41-like protein (human)']}]},
#   'NCBIGene:84154': {'categories': ['biolink:Gene'],
#    'name': 'RPF2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:84154',
#       'ENSEMBL:ENSG00000197498',
#       'HGNC:20870',
#       'OMIM:618471',
#       'UMLS:C1427176',
#       'UniProtKB:Q9H7B2',
#       'PR:Q9H7B2',
#       'ENSEMBL:ENSP00000402338',
#       'ENSEMBL:ENSP00000402338.2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RPF2',
#       'RPF2 gene',
#       'RPF2_HUMAN Ribosome production factor 2 homolog (sprot)',
#       'ribosome production factor 2 homolog (human)']}]},
#   'NCBIGene:8797': {'categories': ['biolink:Gene'],
#    'name': 'TNFRSF10A',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:8797',
#       'ENSEMBL:ENSG00000104689',
#       'HGNC:11904',
#       'OMIM:603611',
#       'UMLS:C1336643',
#       'UniProtKB:O00220',
#       'PR:O00220',
#       'ENSEMBL:ENSP00000221132',
#       'ENSEMBL:ENSP00000221132.3',
#       'UMLS:C1504635']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TNFRSF10A',
#       'TNFRSF10A gene',
#       'TR10A_HUMAN Tumor necrosis factor receptor superfamily member 10A (sprot)',
#       'tumor necrosis factor receptor superfamily member 10A (human)',
#       'TNFRSF10A protein, human']}]},
#   'NCBIGene:10730': {'categories': ['biolink:Gene'],
#    'name': 'YME1L1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:10730',
#       'ENSEMBL:ENSG00000136758',
#       'HGNC:12843',
#       'OMIM:607472',
#       'UMLS:C1421554',
#       'UniProtKB:Q96TA2',
#       'PR:Q96TA2']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['YME1L1',
#       'YME1L1 gene',
#       'YMEL1_HUMAN ATP-dependent zinc metalloprotease YME1L1 (sprot)',
#       'ATP-dependent zinc metalloprotease YME1L1 (human)']}]},
#   'NCBIGene:9221': {'categories': ['biolink:Gene'],
#    'name': 'NOLC1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:9221',
#       'ENSEMBL:ENSG00000166197',
#       'HGNC:15608',
#       'OMIM:602394',
#       'UMLS:C1423614',
#       'UniProtKB:B2RAU8',
#       'UniProtKB:Q14978',
#       'PR:Q14978',
#       'UniProtKB:Q96J17']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NOLC1',
#       'NOLC1 gene',
#       'B2RAU8_HUMAN cDNA, FLJ95131, highly similar to Homo sapiens nucleolar and coiled-body phosphoprotein 1 (NOLC1), mRNA (trembl)',
#       'NOLC1_HUMAN Nucleolar and coiled-body phosphoprotein 1 (sprot)',
#       'nucleolar and coiled-body phosphoprotein 1 (human)',
#       'Q96J17_HUMAN NOLC1 protein (trembl)']}]},
#   'NCBIGene:8036': {'categories': ['biolink:Gene'],
#    'name': 'SHOC2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:8036',
#       'ENSEMBL:ENSG00000108061',
#       'HGNC:15454',
#       'OMIM:602775',
#       'UMLS:C1423500',
#       'UniProtKB:Q9UQ13',
#       'PR:Q9UQ13',
#       'UMLS:C0676309']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['SHOC2',
#       'SHOC2 gene',
#       'SHOC2_HUMAN Leucine-rich repeat protein SHOC-2 (sprot)',
#       'leucine-rich repeat protein SHOC-2 (human)',
#       'Leucine-Rich Repeat Protein SHOC-2, Human']}]},
#   'NCBIGene:5049': {'categories': ['biolink:Gene'],
#    'name': 'PAFAH1B2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5049',
#       'ENSEMBL:ENSG00000168092',
#       'HGNC:8575',
#       'OMIM:602508',
#       'UMLS:C1418246',
#       'UniProtKB:P68402',
#       'PR:P68402',
#       'UMLS:C3273681',
#       'UniProtKB:V9HW44']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['PAFAH1B2',
#       'PAFAH1B2 gene',
#       'PA1B2_HUMAN Platelet-activating factor acetylhydrolase IB subunit alpha2 (sprot)',
#       'platelet-activating factor acetylhydrolase IB subunit alpha2 (human)',
#       'Platelet-Activating Factor Acetylhydrolase IB Subunit Beta',
#       'V9HW44_HUMAN Epididymis secretory protein Li 303 (trembl)']}]},
#   'NCBIGene:5756': {'categories': ['biolink:Gene'],
#    'name': 'TWF1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5756',
#       'ENSEMBL:ENSG00000151239',
#       'HGNC:9620',
#       'OMIM:610932',
#       'UMLS:C1823556',
#       'UniProtKB:Q12792',
#       'PR:Q12792']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TWF1',
#       'TWF1 gene',
#       'TWF1_HUMAN Twinfilin-1 (sprot)',
#       'twinfilin-1 (human)']}]},
#   'NCBIGene:5908': {'categories': ['biolink:Gene'],
#    'name': 'RAP1B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:5908',
#       'ENSEMBL:ENSG00000127314',
#       'HGNC:9857',
#       'OMIM:179530',
#       'UMLS:C1419266',
#       'UniProtKB:A0A024RB87',
#       'UniProtKB:B7ZAY2',
#       'UniProtKB:P61224',
#       'PR:P61224']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAP1B',
#       'RAP1B gene',
#       'A0A024RB87_HUMAN RAP1B, member of RAS oncogene family, isoform CRA_a (trembl)',
#       'B7ZAY2_HUMAN cDNA, FLJ79346, highly similar to Ras-related protein Rap-1b (trembl)',
#       'RAP1B_HUMAN Ras-related protein Rap-1b (sprot)',
#       'Ras-related protein Rap-1b (human)']}]},
#   'NCBIGene:23011': {'categories': ['biolink:Gene'],
#    'name': 'RAB21',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:23011',
#       'ENSEMBL:ENSG00000080371',
#       'HGNC:18263',
#       'OMIM:612398',
#       'UMLS:C1425403',
#       'UniProtKB:A0A024RBA9',
#       'UniProtKB:Q9UL25',
#       'PR:Q9UL25',
#       'ENSEMBL:ENSP00000261263',
#       'ENSEMBL:ENSP00000261263.3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RAB21',
#       'RAB21 gene',
#       'A0A024RBA9_HUMAN Ras-related protein Rab-21 (trembl)',
#       'RAB21_HUMAN Ras-related protein Rab-21 (sprot)',
#       'Ras-related protein Rab-21 (human)']}]},
#   'NCBIGene:64786': {'categories': ['biolink:Gene'],
#    'name': 'TBC1D15',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:64786',
#       'ENSEMBL:ENSG00000121749',
#       'HGNC:25694',
#       'OMIM:612662',
#       'UMLS:C1428511',
#       'UniProtKB:A8K8E1',
#       'UniProtKB:Q8TC07',
#       'PR:Q8TC07']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TBC1D15',
#       'TBC1D15 gene',
#       'A8K8E1_HUMAN TBC1 domain family, member 15, isoform CRA_d (trembl)',
#       'TBC15_HUMAN TBC1 domain family member 15 (sprot)',
#       'TBC1 domain family member 15 (human)']}]},
#   'NCBIGene:6996': {'categories': ['biolink:Gene'],
#    'name': 'TDG',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6996',
#       'ENSEMBL:ENSG00000139372',
#       'HGNC:11700',
#       'OMIM:601423',
#       'UMLS:C1442760',
#       'UniProtKB:B4DI29',
#       'UniProtKB:B4E127',
#       'ENSEMBL:ENSP00000445899',
#       'ENSEMBL:ENSP00000445899.1',
#       'UniProtKB:Q13569',
#       'PR:Q13569',
#       'ENSEMBL:ENSP00000376611',
#       'ENSEMBL:ENSP00000376611.3',
#       'UMLS:C4316851']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['TDG',
#       'TDG gene',
#       'B4DI29_HUMAN cDNA FLJ60553, highly similar to G/T mismatch-specific thymine DNA glycosylase (trembl)',
#       'B4E127_HUMAN G/T mismatch-specific thymine DNA glycosylase (trembl)',
#       'TDG_HUMAN G/T mismatch-specific thymine DNA glycosylase (sprot)',
#       'G/T mismatch-specific thymine DNA glycosylase (human)',
#       'G/T Mismatch-Specific Thymine DNA Glycosylase, human']}]},
#   'NCBIGene:197131': {'categories': ['biolink:Gene'],
#    'name': 'UBR1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:197131',
#       'ENSEMBL:ENSG00000159459',
#       'HGNC:16808',
#       'OMIM:605981',
#       'UMLS:C1424562',
#       'UniProtKB:Q8IWV7',
#       'PR:Q8IWV7']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['UBR1',
#       'UBR1 gene',
#       'UBR1_HUMAN E3 ubiquitin-protein ligase UBR1 (sprot)',
#       'E3 ubiquitin-protein ligase UBR1 (human)']}]},
#   'NCBIGene:7874': {'categories': ['biolink:Gene'],
#    'name': 'USP7',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:7874',
#       'ENSEMBL:ENSG00000187555',
#       'HGNC:12630',
#       'OMIM:602519',
#       'UMLS:C1421408',
#       'UniProtKB:B7Z855',
#       'UniProtKB:B7ZAX6',
#       'UniProtKB:Q6U8A4',
#       'UniProtKB:Q93009',
#       'PR:Q93009',
#       'UMLS:C1142946']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['USP7',
#       'USP7 gene',
#       'B7Z855_HUMAN Ubiquitin carboxyl-terminal hydrolase 7 (trembl)',
#       'B7ZAX6_HUMAN Ubiquitin carboxyl-terminal hydrolase 7 (trembl)',
#       'Q6U8A4_HUMAN Ubiquitin carboxyl-terminal hydrolase 7 (Fragment) (trembl)',
#       'UBP7_HUMAN Ubiquitin carboxyl-terminal hydrolase 7 (sprot)',
#       'ubiquitin carboxyl-terminal hydrolase 7 (human)',
#       'USP7 protein, human']}]},
#   'NCBIGene:81631': {'categories': ['biolink:Gene'],
#    'name': 'MAP1LC3B',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:81631',
#       'ENSEMBL:ENSG00000140941',
#       'HGNC:13352',
#       'OMIM:609604',
#       'UMLS:C1421946',
#       'UniProtKB:Q658J6',
#       'UniProtKB:Q9GZQ8',
#       'PR:Q9GZQ8',
#       'ENSEMBL:ENSP00000268607',
#       'ENSEMBL:ENSP00000268607.5',
#       'ENSEMBL:ENSP00000498476',
#       'ENSEMBL:ENSP00000498476.1',
#       'UMLS:C1311384']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MAP1LC3B',
#       'MAP1LC3B gene',
#       'Q658J6_HUMAN Microtubule-associated protein 1 light chain 3 beta, isoform CRA_c (trembl)',
#       'MLP3B_HUMAN Microtubule-associated proteins 1A/1B light chain 3B (sprot)',
#       'microtubule-associated proteins 1A/1B light chain 3B (human)',
#       'MAP1LC3B protein, human']}]},
#   'NCBIGene:6416': {'categories': ['biolink:Gene'],
#    'name': 'MAP2K4',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6416',
#       'ENSEMBL:ENSG00000065559',
#       'HGNC:6844',
#       'OMIM:601335',
#       'UMLS:C1417008',
#       'UniProtKB:P45985',
#       'PR:P45985']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['MAP2K4',
#       'MAP2K4 gene',
#       'MP2K4_HUMAN Dual specificity mitogen-activated protein kinase kinase 4 (sprot)',
#       'dual specificity mitogen-activated protein kinase kinase 4 (human)']}]},
#   'NCBIGene:57532': {'categories': ['biolink:Gene'],
#    'name': 'NUFIP2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:57532',
#       'ENSEMBL:ENSG00000108256',
#       'HGNC:17634',
#       'OMIM:609356',
#       'UMLS:C1826496',
#       'UniProtKB:Q7Z417',
#       'PR:Q7Z417']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NUFIP2',
#       'NUFIP2 gene',
#       'NUFP2_HUMAN FMR1-interacting protein NUFIP2 (sprot)',
#       'FMR1-interacting protein NUFIP2 (human)']}]},
#   'NCBIGene:117584': {'categories': ['biolink:Gene'],
#    'name': 'RFFL',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:117584',
#       'ENSEMBL:ENSG00000092871',
#       'HGNC:24821',
#       'OMIM:609735',
#       'UMLS:C1826808',
#       'UniProtKB:Q8WZ73',
#       'PR:Q8WZ73']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['RFFL',
#       'RFFL gene',
#       'RFFL_HUMAN E3 ubiquitin-protein ligase rififylin (sprot)',
#       'E3 ubiquitin-protein ligase rififylin (human)']}]},
#   'NCBIGene:8774': {'categories': ['biolink:Gene'],
#    'name': 'NAPG',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:8774',
#       'ENSEMBL:ENSG00000134265',
#       'HGNC:7642',
#       'OMIM:603216',
#       'UMLS:C1417600',
#       'UniProtKB:Q6FHY4',
#       'UniProtKB:Q99747',
#       'PR:Q99747']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['NAPG',
#       'NAPG gene',
#       'Q6FHY4_HUMAN N-ethylmaleimide-sensitive factor attachment protein, gamma, isoform CRA_b (trembl)',
#       'SNAG_HUMAN Gamma-soluble NSF attachment protein (sprot)',
#       'gamma-soluble NSF attachment protein (human)']}]},
#   'NCBIGene:1540': {'categories': ['biolink:Gene'],
#    'name': 'CYLD',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:1540',
#       'ENSEMBL:ENSG00000083799',
#       'HGNC:2584',
#       'OMIM:605018',
#       'UMLS:C1413850',
#       'UniProtKB:A0A024R6T1',
#       'UniProtKB:Q9NQC7',
#       'PR:Q9NQC7',
#       'UMLS:C2985250']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['CYLD',
#       'CYLD gene',
#       'A0A024R6T1_HUMAN Ubiquitin carboxyl-terminal hydrolase CYLD (trembl)',
#       'CYLD_HUMAN Ubiquitin carboxyl-terminal hydrolase CYLD (sprot)',
#       'ubiquitin carboxyl-terminal hydrolase CYLD (human)',
#       'CYLD protein, human']}]},
#   'NCBIGene:54834': {'categories': ['biolink:Gene'],
#    'name': 'GDAP2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:54834',
#       'ENSEMBL:ENSG00000196505',
#       'HGNC:18010',
#       'OMIM:618128',
#       'UMLS:C1425237',
#       'UniProtKB:Q9NXN4',
#       'PR:Q9NXN4']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['GDAP2',
#       'GDAP2 gene',
#       'GDAP2_HUMAN Ganglioside-induced differentiation-associated protein 2 (sprot)',
#       'ganglioside-induced differentiation-associated protein 2 (human)']}]},
#   'NCBIGene:27000': {'categories': ['biolink:Gene'],
#    'name': 'DNAJC2',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:27000',
#       'ENSEMBL:ENSG00000105821',
#       'HGNC:13192',
#       'OMIM:605502',
#       'UMLS:C1421867',
#       'UniProtKB:Q99543',
#       'PR:Q99543']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['DNAJC2',
#       'DNAJC2 gene',
#       'DNJC2_HUMAN DnaJ homolog subfamily C member 2 (sprot)',
#       'DnaJ homolog subfamily C member 2 (human)']}]},
#   'NCBIGene:829': {'categories': ['biolink:Gene'],
#    'name': 'CAPZA1',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:829',
#       'ENSEMBL:ENSG00000116489',
#       'HGNC:1488',
#       'OMIM:601580',
#       'UMLS:C1413121',
#       'UniProtKB:P52907',
#       'PR:P52907',
#       'ENSEMBL:ENSP00000263168',
#       'ENSEMBL:ENSP00000263168.3']},
#     {'attribute_type_id': 'biolink:synonym',
#      'value': ['CAPZA1',
#       'CAPZA1 gene',
#       'CAZA1_HUMAN F-actin-capping protein subunit alpha-1 (sprot)',
#       'F-actin-capping protein subunit alpha-1 (human)']}]},
#   'NCBIGene:6990': {'categories': ['biolink:Gene'],
#    'name': 'DYNLT3',
#    'attributes': [{'attribute_type_id': 'biolink:xref',
#      'value': ['NCBIGene:6990',
#       'ENSEMBL:ENSG00000165169',
#       'HGNC:11694',
#       'OMIM:300302',
#       'UMLS:C1825019',
#       'UniProtKB:P51808',
#       'PR:P51808',
#       'ENSEMBL:ENSP00000367841',
# ...
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '6fbd988e642fd5a8f8e8f0e2b8f5eda9': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:54834',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '2df07c27a1a0e83938d0ca6fe8c84f00': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:27000',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '66b6f18b2cfd8db9b7154b78e966e63a': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:829',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '68b51070b58a99b3b6c21477e4aabf75': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:6990',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '62154b85dffba2fcdaf99bc6035afa0e': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:55500',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '96005de07139ed0de8a9b5ff6733c159': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:25948',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '17c356196adba20a88aa7aeb777202d8': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:9125',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '16dcf225aedeb2621cd86840546298dc': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:85403',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'e12315d1fbc136953a6966b0ccfa3012': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:51719',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '774df1239c5da09322ff6a06c25ecdd3': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:2117',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '95ab73cf5132c35f2ed95ac35d91f86c': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:1452',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '237647ff6838e52c06ba66401ebfdc26': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:84312',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '48c385c6b4cde7433358792c1788dfe8': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:1983',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '94f2fedd49b1c30c98ce35abdb11183d': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:23560',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   'a9bac2c64e064fefc27c67ba608d4cdd': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:283635',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '7d742f2e6e1472db4d8a0a9ed72fcfff': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:10294',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '2ee8857cdfc052b97dc12a57870b0a7c': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:3192',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#   '45dad52c242a6c06af274d16b3d85a7f': {'predicate': 'biolink:positively_correlated_with',
#    'subject': 'NCBIGene:3845',
#    'object': 'NCBIGene:1977',
#    'attributes': [{'attribute_type_id': 'biolink:supporting_study_size',
#      'value': 226},
#     {'attribute_type_id': 'biolink:dataset', 'value': 'GTEx'},
#     {'attribute_type_id': 'biolink:publications', 'value': 'PMID:32913098'},
#     {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#      'value': 'Liver'}],
#    'sources': [{'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#      'resource_role': 'primary_knowledge_source'},
#     {'resource_id': 'infores:gtex', 'resource_role': 'supporting_data_source'},
#     {'resource_id': 'infores:service-provider-trapi',
#      'resource_role': 'aggregator_knowledge_source',
#      'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]}}}

# %%
# Example: what are the genes that are negatively correlcted with KRAS (NCBIGene:3845) ?
query_json = {
    "message": {
        "query_graph": {
            "nodes": {
                "n0": {
                    "ids":["NCBIGene:3003"],
                    #"categories":["biolink:Gene"]
                },
                "n1": {
                    "categories":["biolink:Cell"]
                    
               }
            },
            "edges": {
                "e1": {
                    "subject": "n0",
                    "object": "n1",
                    "predicates": ["biolink:expressed_in"]
                }
            }
        }
    }
}

response = requests.post(BigGIM_URL_test,json=query_json)
result = response.json()["message"]

# %%
result
# Out:
# {'query_graph': {'nodes': {'n0': {'ids': ['NCBIGene:3003']},
#    'n1': {'categories': ['biolink:Cell']}},
#   'edges': {'e1': {'subject': 'n0',
#     'object': 'n1',
#     'predicates': ['biolink:expressed_in']}}},
#  'knowledge_graph': {'nodes': {'NCBIGene:3003': {'categories': ['biolink:Gene'],
#     'name': 'GZMK',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['NCBIGene:3003',
#        'ENSEMBL:ENSG00000113088',
#        'HGNC:4711',
#        'OMIM:600784',
#        'UMLS:C1415382',
#        'UniProtKB:P49863',
#        'PR:P49863',
#        'ENSEMBL:ENSP00000231009',
#        'ENSEMBL:ENSP00000231009.2']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['GZMK',
#        'GZMK gene',
#        'GRAK_HUMAN Granzyme K (sprot)',
#        'granzyme K (human)']}]},
#    'CL:0000623': {'categories': ['biolink:Cell'],
#     'name': 'natural killer cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000623']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['natural killer cell']}]},
#    'CL:0000910': {'categories': ['biolink:Cell'],
#     'name': 'cytotoxic T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000910']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['cytotoxic T cell']}]},
#    'CL:0000084': {'categories': ['biolink:Cell'],
#     'name': 'T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000084']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['T cell']}]},
#    'CL:0000625': {'categories': ['biolink:Cell'],
#     'name': 'CD8-positive, alpha-beta T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000625']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['CD8-positive, alpha-beta T cell']}]},
#    'CL:0000813': {'categories': ['biolink:Cell'],
#     'name': 'memory T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000813']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['memory T cell']}]},
#    'CL:0011025': {'categories': ['biolink:Cell'],
#     'name': 'exhausted T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0011025']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['exhausted T cell']}]},
#    'CL:0000912': {'categories': ['biolink:Cell'],
#     'name': 'helper T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000912']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['helper T cell']}]},
#    'CL:0000913': {'categories': ['biolink:Cell'],
#     'name': 'effector memory CD8-positive, alpha-beta T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000913']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['effector memory CD8-positive, alpha-beta T cell']}]},
#    'CL:0000940': {'categories': ['biolink:Cell'],
#     'name': 'mucosal invariant T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000940']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['mucosal invariant T cell']}]},
#    'CL:0000895': {'categories': ['biolink:Cell'],
#     'name': 'naive thymus-derived CD4-positive, alpha-beta T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000895']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['naive thymus-derived CD4-positive, alpha-beta T cell']}]},
#    'CL:0001044': {'categories': ['biolink:Cell'],
#     'name': 'effector CD4-positive, alpha-beta T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0001044']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['effector CD4-positive, alpha-beta T cell']}]},
#    'CL:0000909': {'categories': ['biolink:Cell'],
#     'name': 'CD8-positive, alpha-beta memory T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000909']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['CD8-positive, alpha-beta memory T cell']}]},
#    'CL:0000911': {'categories': ['biolink:Cell'],
#     'name': 'effector T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000911']},
#      {'attribute_type_id': 'biolink:synonym', 'value': ['effector T cell']}]},
#    'CL:0000897': {'categories': ['biolink:Cell'],
#     'name': 'CD4-positive, alpha-beta memory T cell',
#     'attributes': [{'attribute_type_id': 'biolink:xref',
#       'value': ['CL:0000897']},
#      {'attribute_type_id': 'biolink:synonym',
#       'value': ['CD4-positive, alpha-beta memory T cell']}]}},
#   'edges': {'e8e69a6bdcd1ef9c0de068f800554b47': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000623',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:34861544'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'f74b72c6a08e562e0e04e9a1fca3bef7': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000910',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:32541878'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000029'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '5a551d5c29d1279495ec19d4269d069f': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000084',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:30279229'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002371'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '1481e39387ac388e7874c3f71807b2c0': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000625',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:35184398'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002048'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '20850a87c671834f14d4a35066587798': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000813',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:35192548'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000160'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '539c93eea6301ed9799e01e5f1d15935': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0011025',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:35304295'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002107'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'c975102863683c0c1bf129fff18fd051': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000912',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:28622514'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002107'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '5e497a0c348f2843d1fde1122c9c6948': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000913',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:32796814'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '837475380807cc4ae9699337b8dbf76c': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000940',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:34721400'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0005408'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'c5882ac266068f04326e37cb7cc03a1f': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000895',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:33841428'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0002394'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    'd6ccd38b4a25fec29520f7cffd4bf99d': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0001044',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:35061012'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '04a9049b442ca9ea94e49bccd7238da2': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000909',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:35172892'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0005408'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '4f88e1132d27ed63eb34e0537f4c3bf4': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000911',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:34531370'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0000178'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]},
#    '29a8917cb0645d72a463bf69f9b69871': {'predicate': 'biolink:expressed_in',
#     'subject': 'NCBIGene:3003',
#     'object': 'CL:0000897',
#     'attributes': [{'attribute_type_id': 'biolink:publications',
#       'value': 'PMID:35172892'},
#      {'attribute_type_id': 'biolink:primary_knowledge_source',
#       'attributes': [{'attribute_type_id': 'biolink:source_infores',
#         'value': 'infores:cellmarker2.0'}],
#       'value': 'infores:cellmarker2.0'},
#      {'attribute_type_id': 'biolink:aggregator_knowledge_source',
#       'value': 'infores:biothings-multiomics-biggim-drugresponse'},
#      {'attribute_type_id': 'biolink:anatomical_context_qualifier',
#       'value': 'UBERON_0005408'}],
#     'sources': [{'resource_id': 'infores:cellmarker2.0',
#       'resource_role': 'primary_knowledge_source'},
#      {'resource_id': 'infores:biothings-multiomics-biggim-drugresponse',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:cellmarker2.0']},
#      {'resource_id': 'infores:service-provider-trapi',
#       'resource_role': 'aggregator_knowledge_source',
#       'upstream_resource_ids': ['infores:biothings-multiomics-biggim-drugresponse']}]}}},
#  'auxiliary_graphs': {},
#  'results': [{'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000623'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'e8e69a6bdcd1ef9c0de068f800554b47'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000910'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'f74b72c6a08e562e0e04e9a1fca3bef7'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000084'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '5a551d5c29d1279495ec19d4269d069f'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000625'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '1481e39387ac388e7874c3f71807b2c0'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000813'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '20850a87c671834f14d4a35066587798'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0011025'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '539c93eea6301ed9799e01e5f1d15935'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000912'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'c975102863683c0c1bf129fff18fd051'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000913'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '5e497a0c348f2843d1fde1122c9c6948'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000940'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '837475380807cc4ae9699337b8dbf76c'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000895'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'c5882ac266068f04326e37cb7cc03a1f'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0001044'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': 'd6ccd38b4a25fec29520f7cffd4bf99d'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000909'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '04a9049b442ca9ea94e49bccd7238da2'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000911'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '4f88e1132d27ed63eb34e0537f4c3bf4'}]}}]},
#   {'node_bindings': {'n0': [{'id': 'NCBIGene:3003'}],
#     'n1': [{'id': 'CL:0000897'}]},
#    'analyses': [{'resource_id': 'infores:service-provider-trapi',
#      'edge_bindings': {'e1': [{'id': '29a8917cb0645d72a463bf69f9b69871'}]}}]}]}
